# %%
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %% [markdown]
# To list the results for a specific race use the following URL with the required year and round number:
# http://ergast.com/api/f1/2008/5/results
# For example, to list all the results for a specific driver in a particular season:
# http://ergast.com/api/f1/2008/drivers/alonso/results

# %%
site = 'http://ergast.com/api/f1/'
drivers = 'drivers'
circuits = 'circuits'
constructors = 'constructors'
json = '.json?limit=1000'
years = range(1950,2021)

# %%
list_drivers = []
#function to return all the drivers in a range of years- Returns a dictionary of lists , the key is the year of the season year and the drivers_ID
def season_drivers(from_year, to_year):
    drivers_info = {}
    for year in range(from_year, to_year+1):
        drivers_info[year] = requests.get(site+ f'{str(year)}/'+ drivers +json).json()['MRData']['DriverTable']['Drivers']
    return drivers_info

# %%
season_drivers(2005,2007)
# Out:
# {2005: [{'driverId': 'albers',
#    'code': 'ALB',
#    'url': 'http://en.wikipedia.org/wiki/Christijan_Albers',
#    'givenName': 'Christijan',
#    'familyName': 'Albers',
#    'dateOfBirth': '1979-04-16',
#    'nationality': 'Dutch'},
#   {'driverId': 'alonso',
#    'permanentNumber': '14',
#    'code': 'ALO',
#    'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#    'givenName': 'Fernando',
#    'familyName': 'Alonso',
#    'dateOfBirth': '1981-07-29',
#    'nationality': 'Spanish'},
#   {'driverId': 'barrichello',
#    'code': 'BAR',
#    'url': 'http://en.wikipedia.org/wiki/Rubens_Barrichello',
#    'givenName': 'Rubens',
#    'familyName': 'Barrichello',
#    'dateOfBirth': '1972-05-23',
#    'nationality': 'Brazilian'},
#   {'driverId': 'button',
#    'permanentNumber': '22',
#    'code': 'BUT',
#    'url': 'http://en.wikipedia.org/wiki/Jenson_Button',
#    'givenName': 'Jenson',
#    'familyName': 'Button',
#    'dateOfBirth': '1980-01-19',
#    'nationality': 'British'},
#   {'driverId': 'coulthard',
#    'code': 'COU',
#    'url': 'http://en.wikipedia.org/wiki/David_Coulthard',
#    'givenName': 'David',
#    'familyName': 'Coulthard',
#    'dateOfBirth': '1971-03-27',
#    'nationality': 'British'},
#   {'driverId': 'davidson',
#    'code': 'DAV',
#    'url': 'http://en.wikipedia.org/wiki/Anthony_Davidson',
#    'givenName': 'Anthony',
#    'familyName': 'Davidson',
#    'dateOfBirth': '1979-04-18',
#    'nationality': 'British'},
#   {'driverId': 'rosa',
#    'code': 'DLR',
#    'url': 'http://en.wikipedia.org/wiki/Pedro_de_la_Rosa',
#    'givenName': 'Pedro',
#    'familyName': 'de la Rosa',
#    'dateOfBirth': '1971-02-24',
#    'nationality': 'Spanish'},
#   {'driverId': 'doornbos',
#    'code': 'DOO',
#    'url': 'http://en.wikipedia.org/wiki/Robert_Doornbos',
#    'givenName': 'Robert',
#    'familyName': 'Doornbos',
#    'dateOfBirth': '1981-09-23',
#    'nationality': 'Dutch'},
#   {'driverId': 'fisichella',
#    'code': 'FIS',
#    'url': 'http://en.wikipedia.org/wiki/Giancarlo_Fisichella',
#    'givenName': 'Giancarlo',
#    'familyName': 'Fisichella',
#    'dateOfBirth': '1973-01-14',
#    'nationality': 'Italian'},
#   {'driverId': 'friesacher',
#    'code': 'FRI',
#    'url': 'http://en.wikipedia.org/wiki/Patrick_Friesacher',
#    'givenName': 'Patrick',
#    'familyName': 'Friesacher',
#    'dateOfBirth': '1980-09-26',
#    'nationality': 'Austrian'},
#   {'driverId': 'heidfeld',
#    'code': 'HEI',
#    'url': 'http://en.wikipedia.org/wiki/Nick_Heidfeld',
#    'givenName': 'Nick',
#    'familyName': 'Heidfeld',
#    'dateOfBirth': '1977-05-10',
#    'nationality': 'German'},
#   {'driverId': 'karthikeyan',
#    'code': 'KAR',
#    'url': 'http://en.wikipedia.org/wiki/Narain_Karthikeyan',
#    'givenName': 'Narain',
#    'familyName': 'Karthikeyan',
#    'dateOfBirth': '1977-01-14',
#    'nationality': 'Indian'},
#   {'driverId': 'klien',
#    'code': 'KLI',
#    'url': 'http://en.wikipedia.org/wiki/Christian_Klien',
#    'givenName': 'Christian',
#    'familyName': 'Klien',
#    'dateOfBirth': '1983-02-07',
#    'nationality': 'Austrian'},
#   {'driverId': 'liuzzi',
#    'code': 'LIU',
#    'url': 'http://en.wikipedia.org/wiki/Vitantonio_Liuzzi',
#    'givenName': 'Vitantonio',
#    'familyName': 'Liuzzi',
#    'dateOfBirth': '1980-08-06',
#    'nationality': 'Italian'},
#   {'driverId': 'massa',
#    'permanentNumber': '19',
#    'code': 'MAS',
#    'url': 'http://en.wikipedia.org/wiki/Felipe_Massa',
#    'givenName': 'Felipe',
#    'familyName': 'Massa',
#    'dateOfBirth': '1981-04-25',
#    'nationality': 'Brazilian'},
#   {'driverId': 'monteiro',
#    'code': 'TMO',
#    'url': 'http://en.wikipedia.org/wiki/Tiago_Monteiro',
#    'givenName': 'Tiago',
#    'familyName': 'Monteiro',
#    'dateOfBirth': '1976-07-24',
#    'nationality': 'Portuguese'},
#   {'driverId': 'montoya',
#    'code': 'MON',
#    'url': 'http://en.wikipedia.org/wiki/Juan_Pablo_Montoya',
#    'givenName': 'Juan',
#    'familyName': 'Pablo Montoya',
#    'dateOfBirth': '1975-09-20',
#    'nationality': 'Colombian'},
#   {'driverId': 'pizzonia',
#    'code': 'PIZ',
#    'url': 'http://en.wikipedia.org/wiki/Ant%C3%B4nio_Pizzonia',
#    'givenName': 'Antônio',
#    'familyName': 'Pizzonia',
#    'dateOfBirth': '1980-09-11',
#    'nationality': 'Brazilian'},
#   {'driverId': 'raikkonen',
#    'permanentNumber': '7',
#    'code': 'RAI',
#    'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#    'givenName': 'Kimi',
#    'familyName': 'Räikkönen',
#    'dateOfBirth': '1979-10-17',
#    'nationality': 'Finnish'},
#   {'driverId': 'sato',
#    'code': 'SAT',
#    'url': 'http://en.wikipedia.org/wiki/Takuma_Sato',
#    'givenName': 'Takuma',
#    'familyName': 'Sato',
#    'dateOfBirth': '1977-01-28',
#    'nationality': 'Japanese'},
#   {'driverId': 'ralf_schumacher',
#    'code': 'SCH',
#    'url': 'http://en.wikipedia.org/wiki/Ralf_Schumacher',
#    'givenName': 'Ralf',
#    'familyName': 'Schumacher',
#    'dateOfBirth': '1975-06-30',
#    'nationality': 'German'},
#   {'driverId': 'michael_schumacher',
#    'code': 'MSC',
#    'url': 'http://en.wikipedia.org/wiki/Michael_Schumacher',
#    'givenName': 'Michael',
#    'familyName': 'Schumacher',
#    'dateOfBirth': '1969-01-03',
#    'nationality': 'German'},
#   {'driverId': 'trulli',
#    'code': 'TRU',
#    'url': 'http://en.wikipedia.org/wiki/Jarno_Trulli',
#    'givenName': 'Jarno',
#    'familyName': 'Trulli',
#    'dateOfBirth': '1974-07-13',
#    'nationality': 'Italian'},
#   {'driverId': 'villeneuve',
#    'code': 'VIL',
#    'url': 'http://en.wikipedia.org/wiki/Jacques_Villeneuve',
#    'givenName': 'Jacques',
#    'familyName': 'Villeneuve',
#    'dateOfBirth': '1971-04-09',
#    'nationality': 'Canadian'},
#   {'driverId': 'webber',
#    'code': 'WEB',
#    'url': 'http://en.wikipedia.org/wiki/Mark_Webber',
#    'givenName': 'Mark',
#    'familyName': 'Webber',
#    'dateOfBirth': '1976-08-27',
#    'nationality': 'Australian'},
#   {'driverId': 'wurz',
#    'code': 'WUR',
#    'url': 'http://en.wikipedia.org/wiki/Alexander_Wurz',
#    'givenName': 'Alexander',
#    'familyName': 'Wurz',
#    'dateOfBirth': '1974-02-15',
#    'nationality': 'Austrian'},
#   {'driverId': 'zonta',
#    'code': 'ZON',
#    'url': 'http://en.wikipedia.org/wiki/Ricardo_Zonta',
#    'givenName': 'Ricardo',
#    'familyName': 'Zonta',
#    'dateOfBirth': '1976-03-23',
#    'nationality': 'Brazilian'}],
#  2006: [{'driverId': 'albers',
#    'code': 'ALB',
#    'url': 'http://en.wikipedia.org/wiki/Christijan_Albers',
#    'givenName': 'Christijan',
#    'familyName': 'Albers',
#    'dateOfBirth': '1979-04-16',
#    'nationality': 'Dutch'},
#   {'driverId': 'alonso',
#    'permanentNumber': '14',
#    'code': 'ALO',
#    'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#    'givenName': 'Fernando',
#    'familyName': 'Alonso',
#    'dateOfBirth': '1981-07-29',
#    'nationality': 'Spanish'},
#   {'driverId': 'barrichello',
#    'code': 'BAR',
#    'url': 'http://en.wikipedia.org/wiki/Rubens_Barrichello',
#    'givenName': 'Rubens',
#    'familyName': 'Barrichello',
#    'dateOfBirth': '1972-05-23',
#    'nationality': 'Brazilian'},
#   {'driverId': 'button',
#    'permanentNumber': '22',
#    'code': 'BUT',
#    'url': 'http://en.wikipedia.org/wiki/Jenson_Button',
#    'givenName': 'Jenson',
#    'familyName': 'Button',
#    'dateOfBirth': '1980-01-19',
#    'nationality': 'British'},
#   {'driverId': 'coulthard',
#    'code': 'COU',
#    'url': 'http://en.wikipedia.org/wiki/David_Coulthard',
#    'givenName': 'David',
#    'familyName': 'Coulthard',
#    'dateOfBirth': '1971-03-27',
#    'nationality': 'British'},
#   {'driverId': 'rosa',
#    'code': 'DLR',
#    'url': 'http://en.wikipedia.org/wiki/Pedro_de_la_Rosa',
#    'givenName': 'Pedro',
#    'familyName': 'de la Rosa',
#    'dateOfBirth': '1971-02-24',
#    'nationality': 'Spanish'},
#   {'driverId': 'doornbos',
#    'code': 'DOO',
#    'url': 'http://en.wikipedia.org/wiki/Robert_Doornbos',
#    'givenName': 'Robert',
#    'familyName': 'Doornbos',
#    'dateOfBirth': '1981-09-23',
#    'nationality': 'Dutch'},
#   {'driverId': 'fisichella',
#    'code': 'FIS',
#    'url': 'http://en.wikipedia.org/wiki/Giancarlo_Fisichella',
#    'givenName': 'Giancarlo',
#    'familyName': 'Fisichella',
#    'dateOfBirth': '1973-01-14',
#    'nationality': 'Italian'},
#   {'driverId': 'heidfeld',
#    'code': 'HEI',
#    'url': 'http://en.wikipedia.org/wiki/Nick_Heidfeld',
#    'givenName': 'Nick',
#    'familyName': 'Heidfeld',
#    'dateOfBirth': '1977-05-10',
#    'nationality': 'German'},
#   {'driverId': 'ide',
#    'code': 'IDE',
#    'url': 'http://en.wikipedia.org/wiki/Yuji_Ide',
#    'givenName': 'Yuji',
#    'familyName': 'Ide',
#    'dateOfBirth': '1975-01-21',
#    'nationality': 'Japanese'},
#   {'driverId': 'klien',
#    'code': 'KLI',
#    'url': 'http://en.wikipedia.org/wiki/Christian_Klien',
#    'givenName': 'Christian',
#    'familyName': 'Klien',
#    'dateOfBirth': '1983-02-07',
#    'nationality': 'Austrian'},
#   {'driverId': 'kubica',
#    'permanentNumber': '88',
#    'code': 'KUB',
#    'url': 'http://en.wikipedia.org/wiki/Robert_Kubica',
#    'givenName': 'Robert',
#    'familyName': 'Kubica',
#    'dateOfBirth': '1984-12-07',
#    'nationality': 'Polish'},
#   {'driverId': 'liuzzi',
#    'code': 'LIU',
#    'url': 'http://en.wikipedia.org/wiki/Vitantonio_Liuzzi',
#    'givenName': 'Vitantonio',
#    'familyName': 'Liuzzi',
#    'dateOfBirth': '1980-08-06',
#    'nationality': 'Italian'},
#   {'driverId': 'massa',
#    'permanentNumber': '19',
#    'code': 'MAS',
#    'url': 'http://en.wikipedia.org/wiki/Felipe_Massa',
#    'givenName': 'Felipe',
#    'familyName': 'Massa',
#    'dateOfBirth': '1981-04-25',
#    'nationality': 'Brazilian'},
#   {'driverId': 'montagny',
#    'code': 'FMO',
#    'url': 'http://en.wikipedia.org/wiki/Franck_Montagny',
#    'givenName': 'Franck',
#    'familyName': 'Montagny',
#    'dateOfBirth': '1978-01-05',
#    'nationality': 'French'},
#   {'driverId': 'monteiro',
#    'code': 'TMO',
#    'url': 'http://en.wikipedia.org/wiki/Tiago_Monteiro',
#    'givenName': 'Tiago',
#    'familyName': 'Monteiro',
#    'dateOfBirth': '1976-07-24',
#    'nationality': 'Portuguese'},
#   {'driverId': 'montoya',
#    'code': 'MON',
#    'url': 'http://en.wikipedia.org/wiki/Juan_Pablo_Montoya',
#    'givenName': 'Juan',
#    'familyName': 'Pablo Montoya',
#    'dateOfBirth': '1975-09-20',
#    'nationality': 'Colombian'},
#   {'driverId': 'raikkonen',
#    'permanentNumber': '7',
#    'code': 'RAI',
#    'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#    'givenName': 'Kimi',
#    'familyName': 'Räikkönen',
#    'dateOfBirth': '1979-10-17',
#    'nationality': 'Finnish'},
#   {'driverId': 'rosberg',
#    'permanentNumber': '6',
#    'code': 'ROS',
#    'url': 'http://en.wikipedia.org/wiki/Nico_Rosberg',
#    'givenName': 'Nico',
#    'familyName': 'Rosberg',
#    'dateOfBirth': '1985-06-27',
#    'nationality': 'German'},
#   {'driverId': 'sato',
#    'code': 'SAT',
#    'url': 'http://en.wikipedia.org/wiki/Takuma_Sato',
#    'givenName': 'Takuma',
#    'familyName': 'Sato',
#    'dateOfBirth': '1977-01-28',
#    'nationality': 'Japanese'},
#   {'driverId': 'ralf_schumacher',
#    'code': 'SCH',
#    'url': 'http://en.wikipedia.org/wiki/Ralf_Schumacher',
#    'givenName': 'Ralf',
#    'familyName': 'Schumacher',
#    'dateOfBirth': '1975-06-30',
#    'nationality': 'German'},
#   {'driverId': 'michael_schumacher',
#    'code': 'MSC',
#    'url': 'http://en.wikipedia.org/wiki/Michael_Schumacher',
#    'givenName': 'Michael',
#    'familyName': 'Schumacher',
#    'dateOfBirth': '1969-01-03',
#    'nationality': 'German'},
#   {'driverId': 'speed',
#    'code': 'SPE',
#    'url': 'http://en.wikipedia.org/wiki/Scott_Speed',
#    'givenName': 'Scott',
#    'familyName': 'Speed',
#    'dateOfBirth': '1983-01-24',
#    'nationality': 'American'},
#   {'driverId': 'trulli',
#    'code': 'TRU',
#    'url': 'http://en.wikipedia.org/wiki/Jarno_Trulli',
#    'givenName': 'Jarno',
#    'familyName': 'Trulli',
#    'dateOfBirth': '1974-07-13',
#    'nationality': 'Italian'},
#   {'driverId': 'villeneuve',
#    'code': 'VIL',
#    'url': 'http://en.wikipedia.org/wiki/Jacques_Villeneuve',
#    'givenName': 'Jacques',
#    'familyName': 'Villeneuve',
#    'dateOfBirth': '1971-04-09',
#    'nationality': 'Canadian'},
#   {'driverId': 'webber',
#    'code': 'WEB',
#    'url': 'http://en.wikipedia.org/wiki/Mark_Webber',
#    'givenName': 'Mark',
#    'familyName': 'Webber',
#    'dateOfBirth': '1976-08-27',
#    'nationality': 'Australian'},
#   {'driverId': 'yamamoto',
#    'code': 'YAM',
#    'url': 'http://en.wikipedia.org/wiki/Sakon_Yamamoto',
#    'givenName': 'Sakon',
#    'familyName': 'Yamamoto',
#    'dateOfBirth': '1982-07-09',
#    'nationality': 'Japanese'}],
#  2007: [{'driverId': 'albers',
#    'code': 'ALB',
#    'url': 'http://en.wikipedia.org/wiki/Christijan_Albers',
#    'givenName': 'Christijan',
#    'familyName': 'Albers',
#    'dateOfBirth': '1979-04-16',
#    'nationality': 'Dutch'},
#   {'driverId': 'alonso',
#    'permanentNumber': '14',
#    'code': 'ALO',
#    'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#    'givenName': 'Fernando',
#    'familyName': 'Alonso',
#    'dateOfBirth': '1981-07-29',
#    'nationality': 'Spanish'},
#   {'driverId': 'barrichello',
#    'code': 'BAR',
#    'url': 'http://en.wikipedia.org/wiki/Rubens_Barrichello',
#    'givenName': 'Rubens',
#    'familyName': 'Barrichello',
#    'dateOfBirth': '1972-05-23',
#    'nationality': 'Brazilian'},
#   {'driverId': 'button',
#    'permanentNumber': '22',
#    'code': 'BUT',
#    'url': 'http://en.wikipedia.org/wiki/Jenson_Button',
#    'givenName': 'Jenson',
#    'familyName': 'Button',
#    'dateOfBirth': '1980-01-19',
#    'nationality': 'British'},
#   {'driverId': 'coulthard',
#    'code': 'COU',
#    'url': 'http://en.wikipedia.org/wiki/David_Coulthard',
#    'givenName': 'David',
#    'familyName': 'Coulthard',
#    'dateOfBirth': '1971-03-27',
#    'nationality': 'British'},
#   {'driverId': 'davidson',
#    'code': 'DAV',
#    'url': 'http://en.wikipedia.org/wiki/Anthony_Davidson',
#    'givenName': 'Anthony',
#    'familyName': 'Davidson',
#    'dateOfBirth': '1979-04-18',
#    'nationality': 'British'},
#   {'driverId': 'fisichella',
#    'code': 'FIS',
#    'url': 'http://en.wikipedia.org/wiki/Giancarlo_Fisichella',
#    'givenName': 'Giancarlo',
#    'familyName': 'Fisichella',
#    'dateOfBirth': '1973-01-14',
#    'nationality': 'Italian'},
#   {'driverId': 'hamilton',
#    'permanentNumber': '44',
#    'code': 'HAM',
#    'url': 'http://en.wikipedia.org/wiki/Lewis_Hamilton',
#    'givenName': 'Lewis',
#    'familyName': 'Hamilton',
#    'dateOfBirth': '1985-01-07',
#    'nationality': 'British'},
#   {'driverId': 'heidfeld',
#    'code': 'HEI',
#    'url': 'http://en.wikipedia.org/wiki/Nick_Heidfeld',
#    'givenName': 'Nick',
#    'familyName': 'Heidfeld',
#    'dateOfBirth': '1977-05-10',
#    'nationality': 'German'},
#   {'driverId': 'kovalainen',
#    'code': 'KOV',
#    'url': 'http://en.wikipedia.org/wiki/Heikki_Kovalainen',
#    'givenName': 'Heikki',
#    'familyName': 'Kovalainen',
#    'dateOfBirth': '1981-10-19',
#    'nationality': 'Finnish'},
#   {'driverId': 'kubica',
#    'permanentNumber': '88',
#    'code': 'KUB',
#    'url': 'http://en.wikipedia.org/wiki/Robert_Kubica',
#    'givenName': 'Robert',
#    'familyName': 'Kubica',
#    'dateOfBirth': '1984-12-07',
#    'nationality': 'Polish'},
#   {'driverId': 'liuzzi',
#    'code': 'LIU',
#    'url': 'http://en.wikipedia.org/wiki/Vitantonio_Liuzzi',
#    'givenName': 'Vitantonio',
#    'familyName': 'Liuzzi',
#    'dateOfBirth': '1980-08-06',
#    'nationality': 'Italian'},
#   {'driverId': 'massa',
#    'permanentNumber': '19',
#    'code': 'MAS',
#    'url': 'http://en.wikipedia.org/wiki/Felipe_Massa',
#    'givenName': 'Felipe',
#    'familyName': 'Massa',
#    'dateOfBirth': '1981-04-25',
#    'nationality': 'Brazilian'},
#   {'driverId': 'nakajima',
#    'code': 'NAK',
#    'url': 'http://en.wikipedia.org/wiki/Kazuki_Nakajima',
#    'givenName': 'Kazuki',
#    'familyName': 'Nakajima',
#    'dateOfBirth': '1985-01-11',
#    'nationality': 'Japanese'},
#   {'driverId': 'raikkonen',
#    'permanentNumber': '7',
#    'code': 'RAI',
#    'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#    'givenName': 'Kimi',
#    'familyName': 'Räikkönen',
#    'dateOfBirth': '1979-10-17',
#    'nationality': 'Finnish'},
#   {'driverId': 'rosberg',
#    'permanentNumber': '6',
#    'code': 'ROS',
#    'url': 'http://en.wikipedia.org/wiki/Nico_Rosberg',
#    'givenName': 'Nico',
#    'familyName': 'Rosberg',
#    'dateOfBirth': '1985-06-27',
#    'nationality': 'German'},
#   {'driverId': 'sato',
#    'code': 'SAT',
#    'url': 'http://en.wikipedia.org/wiki/Takuma_Sato',
#    'givenName': 'Takuma',
#    'familyName': 'Sato',
#    'dateOfBirth': '1977-01-28',
#    'nationality': 'Japanese'},
#   {'driverId': 'ralf_schumacher',
#    'code': 'SCH',
#    'url': 'http://en.wikipedia.org/wiki/Ralf_Schumacher',
#    'givenName': 'Ralf',
#    'familyName': 'Schumacher',
#    'dateOfBirth': '1975-06-30',
#    'nationality': 'German'},
#   {'driverId': 'speed',
#    'code': 'SPE',
#    'url': 'http://en.wikipedia.org/wiki/Scott_Speed',
#    'givenName': 'Scott',
#    'familyName': 'Speed',
#    'dateOfBirth': '1983-01-24',
#    'nationality': 'American'},
#   {'driverId': 'sutil',
#    'permanentNumber': '99',
#    'code': 'SUT',
#    'url': 'http://en.wikipedia.org/wiki/Adrian_Sutil',
#    'givenName': 'Adrian',
#    'familyName': 'Sutil',
#    'dateOfBirth': '1983-01-11',
#    'nationality': 'German'},
#   {'driverId': 'trulli',
#    'code': 'TRU',
#    'url': 'http://en.wikipedia.org/wiki/Jarno_Trulli',
#    'givenName': 'Jarno',
#    'familyName': 'Trulli',
#    'dateOfBirth': '1974-07-13',
#    'nationality': 'Italian'},
#   {'driverId': 'vettel',
#    'permanentNumber': '5',
#    'code': 'VET',
#    'url': 'http://en.wikipedia.org/wiki/Sebastian_Vettel',
#    'givenName': 'Sebastian',
#    'familyName': 'Vettel',
#    'dateOfBirth': '1987-07-03',
#    'nationality': 'German'},
#   {'driverId': 'webber',
#    'code': 'WEB',
#    'url': 'http://en.wikipedia.org/wiki/Mark_Webber',
#    'givenName': 'Mark',
#    'familyName': 'Webber',
#    'dateOfBirth': '1976-08-27',
#    'nationality': 'Australian'},
#   {'driverId': 'markus_winkelhock',
#    'code': 'WIN',
#    'url': 'http://en.wikipedia.org/wiki/Markus_Winkelhock',
#    'givenName': 'Markus',
#    'familyName': 'Winkelhock',
#    'dateOfBirth': '1980-06-13',
#    'nationality': 'German'},
#   {'driverId': 'wurz',
#    'code': 'WUR',
#    'url': 'http://en.wikipedia.org/wiki/Alexander_Wurz',
#    'givenName': 'Alexander',
#    'familyName': 'Wurz',
#    'dateOfBirth': '1974-02-15',
#    'nationality': 'Austrian'},
#   {'driverId': 'yamamoto',
#    'code': 'YAM',
#    'url': 'http://en.wikipedia.org/wiki/Sakon_Yamamoto',
#    'givenName': 'Sakon',
#    'familyName': 'Yamamoto',
#    'dateOfBirth': '1982-07-09',
#    'nationality': 'Japanese'}]}

# %%
def drivers_info():
    drivers_req = requests.get(site+ drivers +json).json()['MRData']['DriverTable']['Drivers']
    drivers_info = {} 
    for driver in drivers_req:
        drivers_info[driver['driverId']] = driver
    return drivers_info
drivers_info = drivers_info()
drivers_info
# Out:
# {'abate': {'driverId': 'abate',
#   'url': 'http://en.wikipedia.org/wiki/Carlo_Mario_Abate',
#   'givenName': 'Carlo',
#   'familyName': 'Abate',
#   'dateOfBirth': '1932-07-10',
#   'nationality': 'Italian'},
#  'abecassis': {'driverId': 'abecassis',
#   'url': 'http://en.wikipedia.org/wiki/George_Abecassis',
#   'givenName': 'George',
#   'familyName': 'Abecassis',
#   'dateOfBirth': '1913-03-21',
#   'nationality': 'British'},
#  'acheson': {'driverId': 'acheson',
#   'url': 'http://en.wikipedia.org/wiki/Kenny_Acheson',
#   'givenName': 'Kenny',
#   'familyName': 'Acheson',
#   'dateOfBirth': '1957-11-27',
#   'nationality': 'British'},
#  'adams': {'driverId': 'adams',
#   'url': 'http://en.wikipedia.org/wiki/Philippe_Adams',
#   'givenName': 'Philippe',
#   'familyName': 'Adams',
#   'dateOfBirth': '1969-11-19',
#   'nationality': 'Belgian'},
#  'ader': {'driverId': 'ader',
#   'url': 'http://en.wikipedia.org/wiki/Walt_Ader',
#   'givenName': 'Walt',
#   'familyName': 'Ader',
#   'dateOfBirth': '1913-12-15',
#   'nationality': 'American'},
#  'adolff': {'driverId': 'adolff',
#   'url': 'http://en.wikipedia.org/wiki/Kurt_Adolff',
#   'givenName': 'Kurt',
#   'familyName': 'Adolff',
#   'dateOfBirth': '1921-11-05',
#   'nationality': 'German'},
#  'agabashian': {'driverId': 'agabashian',
#   'url': 'http://en.wikipedia.org/wiki/Fred_Agabashian',
#   'givenName': 'Fred',
#   'familyName': 'Agabashian',
#   'dateOfBirth': '1913-08-21',
#   'nationality': 'American'},
#  'ahrens': {'driverId': 'ahrens',
#   'url': 'http://en.wikipedia.org/wiki/Kurt_Ahrens,_Jr.',
#   'givenName': 'Kurt',
#   'familyName': 'Ahrens',
#   'dateOfBirth': '1940-04-19',
#   'nationality': 'German'},
#  'albers': {'driverId': 'albers',
#   'code': 'ALB',
#   'url': 'http://en.wikipedia.org/wiki/Christijan_Albers',
#   'givenName': 'Christijan',
#   'familyName': 'Albers',
#   'dateOfBirth': '1979-04-16',
#   'nationality': 'Dutch'},
#  'albon': {'driverId': 'albon',
#   'permanentNumber': '23',
#   'code': 'ALB',
#   'url': 'http://en.wikipedia.org/wiki/Alexander_Albon',
#   'givenName': 'Alexander',
#   'familyName': 'Albon',
#   'dateOfBirth': '1996-03-23',
#   'nationality': 'Thai'},
#  'alboreto': {'driverId': 'alboreto',
#   'url': 'http://en.wikipedia.org/wiki/Michele_Alboreto',
#   'givenName': 'Michele',
#   'familyName': 'Alboreto',
#   'dateOfBirth': '1956-12-23',
#   'nationality': 'Italian'},
#  'alesi': {'driverId': 'alesi',
#   'url': 'http://en.wikipedia.org/wiki/Jean_Alesi',
#   'givenName': 'Jean',
#   'familyName': 'Alesi',
#   'dateOfBirth': '1964-06-11',
#   'nationality': 'French'},
#  'alguersuari': {'driverId': 'alguersuari',
#   'code': 'ALG',
#   'url': 'http://en.wikipedia.org/wiki/Jaime_Alguersuari',
#   'givenName': 'Jaime',
#   'familyName': 'Alguersuari',
#   'dateOfBirth': '1990-03-23',
#   'nationality': 'Spanish'},
#  'alliot': {'driverId': 'alliot',
#   'url': 'http://en.wikipedia.org/wiki/Philippe_Alliot',
#   'givenName': 'Philippe',
#   'familyName': 'Alliot',
#   'dateOfBirth': '1954-07-27',
#   'nationality': 'French'},
#  'allison': {'driverId': 'allison',
#   'url': 'http://en.wikipedia.org/wiki/Cliff_Allison',
#   'givenName': 'Cliff',
#   'familyName': 'Allison',
#   'dateOfBirth': '1932-02-08',
#   'nationality': 'British'},
#  'alonso': {'driverId': 'alonso',
#   'permanentNumber': '14',
#   'code': 'ALO',
#   'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#   'givenName': 'Fernando',
#   'familyName': 'Alonso',
#   'dateOfBirth': '1981-07-29',
#   'nationality': 'Spanish'},
#  'amati': {'driverId': 'amati',
#   'url': 'http://en.wikipedia.org/wiki/Giovanna_Amati',
#   'givenName': 'Giovanna',
#   'familyName': 'Amati',
#   'dateOfBirth': '1959-07-20',
#   'nationality': 'Italian'},
#  'amick': {'driverId': 'amick',
#   'url': 'http://en.wikipedia.org/wiki/Red_Amick',
#   'givenName': 'Red',
#   'familyName': 'Amick',
#   'dateOfBirth': '1929-01-19',
#   'nationality': 'American'},
#  'george_amick': {'driverId': 'george_amick',
#   'url': 'http://en.wikipedia.org/wiki/George_Amick',
#   'givenName': 'George',
#   'familyName': 'Amick',
#   'dateOfBirth': '1924-10-24',
#   'nationality': 'American'},
#  'amon': {'driverId': 'amon',
#   'url': 'http://en.wikipedia.org/wiki/Chris_Amon',
#   'givenName': 'Chris',
#   'familyName': 'Amon',
#   'dateOfBirth': '1943-07-20',
#   'nationality': 'New Zealander'},
#  'anderson': {'driverId': 'anderson',
#   'url': 'http://en.wikipedia.org/wiki/Bob_Anderson_(racing_driver)',
#   'givenName': 'Bob',
#   'familyName': 'Anderson',
#   'dateOfBirth': '1931-05-19',
#   'nationality': 'British'},
#  'andersson': {'driverId': 'andersson',
#   'url': 'http://en.wikipedia.org/wiki/Conny_Andersson_(racing_driver)',
#   'givenName': 'Conny',
#   'familyName': 'Andersson',
#   'dateOfBirth': '1939-12-28',
#   'nationality': 'Swedish'},
#  'andretti': {'driverId': 'andretti',
#   'url': 'http://en.wikipedia.org/wiki/Michael_Andretti',
#   'givenName': 'Michael',
#   'familyName': 'Andretti',
#   'dateOfBirth': '1962-10-05',
#   'nationality': 'American'},
#  'mario_andretti': {'driverId': 'mario_andretti',
#   'url': 'http://en.wikipedia.org/wiki/Mario_Andretti',
#   'givenName': 'Mario',
#   'familyName': 'Andretti',
#   'dateOfBirth': '1940-02-28',
#   'nationality': 'American'},
#  'andrews': {'driverId': 'andrews',
#   'url': 'http://en.wikipedia.org/wiki/Keith_Andrews_(driver)',
#   'givenName': 'Keith',
#   'familyName': 'Andrews',
#   'dateOfBirth': '1920-06-15',
#   'nationality': 'American'},
#  'apicella': {'driverId': 'apicella',
#   'url': 'http://en.wikipedia.org/wiki/Marco_Apicella',
#   'givenName': 'Marco',
#   'familyName': 'Apicella',
#   'dateOfBirth': '1965-10-07',
#   'nationality': 'Italian'},
#  'armi': {'driverId': 'armi',
#   'url': 'http://en.wikipedia.org/wiki/Frank_Armi',
#   'givenName': 'Frank',
#   'familyName': 'Armi',
#   'dateOfBirth': '1918-10-12',
#   'nationality': 'American'},
#  'arnold': {'driverId': 'arnold',
#   'url': 'http://en.wikipedia.org/wiki/Chuck_Arnold',
#   'givenName': 'Chuck',
#   'familyName': 'Arnold',
#   'dateOfBirth': '1926-05-30',
#   'nationality': 'American'},
#  'arnoux': {'driverId': 'arnoux',
#   'url': 'http://en.wikipedia.org/wiki/Ren%C3%A9_Arnoux',
#   'givenName': 'René',
#   'familyName': 'Arnoux',
#   'dateOfBirth': '1948-07-04',
#   'nationality': 'French'},
#  'arundell': {'driverId': 'arundell',
#   'url': 'http://en.wikipedia.org/wiki/Peter_Arundell',
#   'givenName': 'Peter',
#   'familyName': 'Arundell',
#   'dateOfBirth': '1933-11-08',
#   'nationality': 'British'},
#  'ascari': {'driverId': 'ascari',
#   'url': 'http://en.wikipedia.org/wiki/Alberto_Ascari',
#   'givenName': 'Alberto',
#   'familyName': 'Ascari',
#   'dateOfBirth': '1918-07-13',
#   'nationality': 'Italian'},
#  'ashdown': {'driverId': 'ashdown',
#   'url': 'http://en.wikipedia.org/wiki/Peter_Ashdown',
#   'givenName': 'Peter',
#   'familyName': 'Ashdown',
#   'dateOfBirth': '1934-10-16',
#   'nationality': 'British'},
#  'ashley': {'driverId': 'ashley',
#   'url': 'http://en.wikipedia.org/wiki/Ian_Ashley',
#   'givenName': 'Ian',
#   'familyName': 'Ashley',
#   'dateOfBirth': '1947-10-26',
#   'nationality': 'British'},
#  'ashmore': {'driverId': 'ashmore',
#   'url': 'http://en.wikipedia.org/wiki/Gerry_Ashmore',
#   'givenName': 'Gerry',
#   'familyName': 'Ashmore',
#   'dateOfBirth': '1936-07-25',
#   'nationality': 'British'},
#  'aston': {'driverId': 'aston',
#   'url': 'http://en.wikipedia.org/wiki/Bill_Aston',
#   'givenName': 'Bill',
#   'familyName': 'Aston',
#   'dateOfBirth': '1900-03-29',
#   'nationality': 'British'},
#  'attwood': {'driverId': 'attwood',
#   'url': 'http://en.wikipedia.org/wiki/Richard_Attwood',
#   'givenName': 'Richard',
#   'familyName': 'Attwood',
#   'dateOfBirth': '1940-04-04',
#   'nationality': 'British'},
#  'ayulo': {'driverId': 'ayulo',
#   'url': 'http://en.wikipedia.org/wiki/Manny_Ayulo',
#   'givenName': 'Manny',
#   'familyName': 'Ayulo',
#   'dateOfBirth': '1921-10-20',
#   'nationality': 'American'},
#  'badoer': {'driverId': 'badoer',
#   'code': 'BAD',
#   'url': 'http://en.wikipedia.org/wiki/Luca_Badoer',
#   'givenName': 'Luca',
#   'familyName': 'Badoer',
#   'dateOfBirth': '1971-01-25',
#   'nationality': 'Italian'},
#  'baghetti': {'driverId': 'baghetti',
#   'url': 'http://en.wikipedia.org/wiki/Giancarlo_Baghetti',
#   'givenName': 'Giancarlo',
#   'familyName': 'Baghetti',
#   'dateOfBirth': '1934-12-25',
#   'nationality': 'Italian'},
#  'bailey': {'driverId': 'bailey',
#   'url': 'http://en.wikipedia.org/wiki/Julian_Bailey',
#   'givenName': 'Julian',
#   'familyName': 'Bailey',
#   'dateOfBirth': '1961-10-09',
#   'nationality': 'British'},
#  'baldi': {'driverId': 'baldi',
#   'url': 'http://en.wikipedia.org/wiki/Mauro_Baldi',
#   'givenName': 'Mauro',
#   'familyName': 'Baldi',
#   'dateOfBirth': '1954-01-31',
#   'nationality': 'Italian'},
#  'ball': {'driverId': 'ball',
#   'url': 'http://en.wikipedia.org/wiki/Bobby_Ball_(auto_racer)',
#   'givenName': 'Bobby',
#   'familyName': 'Ball',
#   'dateOfBirth': '1925-08-26',
#   'nationality': 'American'},
#  'balsa': {'driverId': 'balsa',
#   'url': 'http://en.wikipedia.org/wiki/Marcel_Balsa',
#   'givenName': 'Marcel',
#   'familyName': 'Balsa',
#   'dateOfBirth': '1909-01-01',
#   'nationality': 'French'},
#  'bandini': {'driverId': 'bandini',
#   'url': 'http://en.wikipedia.org/wiki/Lorenzo_Bandini',
#   'givenName': 'Lorenzo',
#   'familyName': 'Bandini',
#   'dateOfBirth': '1935-12-21',
#   'nationality': 'Italian'},
#  'banks': {'driverId': 'banks',
#   'url': 'http://en.wikipedia.org/wiki/Henry_Banks',
#   'givenName': 'Henry',
#   'familyName': 'Banks',
#   'dateOfBirth': '1913-06-14',
#   'nationality': 'American'},
#  'barbazza': {'driverId': 'barbazza',
#   'url': 'http://en.wikipedia.org/wiki/Fabrizio_Barbazza',
#   'givenName': 'Fabrizio',
#   'familyName': 'Barbazza',
#   'dateOfBirth': '1963-04-02',
#   'nationality': 'Italian'},
#  'barber': {'driverId': 'barber',
#   'url': 'http://en.wikipedia.org/wiki/Skip_Barber',
#   'givenName': 'Skip',
#   'familyName': 'Barber',
#   'dateOfBirth': '1936-11-16',
#   'nationality': 'American'},
#  'john_barber': {'driverId': 'john_barber',
#   'url': 'http://en.wikipedia.org/wiki/John_Barber_(racing_driver)',
#   'givenName': 'John',
#   'familyName': 'Barber',
#   'dateOfBirth': '1929-07-22',
#   'nationality': 'British'},
#  'barilla': {'driverId': 'barilla',
#   'url': 'http://en.wikipedia.org/wiki/Paolo_Barilla',
#   'givenName': 'Paolo',
#   'familyName': 'Barilla',
#   'dateOfBirth': '1961-04-20',
#   'nationality': 'Italian'},
#  'barrichello': {'driverId': 'barrichello',
#   'code': 'BAR',
#   'url': 'http://en.wikipedia.org/wiki/Rubens_Barrichello',
#   'givenName': 'Rubens',
#   'familyName': 'Barrichello',
#   'dateOfBirth': '1972-05-23',
#   'nationality': 'Brazilian'},
#  'bartels': {'driverId': 'bartels',
#   'url': 'http://en.wikipedia.org/wiki/Michael_Bartels',
#   'givenName': 'Michael',
#   'familyName': 'Bartels',
#   'dateOfBirth': '1968-03-08',
#   'nationality': 'German'},
#  'barth': {'driverId': 'barth',
#   'url': 'http://en.wikipedia.org/wiki/Edgar_Barth',
#   'givenName': 'Edgar',
#   'familyName': 'Barth',
#   'dateOfBirth': '1917-01-26',
#   'nationality': 'German'},
#  'bassi': {'driverId': 'bassi',
#   'url': 'http://en.wikipedia.org/wiki/Giorgio_Bassi',
#   'givenName': 'Giorgio',
#   'familyName': 'Bassi',
#   'dateOfBirth': '1934-01-20',
#   'nationality': 'Italian'},
#  'bauer': {'driverId': 'bauer',
#   'url': 'http://en.wikipedia.org/wiki/Erwin_Bauer',
#   'givenName': 'Erwin',
#   'familyName': 'Bauer',
#   'dateOfBirth': '1912-07-17',
#   'nationality': 'German'},
#  'baumgartner': {'driverId': 'baumgartner',
#   'url': 'http://en.wikipedia.org/wiki/Zsolt_Baumgartner',
#   'givenName': 'Zsolt',
#   'familyName': 'Baumgartner',
#   'dateOfBirth': '1981-01-01',
#   'nationality': 'Hungarian'},
#  'bayol': {'driverId': 'bayol',
#   'url': 'http://en.wikipedia.org/wiki/%C3%89lie_Bayol',
#   'givenName': 'Élie',
#   'familyName': 'Bayol',
#   'dateOfBirth': '1914-02-28',
#   'nationality': 'French'},
#  'beauman': {'driverId': 'beauman',
#   'url': 'http://en.wikipedia.org/wiki/Don_Beauman',
#   'givenName': 'Don',
#   'familyName': 'Beauman',
#   'dateOfBirth': '1928-07-26',
#   'nationality': 'British'},
#  'bechem': {'driverId': 'bechem',
#   'url': 'http://en.wikipedia.org/wiki/G%C3%BCnther_Bechem',
#   'givenName': 'Günther',
#   'familyName': 'Bechem',
#   'dateOfBirth': '1921-12-21',
#   'nationality': 'German'},
#  'behra': {'driverId': 'behra',
#   'url': 'http://en.wikipedia.org/wiki/Jean_Behra',
#   'givenName': 'Jean',
#   'familyName': 'Behra',
#   'dateOfBirth': '1921-02-16',
#   'nationality': 'French'},
#  'bell': {'driverId': 'bell',
#   'url': 'http://en.wikipedia.org/wiki/Derek_Bell_(auto_racer)',
#   'givenName': 'Derek',
#   'familyName': 'Bell',
#   'dateOfBirth': '1941-10-31',
#   'nationality': 'British'},
#  'bellof': {'driverId': 'bellof',
#   'url': 'http://en.wikipedia.org/wiki/Stefan_Bellof',
#   'givenName': 'Stefan',
#   'familyName': 'Bellof',
#   'dateOfBirth': '1957-11-20',
#   'nationality': 'German'},
#  'belmondo': {'driverId': 'belmondo',
#   'url': 'http://en.wikipedia.org/wiki/Paul_Belmondo',
#   'givenName': 'Paul',
#   'familyName': 'Belmondo',
#   'dateOfBirth': '1963-04-23',
#   'nationality': 'French'},
#  'belso': {'driverId': 'belso',
#   'url': 'http://en.wikipedia.org/wiki/Tom_Bels%C3%B8',
#   'givenName': 'Tom',
#   'familyName': 'Belsø',
#   'dateOfBirth': '1942-08-27',
#   'nationality': 'Danish'},
#  'beltoise': {'driverId': 'beltoise',
#   'url': 'http://en.wikipedia.org/wiki/Jean-Pierre_Beltoise',
#   'givenName': 'Jean-Pierre',
#   'familyName': 'Beltoise',
#   'dateOfBirth': '1937-04-26',
#   'nationality': 'French'},
#  'beretta': {'driverId': 'beretta',
#   'url': 'http://en.wikipedia.org/wiki/Olivier_Beretta',
#   'givenName': 'Olivier',
#   'familyName': 'Beretta',
#   'dateOfBirth': '1969-11-23',
#   'nationality': 'Monegasque'},
#  'berg': {'driverId': 'berg',
#   'url': 'http://en.wikipedia.org/wiki/Allen_Berg',
#   'givenName': 'Allen',
#   'familyName': 'Berg',
#   'dateOfBirth': '1961-08-01',
#   'nationality': 'Canadian'},
#  'berger': {'driverId': 'berger',
#   'url': 'http://en.wikipedia.org/wiki/Gerhard_Berger',
#   'givenName': 'Gerhard',
#   'familyName': 'Berger',
#   'dateOfBirth': '1959-08-27',
#   'nationality': 'Austrian'},
#  'georges_berger': {'driverId': 'georges_berger',
#   'url': 'http://en.wikipedia.org/wiki/Georges_Berger',
#   'givenName': 'Georges',
#   'familyName': 'Berger',
#   'dateOfBirth': '1918-09-14',
#   'nationality': 'Belgian'},
#  'bernard': {'driverId': 'bernard',
#   'url': 'http://en.wikipedia.org/wiki/%C3%89ric_Bernard',
#   'givenName': 'Éric',
#   'familyName': 'Bernard',
#   'dateOfBirth': '1964-08-24',
#   'nationality': 'French'},
#  'bernoldi': {'driverId': 'bernoldi',
#   'url': 'http://en.wikipedia.org/wiki/Enrique_Bernoldi',
#   'givenName': 'Enrique',
#   'familyName': 'Bernoldi',
#   'dateOfBirth': '1978-10-19',
#   'nationality': 'Brazilian'},
#  'bertaggia': {'driverId': 'bertaggia',
#   'url': 'http://en.wikipedia.org/wiki/Enrico_Bertaggia',
#   'givenName': 'Enrico',
#   'familyName': 'Bertaggia',
#   'dateOfBirth': '1964-09-19',
#   'nationality': 'Italian'},
#  'bettenhausen': {'driverId': 'bettenhausen',
#   'url': 'http://en.wikipedia.org/wiki/Tony_Bettenhausen',
#   'givenName': 'Tony',
#   'familyName': 'Bettenhausen',
#   'dateOfBirth': '1916-09-12',
#   'nationality': 'American'},
#  'beuttler': {'driverId': 'beuttler',
#   'url': 'http://en.wikipedia.org/wiki/Mike_Beuttler',
#   'givenName': 'Mike',
#   'familyName': 'Beuttler',
#   'dateOfBirth': '1940-04-13',
#   'nationality': 'British'},
#  'bianchi': {'driverId': 'bianchi',
#   'code': 'BIA',
#   'url': 'http://en.wikipedia.org/wiki/Lucien_Bianchi',
#   'givenName': 'Lucien',
#   'familyName': 'Bianchi',
#   'dateOfBirth': '1934-11-10',
#   'nationality': 'Belgian'},
#  'jules_bianchi': {'driverId': 'jules_bianchi',
#   'permanentNumber': '17',
#   'code': 'BIA',
#   'url': 'http://en.wikipedia.org/wiki/Jules_Bianchi',
#   'givenName': 'Jules',
#   'familyName': 'Bianchi',
#   'dateOfBirth': '1989-08-03',
#   'nationality': 'French'},
#  'bianco': {'driverId': 'bianco',
#   'url': 'http://en.wikipedia.org/wiki/Gino_Bianco',
#   'givenName': 'Gino',
#   'familyName': 'Bianco',
#   'dateOfBirth': '1916-07-22',
#   'nationality': 'Brazilian'},
#  'binder': {'driverId': 'binder',
#   'url': 'http://en.wikipedia.org/wiki/Hans_Binder',
#   'givenName': 'Hans',
#   'familyName': 'Binder',
#   'dateOfBirth': '1948-06-12',
#   'nationality': 'Austrian'},
#  'biondetti': {'driverId': 'biondetti',
#   'url': 'http://en.wikipedia.org/wiki/Clemente_Biondetti',
#   'givenName': 'Clemente',
#   'familyName': 'Biondetti',
#   'dateOfBirth': '1898-08-18',
#   'nationality': 'Italian'},
#  'bira': {'driverId': 'bira',
#   'url': 'http://en.wikipedia.org/wiki/Prince_Bira',
#   'givenName': 'Prince',
#   'familyName': 'Bira',
#   'dateOfBirth': '1914-07-15',
#   'nationality': 'Thai'},
#  'birger': {'driverId': 'birger',
#   'url': 'http://en.wikipedia.org/wiki/Pablo_Birger',
#   'givenName': 'Pablo',
#   'familyName': 'Birger',
#   'dateOfBirth': '1924-01-07',
#   'nationality': 'Argentine'},
#  'bisch': {'driverId': 'bisch',
#   'url': 'http://en.wikipedia.org/wiki/Art_Bisch',
#   'givenName': 'Art',
#   'familyName': 'Bisch',
#   'dateOfBirth': '1926-11-10',
#   'nationality': 'American'},
#  'blanchard': {'driverId': 'blanchard',
#   'url': 'http://en.wikipedia.org/wiki/Harry_Blanchard',
#   'givenName': 'Harry',
#   'familyName': 'Blanchard',
#   'dateOfBirth': '1929-06-13',
#   'nationality': 'American'},
#  'bleekemolen': {'driverId': 'bleekemolen',
#   'url': 'http://en.wikipedia.org/wiki/Michael_Bleekemolen',
#   'givenName': 'Michael',
#   'familyName': 'Bleekemolen',
#   'dateOfBirth': '1949-10-02',
#   'nationality': 'Dutch'},
#  'blignaut': {'driverId': 'blignaut',
#   'url': 'http://en.wikipedia.org/wiki/Alex_Blignaut',
#   'givenName': 'Alex',
#   'familyName': 'Blignaut',
#   'dateOfBirth': '1932-11-30',
#   'nationality': 'South African'},
#  'blokdyk': {'driverId': 'blokdyk',
#   'url': 'http://en.wikipedia.org/wiki/Trevor_Blokdyk',
#   'givenName': 'Trevor',
#   'familyName': 'Blokdyk',
#   'dateOfBirth': '1935-11-30',
#   'nationality': 'South African'},
#  'blundell': {'driverId': 'blundell',
#   'url': 'http://en.wikipedia.org/wiki/Mark_Blundell',
#   'givenName': 'Mark',
#   'familyName': 'Blundell',
#   'dateOfBirth': '1966-04-08',
#   'nationality': 'British'},
#  'boesel': {'driverId': 'boesel',
#   'url': 'http://en.wikipedia.org/wiki/Raul_Boesel',
#   'givenName': 'Raul',
#   'familyName': 'Boesel',
#   'dateOfBirth': '1957-12-04',
#   'nationality': 'Brazilian'},
#  'boffa': {'driverId': 'boffa',
#   'url': 'http://en.wikipedia.org/wiki/Menato_Boffa',
#   'givenName': 'Menato',
#   'familyName': 'Boffa',
#   'dateOfBirth': '1930-01-04',
#   'nationality': 'Italian'},
#  'bondurant': {'driverId': 'bondurant',
#   'url': 'http://en.wikipedia.org/wiki/Bob_Bondurant',
#   'givenName': 'Bob',
#   'familyName': 'Bondurant',
#   'dateOfBirth': '1933-04-27',
#   'nationality': 'American'},
#  'bonetto': {'driverId': 'bonetto',
#   'url': 'http://en.wikipedia.org/wiki/Felice_Bonetto',
#   'givenName': 'Felice',
#   'familyName': 'Bonetto',
#   'dateOfBirth': '1903-06-09',
#   'nationality': 'Italian'},
#  'bonnier': {'driverId': 'bonnier',
#   'url': 'http://en.wikipedia.org/wiki/Joakim_Bonnier',
#   'givenName': 'Jo',
#   'familyName': 'Bonnier',
#   'dateOfBirth': '1930-01-31',
#   'nationality': 'Swedish'},
#  'bonomi': {'driverId': 'bonomi',
#   'url': 'http://en.wikipedia.org/wiki/Roberto_Bonomi',
#   'givenName': 'Roberto',
#   'familyName': 'Bonomi',
#   'dateOfBirth': '1919-09-30',
#   'nationality': 'Argentine'},
#  'bordeu': {'driverId': 'bordeu',
#   'url': 'http://en.wikipedia.org/wiki/Juan_Manuel_Bordeu',
#   'givenName': 'Juan Manuel',
#   'familyName': 'Bordeu',
#   'dateOfBirth': '1934-01-28',
#   'nationality': 'Argentine'},
#  'borgudd': {'driverId': 'borgudd',
#   'url': 'http://en.wikipedia.org/wiki/Slim_Borgudd',
#   'givenName': 'Slim',
#   'familyName': 'Borgudd',
#   'dateOfBirth': '1946-11-25',
#   'nationality': 'Swedish'},
#  'botha': {'driverId': 'botha',
#   'url': 'http://en.wikipedia.org/wiki/Luki_Botha',
#   'givenName': 'Luki',
#   'familyName': 'Botha',
#   'dateOfBirth': '1930-01-16',
#   'nationality': 'South African'},
#  'bottas': {'driverId': 'bottas',
#   'permanentNumber': '77',
#   'code': 'BOT',
#   'url': 'http://en.wikipedia.org/wiki/Valtteri_Bottas',
#   'givenName': 'Valtteri',
#   'familyName': 'Bottas',
#   'dateOfBirth': '1989-08-28',
#   'nationality': 'Finnish'},
#  'boullion': {'driverId': 'boullion',
#   'url': 'http://en.wikipedia.org/wiki/Jean-Christophe_Boullion',
#   'givenName': 'Jean-Christophe',
#   'familyName': 'Boullion',
#   'dateOfBirth': '1969-12-27',
#   'nationality': 'French'},
#  'bourdais': {'driverId': 'bourdais',
#   'code': 'BOU',
#   'url': 'http://en.wikipedia.org/wiki/S%C3%A9bastien_Bourdais',
#   'givenName': 'Sébastien',
#   'familyName': 'Bourdais',
#   'dateOfBirth': '1979-02-28',
#   'nationality': 'French'},
#  'boutsen': {'driverId': 'boutsen',
#   'url': 'http://en.wikipedia.org/wiki/Thierry_Boutsen',
#   'givenName': 'Thierry',
#   'familyName': 'Boutsen',
#   'dateOfBirth': '1957-07-13',
#   'nationality': 'Belgian'},
#  'boyd': {'driverId': 'boyd',
#   'url': 'http://en.wikipedia.org/wiki/Johnny_Boyd',
#   'givenName': 'Johnny',
#   'familyName': 'Boyd',
#   'dateOfBirth': '1926-08-19',
#   'nationality': 'American'},
#  'brabham': {'driverId': 'brabham',
#   'url': 'http://en.wikipedia.org/wiki/David_Brabham',
#   'givenName': 'David',
#   'familyName': 'Brabham',
#   'dateOfBirth': '1965-09-05',
#   'nationality': 'Australian'},
#  'gary_brabham': {'driverId': 'gary_brabham',
#   'url': 'http://en.wikipedia.org/wiki/Gary_Brabham',
#   'givenName': 'Gary',
#   'familyName': 'Brabham',
#   'dateOfBirth': '1961-03-29',
#   'nationality': 'Australian'},
#  'jack_brabham': {'driverId': 'jack_brabham',
#   'url': 'http://en.wikipedia.org/wiki/Jack_Brabham',
#   'givenName': 'Jack',
#   'familyName': 'Brabham',
#   'dateOfBirth': '1926-04-02',
#   'nationality': 'Australian'},
#  'brack': {'driverId': 'brack',
#   'url': 'http://en.wikipedia.org/wiki/Bill_Brack',
#   'givenName': 'Bill',
#   'familyName': 'Brack',
#   'dateOfBirth': '1935-12-26',
#   'nationality': 'Canadian'},
#  'brambilla': {'driverId': 'brambilla',
#   'url': 'http://en.wikipedia.org/wiki/Vittorio_Brambilla',
#   'givenName': 'Vittorio',
#   'familyName': 'Brambilla',
#   'dateOfBirth': '1937-11-11',
#   'nationality': 'Italian'},
#  'ernesto_brambilla': {'driverId': 'ernesto_brambilla',
#   'url': 'http://en.wikipedia.org/wiki/Ernesto_Brambilla',
#   'givenName': 'Ernesto',
#   'familyName': 'Brambilla',
#   'dateOfBirth': '1934-01-31',
#   'nationality': 'Italian'},
#  'branca': {'driverId': 'branca',
#   'url': 'http://en.wikipedia.org/wiki/Toni_Branca',
#   'givenName': 'Toni',
#   'familyName': 'Branca',
#   'dateOfBirth': '1916-09-15',
#   'nationality': 'Swiss'},
#  'brancatelli': {'driverId': 'brancatelli',
#   'url': 'http://en.wikipedia.org/wiki/Gianfranco_Brancatelli',
#   'givenName': 'Gianfranco',
#   'familyName': 'Brancatelli',
#   'dateOfBirth': '1950-01-18',
#   'nationality': 'Italian'},
#  'brandon': {'driverId': 'brandon',
#   'url': 'http://en.wikipedia.org/wiki/Eric_Brandon',
#   'givenName': 'Eric',
#   'familyName': 'Brandon',
#   'dateOfBirth': '1920-07-18',
#   'nationality': 'British'},
#  'branson': {'driverId': 'branson',
#   'url': 'http://en.wikipedia.org/wiki/Don_Branson',
#   'givenName': 'Don',
#   'familyName': 'Branson',
#   'dateOfBirth': '1920-06-02',
#   'nationality': 'American'},
#  'bridger': {'driverId': 'bridger',
#   'url': 'http://en.wikipedia.org/wiki/Tom_Bridger',
#   'givenName': 'Tom',
#   'familyName': 'Bridger',
#   'dateOfBirth': '1934-06-24',
#   'nationality': 'British'},
#  'brise': {'driverId': 'brise',
#   'url': 'http://en.wikipedia.org/wiki/Tony_Brise',
#   'givenName': 'Tony',
#   'familyName': 'Brise',
#   'dateOfBirth': '1952-03-28',
#   'nationality': 'British'},
#  'bristow': {'driverId': 'bristow',
#   'url': 'http://en.wikipedia.org/wiki/Chris_Bristow',
#   'givenName': 'Chris',
#   'familyName': 'Bristow',
#   'dateOfBirth': '1937-12-02',
#   'nationality': 'British'},
#  'broeker': {'driverId': 'broeker',
#   'url': 'http://en.wikipedia.org/wiki/Peter_Broeker',
#   'givenName': 'Peter',
#   'familyName': 'Broeker',
#   'dateOfBirth': '1926-05-15',
#   'nationality': 'Canadian'},
#  'brooks': {'driverId': 'brooks',
#   'url': 'http://en.wikipedia.org/wiki/Tony_Brooks',
#   'givenName': 'Tony',
#   'familyName': 'Brooks',
#   'dateOfBirth': '1932-02-25',
#   'nationality': 'British'},
#  'brown': {'driverId': 'brown',
#   'url': 'http://en.wikipedia.org/wiki/Warwick_Brown',
#   'givenName': 'Warwick',
#   'familyName': 'Brown',
#   'dateOfBirth': '1949-12-24',
#   'nationality': 'Australian'},
#  'alan_brown': {'driverId': 'alan_brown',
#   'url': 'http://en.wikipedia.org/wiki/Alan_Brown_(racing_driver)',
#   'givenName': 'Alan',
#   'familyName': 'Brown',
#   'dateOfBirth': '1919-11-20',
#   'nationality': 'British'},
#  'walt_brown': {'driverId': 'walt_brown',
#   'url': 'http://en.wikipedia.org/wiki/Walt_Brown_(auto_racer)',
#   'givenName': 'Walt',
#   'familyName': 'Brown',
#   'dateOfBirth': '1911-12-30',
#   'nationality': 'American'},
#  'brudes': {'driverId': 'brudes',
#   'url': 'http://en.wikipedia.org/wiki/Adolf_Brudes',
#   'givenName': 'Adolf',
#   'familyName': 'Brudes',
#   'dateOfBirth': '1899-10-15',
#   'nationality': 'German'},
#  'brundle': {'driverId': 'brundle',
#   'url': 'http://en.wikipedia.org/wiki/Martin_Brundle',
#   'givenName': 'Martin',
#   'familyName': 'Brundle',
#   'dateOfBirth': '1959-06-01',
#   'nationality': 'British'},
#  'bruni': {'driverId': 'bruni',
#   'url': 'http://en.wikipedia.org/wiki/Gianmaria_Bruni',
#   'givenName': 'Gianmaria',
#   'familyName': 'Bruni',
#   'dateOfBirth': '1981-05-30',
#   'nationality': 'Italian'},
#  'bryan': {'driverId': 'bryan',
#   'url': 'http://en.wikipedia.org/wiki/Jimmy_Bryan',
#   'givenName': 'Jimmy',
#   'familyName': 'Bryan',
#   'dateOfBirth': '1926-01-28',
#   'nationality': 'American'},
#  'bucci': {'driverId': 'bucci',
#   'url': 'http://en.wikipedia.org/wiki/Clemar_Bucci',
#   'givenName': 'Clemar',
#   'familyName': 'Bucci',
#   'dateOfBirth': '1920-09-04',
#   'nationality': 'Argentine'},
#  'bucknum': {'driverId': 'bucknum',
#   'url': 'http://en.wikipedia.org/wiki/Ronnie_Bucknum',
#   'givenName': 'Ronnie',
#   'familyName': 'Bucknum',
#   'dateOfBirth': '1936-04-05',
#   'nationality': 'American'},
#  'bueb': {'driverId': 'bueb',
#   'url': 'http://en.wikipedia.org/wiki/Ivor_Bueb',
#   'givenName': 'Ivor',
#   'familyName': 'Bueb',
#   'dateOfBirth': '1923-06-06',
#   'nationality': 'British'},
#  'buemi': {'driverId': 'buemi',
#   'code': 'BUE',
#   'url': 'http://en.wikipedia.org/wiki/S%C3%A9bastien_Buemi',
#   'givenName': 'Sébastien',
#   'familyName': 'Buemi',
#   'dateOfBirth': '1988-10-31',
#   'nationality': 'Swiss'},
#  'bueno': {'driverId': 'bueno',
#   'url': 'http://en.wikipedia.org/wiki/Luiz_Bueno',
#   'givenName': 'Luiz',
#   'familyName': 'Bueno',
#   'dateOfBirth': '1937-01-16',
#   'nationality': 'Brazilian'},
#  'burgess': {'driverId': 'burgess',
#   'url': 'http://en.wikipedia.org/wiki/Ian_Burgess',
#   'givenName': 'Ian',
#   'familyName': 'Burgess',
#   'dateOfBirth': '1930-07-06',
#   'nationality': 'British'},
#  'burti': {'driverId': 'burti',
#   'url': 'http://en.wikipedia.org/wiki/Luciano_Burti',
#   'givenName': 'Luciano',
#   'familyName': 'Burti',
#   'dateOfBirth': '1975-03-05',
#   'nationality': 'Brazilian'},
#  'bussinello': {'driverId': 'bussinello',
#   'url': 'http://en.wikipedia.org/wiki/Roberto_Bussinello',
#   'givenName': 'Roberto',
#   'familyName': 'Bussinello',
#   'dateOfBirth': '1927-10-04',
#   'nationality': 'Italian'},
#  'button': {'driverId': 'button',
#   'permanentNumber': '22',
#   'code': 'BUT',
#   'url': 'http://en.wikipedia.org/wiki/Jenson_Button',
#   'givenName': 'Jenson',
#   'familyName': 'Button',
#   'dateOfBirth': '1980-01-19',
#   'nationality': 'British'},
#  'byrne': {'driverId': 'byrne',
#   'url': 'http://en.wikipedia.org/wiki/Tommy_Byrne_%28racing_driver%29',
#   'givenName': 'Tommy',
#   'familyName': 'Byrne',
#   'dateOfBirth': '1958-05-06',
#   'nationality': 'Irish'},
#  'cabantous': {'driverId': 'cabantous',
#   'url': 'http://en.wikipedia.org/wiki/Yves_Giraud_Cabantous',
#   'givenName': 'Yves',
#   'familyName': 'Cabantous',
#   'dateOfBirth': '1904-10-08',
#   'nationality': 'French'},
#  'cabianca': {'driverId': 'cabianca',
#   'url': 'http://en.wikipedia.org/wiki/Giulio_Cabianca',
#   'givenName': 'Giulio',
#   'familyName': 'Cabianca',
#   'dateOfBirth': '1923-02-19',
#   'nationality': 'Italian'},
#  'cabral': {'driverId': 'cabral',
#   'url': 'http://en.wikipedia.org/wiki/Mario_de_Araujo_Cabral',
#   'givenName': 'Mário de Araújo',
#   'familyName': 'Cabral',
#   'dateOfBirth': '1934-01-15',
#   'nationality': 'Portuguese'},
#  'cade': {'driverId': 'cade',
#   'url': 'http://en.wikipedia.org/wiki/Phil_Cade',
#   'givenName': 'Phil',
#   'familyName': 'Cade',
#   'dateOfBirth': '1916-06-12',
#   'nationality': 'American'},
#  'caffi': {'driverId': 'caffi',
#   'url': 'http://en.wikipedia.org/wiki/Alex_Caffi',
#   'givenName': 'Alex',
#   'familyName': 'Caffi',
#   'dateOfBirth': '1964-03-18',
#   'nationality': 'Italian'},
#  'campbell-jones': {'driverId': 'campbell-jones',
#   'url': 'http://en.wikipedia.org/wiki/John_Campbell-Jones',
#   'givenName': 'John',
#   'familyName': 'Campbell-Jones',
#   'dateOfBirth': '1930-01-21',
#   'nationality': 'British'},
#  'campos': {'driverId': 'campos',
#   'url': 'http://en.wikipedia.org/wiki/Adri%C3%A1n_Campos',
#   'givenName': 'Adrián',
#   'familyName': 'Campos',
#   'dateOfBirth': '1960-06-17',
#   'nationality': 'Spanish'},
#  'Cannoc': {'driverId': 'Cannoc',
#   'url': 'http://en.wikipedia.org/wiki/John_Cannon_(auto_racer)',
#   'givenName': 'John',
#   'familyName': 'Cannon',
#   'dateOfBirth': '1933-06-21',
#   'nationality': 'Canadian'},
#  'cantoni': {'driverId': 'cantoni',
#   'url': 'http://en.wikipedia.org/wiki/Eitel_Cantoni',
#   'givenName': 'Eitel',
#   'familyName': 'Cantoni',
#   'dateOfBirth': '1906-10-04',
#   'nationality': 'Uruguayan'},
#  'cantrell': {'driverId': 'cantrell',
#   'url': 'http://en.wikipedia.org/wiki/William_Cantrell',
#   'givenName': 'Bill',
#   'familyName': 'Cantrell',
#   'dateOfBirth': '1908-01-31',
#   'nationality': 'American'},
#  'capelli': {'driverId': 'capelli',
#   'url': 'http://en.wikipedia.org/wiki/Ivan_Capelli',
#   'givenName': 'Ivan',
#   'familyName': 'Capelli',
#   'dateOfBirth': '1963-05-24',
#   'nationality': 'Italian'},
#  'carini': {'driverId': 'carini',
#   'url': 'http://en.wikipedia.org/wiki/Piero_Carini',
#   'givenName': 'Piero',
#   'familyName': 'Carini',
#   'dateOfBirth': '1921-03-06',
#   'nationality': 'Italian'},
#  'darter': {'driverId': 'darter',
#   'url': 'http://en.wikipedia.org/wiki/Duane_Carter',
#   'givenName': 'Duane',
#   'familyName': 'Carter',
#   'dateOfBirth': '1913-05-05',
#   'nationality': 'American'},
#  'castellotti': {'driverId': 'castellotti',
#   'url': 'http://en.wikipedia.org/wiki/Eugenio_Castellotti',
#   'givenName': 'Eugenio',
#   'familyName': 'Castellotti',
#   'dateOfBirth': '1930-10-10',
#   'nationality': 'Italian'},
#  'cecotto': {'driverId': 'cecotto',
#   'url': 'http://en.wikipedia.org/wiki/Johnny_Cecotto',
#   'givenName': 'Johnny',
#   'familyName': 'Cecotto',
#   'dateOfBirth': '1956-01-25',
#   'nationality': 'Venezuelan'},
#  'cevert': {'driverId': 'cevert',
#   'url': 'http://en.wikipedia.org/wiki/Fran%C3%A7ois_Cevert',
#   'givenName': 'François',
#   'familyName': 'Cevert',
#   'dateOfBirth': '1944-02-25',
#   'nationality': 'French'},
#  'chaboud': {'driverId': 'chaboud',
#   'url': 'http://en.wikipedia.org/wiki/Eug%C3%A8ne_Chaboud',
#   'givenName': 'Eugène',
#   'familyName': 'Chaboud',
#   'dateOfBirth': '1907-04-12',
#   'nationality': 'French'},
#  'chamberlain': {'driverId': 'chamberlain',
#   'url': 'http://en.wikipedia.org/wiki/Jay_Chamberlain',
#   'givenName': 'Jay',
#   'familyName': 'Chamberlain',
#   'dateOfBirth': '1925-12-29',
#   'nationality': 'American'},
#  'chandhok': {'driverId': 'chandhok',
#   'code': 'CHA',
#   'url': 'http://en.wikipedia.org/wiki/Karun_Chandhok',
#   'givenName': 'Karun',
#   'familyName': 'Chandhok',
#   'dateOfBirth': '1984-01-19',
#   'nationality': 'Indian'},
#  'chapman': {'driverId': 'chapman',
#   'url': 'http://en.wikipedia.org/wiki/Colin_Chapman',
#   'givenName': 'Colin',
#   'familyName': 'Chapman',
#   'dateOfBirth': '1928-05-19',
#   'nationality': 'British'},
#  'charlton': {'driverId': 'charlton',
#   'url': 'http://en.wikipedia.org/wiki/Dave_Charlton',
#   'givenName': 'Dave',
#   'familyName': 'Charlton',
#   'dateOfBirth': '1936-10-27',
#   'nationality': 'South African'},
#  'chaves': {'driverId': 'chaves',
#   'url': 'http://en.wikipedia.org/wiki/Pedro_Chaves',
#   'givenName': 'Pedro',
#   'familyName': 'Chaves',
#   'dateOfBirth': '1965-02-27',
#   'nationality': 'Portuguese'},
#  'cheesbourg': {'driverId': 'cheesbourg',
#   'url': 'http://en.wikipedia.org/wiki/Bill_Cheesbourg',
#   'givenName': 'Bill',
#   'familyName': 'Cheesbourg',
#   'dateOfBirth': '1927-06-12',
#   'nationality': 'American'},
#  'cheever': {'driverId': 'cheever',
#   'url': 'http://en.wikipedia.org/wiki/Eddie_Cheever',
#   'givenName': 'Eddie',
#   'familyName': 'Cheever',
#   'dateOfBirth': '1958-01-10',
#   'nationality': 'American'},
#  'chiesa': {'driverId': 'chiesa',
#   'url': 'http://en.wikipedia.org/wiki/Andrea_Chiesa',
#   'givenName': 'Andrea',
#   'familyName': 'Chiesa',
#   'dateOfBirth': '1964-05-06',
#   'nationality': 'Swiss'},
#  'chilton': {'driverId': 'chilton',
#   'permanentNumber': '4',
#   'code': 'CHI',
#   'url': 'http://en.wikipedia.org/wiki/Max_Chilton',
#   'givenName': 'Max',
#   'familyName': 'Chilton',
#   'dateOfBirth': '1991-04-21',
#   'nationality': 'British'},
#  'chimeri': {'driverId': 'chimeri',
#   'url': 'http://en.wikipedia.org/wiki/Ettore_Chimeri',
#   'givenName': 'Ettore',
#   'familyName': 'Chimeri',
#   'dateOfBirth': '1921-06-04',
#   'nationality': 'Venezuelan'},
#  'chiron': {'driverId': 'chiron',
#   'url': 'http://en.wikipedia.org/wiki/Louis_Chiron',
#   'givenName': 'Louis',
#   'familyName': 'Chiron',
#   'dateOfBirth': '1899-08-03',
#   'nationality': 'Monegasque'},
#  'chitwood': {'driverId': 'chitwood',
#   'url': 'http://en.wikipedia.org/wiki/Joie_Chitwood',
#   'givenName': 'Joie',
#   'familyName': 'Chitwood',
#   'dateOfBirth': '1912-04-14',
#   'nationality': 'American'},
#  'christie': {'driverId': 'christie',
#   'url': 'http://en.wikipedia.org/wiki/Bob_Christie_(racing_driver)',
#   'givenName': 'Bob',
#   'familyName': 'Christie',
#   'dateOfBirth': '1924-04-04',
#   'nationality': 'American'},
#  'claes': {'driverId': 'claes',
#   'url': 'http://en.wikipedia.org/wiki/Johnny_Claes',
#   'givenName': 'Johnny',
#   'familyName': 'Claes',
#   'dateOfBirth': '1916-08-11',
#   'nationality': 'Belgian'},
#  'clapham': {'driverId': 'clapham',
#   'url': 'http://en.wikipedia.org/wiki/David_Clapham',
#   'givenName': 'David',
#   'familyName': 'Clapham',
#   'dateOfBirth': '1931-05-18',
#   'nationality': 'South African'},
#  'clark': {'driverId': 'clark',
#   'url': 'http://en.wikipedia.org/wiki/Jim_Clark',
#   'givenName': 'Jim',
#   'familyName': 'Clark',
#   'dateOfBirth': '1936-03-04',
#   'nationality': 'British'},
#  'cogan': {'driverId': 'cogan',
#   'url': 'http://en.wikipedia.org/wiki/Kevin_Cogan',
#   'givenName': 'Kevin',
#   'familyName': 'Cogan',
#   'dateOfBirth': '1956-03-31',
#   'nationality': 'American'},
#  'collins': {'driverId': 'collins',
#   'url': 'http://en.wikipedia.org/wiki/Peter_Collins_(racing_driver)',
#   'givenName': 'Peter',
#   'familyName': 'Collins',
#   'dateOfBirth': '1931-11-06',
#   'nationality': 'British'},
#  'collomb': {'driverId': 'collomb',
#   'url': 'http://en.wikipedia.org/wiki/Bernard_Collomb',
#   'givenName': 'Bernard',
#   'familyName': 'Collomb',
#   'dateOfBirth': '1930-10-07',
#   'nationality': 'French'},
#  'colombo': {'driverId': 'colombo',
#   'url': 'http://en.wikipedia.org/wiki/Alberto_Colombo',
#   'givenName': 'Alberto',
#   'familyName': 'Colombo',
#   'dateOfBirth': '1946-02-23',
#   'nationality': 'Italian'},
#  'comas': {'driverId': 'comas',
#   'url': 'http://en.wikipedia.org/wiki/%C3%89rik_Comas',
#   'givenName': 'Érik',
#   'familyName': 'Comas',
#   'dateOfBirth': '1963-09-28',
#   'nationality': 'French'},
#  'comotti': {'driverId': 'comotti',
#   'url': 'http://en.wikipedia.org/wiki/Franco_Comotti',
#   'givenName': 'Franco',
#   'familyName': 'Comotti',
#   'dateOfBirth': '1906-07-24',
#   'nationality': 'Italian'},
#  'george_connor': {'driverId': 'george_connor',
#   'url': 'http://en.wikipedia.org/wiki/George_Connor_(driver)',
#   'givenName': 'George',
#   'familyName': 'Connor',
#   'dateOfBirth': '1906-08-16',
#   'nationality': 'American'},
#  'constantine': {'driverId': 'constantine',
#   'url': 'http://en.wikipedia.org/wiki/George_Constantine',
#   'givenName': 'George',
#   'familyName': 'Constantine',
#   'dateOfBirth': '1918-02-22',
#   'nationality': 'American'},
#  'cordts': {'driverId': 'cordts',
#   'url': 'http://en.wikipedia.org/wiki/John_Cordts',
#   'givenName': 'John',
#   'familyName': 'Cordts',
#   'dateOfBirth': '1935-07-23',
#   'nationality': 'Canadian'},
#  'coulthard': {'driverId': 'coulthard',
#   'code': 'COU',
#   'url': 'http://en.wikipedia.org/wiki/David_Coulthard',
#   'givenName': 'David',
#   'familyName': 'Coulthard',
#   'dateOfBirth': '1971-03-27',
#   'nationality': 'British'},
#  'courage': {'driverId': 'courage',
#   'url': 'http://en.wikipedia.org/wiki/Piers_Courage',
#   'givenName': 'Piers',
#   'familyName': 'Courage',
#   'dateOfBirth': '1942-05-27',
#   'nationality': 'British'},
#  'craft': {'driverId': 'craft',
#   'url': 'http://en.wikipedia.org/wiki/Chris_Craft_(racing_driver)',
#   'givenName': 'Chris',
#   'familyName': 'Craft',
#   'dateOfBirth': '1939-11-17',
#   'nationality': 'British'},
#  'crawford': {'driverId': 'crawford',
#   'url': 'http://en.wikipedia.org/wiki/Jim_Crawford_(driver)',
#   'givenName': 'Jim',
#   'familyName': 'Crawford',
#   'dateOfBirth': '1948-02-13',
#   'nationality': 'British'},
#  'ray_crawford': {'driverId': 'ray_crawford',
#   'url': 'http://en.wikipedia.org/wiki/Ray_Crawford',
#   'givenName': 'Ray',
#   'familyName': 'Crawford',
#   'dateOfBirth': '1915-10-26',
#   'nationality': 'American'},
#  'crespo': {'driverId': 'crespo',
#   'url': 'http://en.wikipedia.org/wiki/Alberto_Crespo',
#   'givenName': 'Alberto',
#   'familyName': 'Crespo',
#   'dateOfBirth': '1920-01-16',
#   'nationality': 'Argentine'},
#  'creus': {'driverId': 'creus',
#   'url': 'http://en.wikipedia.org/wiki/Antonio_Creus',
#   'givenName': 'Antonio',
#   'familyName': 'Creus',
#   'dateOfBirth': '1924-10-28',
#   'nationality': 'Spanish'},
#  'crockett': {'driverId': 'crockett',
#   'url': 'http://en.wikipedia.org/wiki/Larry_Crockett',
#   'givenName': 'Larry',
#   'familyName': 'Crockett',
#   'dateOfBirth': '1926-10-23',
#   'nationality': 'American'},
#  'crook': {'driverId': 'crook',
#   'url': 'http://en.wikipedia.org/wiki/Tony_Crook',
#   'givenName': 'Tony',
#   'familyName': 'Crook',
#   'dateOfBirth': '1920-02-16',
#   'nationality': 'British'},
#  'cross': {'driverId': 'cross',
#   'url': 'http://en.wikipedia.org/wiki/Art_Cross',
#   'givenName': 'Art',
#   'familyName': 'Cross',
#   'dateOfBirth': '1918-01-24',
#   'nationality': 'American'},
#  'crossley': {'driverId': 'crossley',
#   'url': 'http://en.wikipedia.org/wiki/Geoff_Crossley',
#   'givenName': 'Geoff',
#   'familyName': 'Crossley',
#   'dateOfBirth': '1921-05-11',
#   'nationality': 'British'},
#  'cruz': {'driverId': 'cruz',
#   'url': 'http://en.wikipedia.org/wiki/Adolfo_Schewelm_Cruz',
#   'givenName': 'Adolfo',
#   'familyName': 'Cruz',
#   'dateOfBirth': '1923-06-28',
#   'nationality': 'Argentine'},
#  'ambrosio': {'driverId': 'ambrosio',
#   'code': 'DAM',
#   'url': 'http://en.wikipedia.org/wiki/J%C3%A9r%C3%B4me_d%27Ambrosio',
#   'givenName': 'Jérôme',
#   'familyName': "d'Ambrosio",
#   'dateOfBirth': '1985-12-27',
#   'nationality': 'Belgian'},
#  'orey': {'driverId': 'orey',
#   'url': 'http://en.wikipedia.org/wiki/Fritz_d%27Orey',
#   'givenName': 'Fritz',
#   'familyName': "d'Orey",
#   'dateOfBirth': '1938-03-25',
#   'nationality': 'Brazilian'},
#  'matta': {'driverId': 'matta',
#   'url': 'http://en.wikipedia.org/wiki/Cristiano_da_Matta',
#   'givenName': 'Cristiano',
#   'familyName': 'da Matta',
#   'dateOfBirth': '1973-09-19',
#   'nationality': 'Brazilian'},
#  'ramos': {'driverId': 'ramos',
#   'url': 'http://en.wikipedia.org/wiki/Hernando_da_Silva_Ramos',
#   'givenName': 'Hernando',
#   'familyName': 'da Silva Ramos',
#   'dateOfBirth': '1925-12-07',
#   'nationality': 'Brazilian'},
#  'daigh': {'driverId': 'daigh',
#   'url': 'http://en.wikipedia.org/wiki/Chuck_Daigh',
#   'givenName': 'Chuck',
#   'familyName': 'Daigh',
#   'dateOfBirth': '1923-11-29',
#   'nationality': 'American'},
#  'dalmas': {'driverId': 'dalmas',
#   'url': 'http://en.wikipedia.org/wiki/Yannick_Dalmas',
#   'givenName': 'Yannick',
#   'familyName': 'Dalmas',
#   'dateOfBirth': '1961-07-28',
#   'nationality': 'French'},
#  'daly': {'driverId': 'daly',
#   'url': 'http://en.wikipedia.org/wiki/Derek_Daly',
#   'givenName': 'Derek',
#   'familyName': 'Daly',
#   'dateOfBirth': '1953-03-11',
#   'nationality': 'Irish'},
#  'danner': {'driverId': 'danner',
#   'url': 'http://en.wikipedia.org/wiki/Christian_Danner',
#   'givenName': 'Christian',
#   'familyName': 'Danner',
#   'dateOfBirth': '1958-04-04',
#   'nationality': 'German'},
#  'daponte': {'driverId': 'daponte',
#   'url': 'http://en.wikipedia.org/wiki/Jorge_Daponte',
#   'givenName': 'Jorge',
#   'familyName': 'Daponte',
#   'dateOfBirth': '1923-06-05',
#   'nationality': 'Argentine'},
#  'davidson': {'driverId': 'davidson',
#   'code': 'DAV',
#   'url': 'http://en.wikipedia.org/wiki/Anthony_Davidson',
#   'givenName': 'Anthony',
#   'familyName': 'Davidson',
#   'dateOfBirth': '1979-04-18',
#   'nationality': 'British'},
#  'davies': {'driverId': 'davies',
#   'url': 'http://en.wikipedia.org/wiki/Jimmy_Davies',
#   'givenName': 'Jimmy',
#   'familyName': 'Davies',
#   'dateOfBirth': '1929-08-08',
#   'nationality': 'American'},
#  'davis': {'driverId': 'davis',
#   'url': 'http://en.wikipedia.org/wiki/Colin_Davis_(driver)',
#   'givenName': 'Colin',
#   'familyName': 'Davis',
#   'dateOfBirth': '1933-07-29',
#   'nationality': 'British'},
#  'daywalt': {'driverId': 'daywalt',
#   'url': 'http://en.wikipedia.org/wiki/Jimmy_Daywalt',
#   'givenName': 'Jimmy',
#   'familyName': 'Daywalt',
#   'dateOfBirth': '1924-08-28',
#   'nationality': 'American'},
#  'adamich': {'driverId': 'adamich',
#   'url': 'http://en.wikipedia.org/wiki/Andrea_de_Adamich',
#   'givenName': 'Andrea',
#   'familyName': 'de Adamich',
#   'dateOfBirth': '1941-10-03',
#   'nationality': 'Italian'},
#  'angelis': {'driverId': 'angelis',
#   'url': 'http://en.wikipedia.org/wiki/Elio_de_Angelis',
#   'givenName': 'Elio',
#   'familyName': 'de Angelis',
#   'dateOfBirth': '1958-03-26',
#   'nationality': 'Italian'},
#  'beaufort': {'driverId': 'beaufort',
#   'url': 'http://en.wikipedia.org/wiki/Carel_Godin_de_Beaufort',
#   'givenName': 'Carel Godin',
#   'familyName': 'de Beaufort',
#   'dateOfBirth': '1934-04-10',
#   'nationality': 'Dutch'},
#  'cesaris': {'driverId': 'cesaris',
#   'url': 'http://en.wikipedia.org/wiki/Andrea_de_Cesaris',
#   'givenName': 'Andrea',
#   'familyName': 'de Cesaris',
#   'dateOfBirth': '1959-05-31',
#   'nationality': 'Italian'},
#  'Changy': {'driverId': 'Changy',
#   'url': 'http://en.wikipedia.org/wiki/Alain_de_Changy',
#   'givenName': 'Alain',
#   'familyName': 'de Changy',
#   'dateOfBirth': '1922-02-05',
#   'nationality': 'Belgian'},
#  'dryver': {'driverId': 'dryver',
#   'url': 'http://en.wikipedia.org/wiki/Bernard_de_Dryver',
#   'givenName': 'Bernard',
#   'familyName': 'de Dryver',
#   'dateOfBirth': '1952-09-19',
#   'nationality': 'Belgian'},
#  'filippis': {'driverId': 'filippis',
#   'url': 'http://en.wikipedia.org/wiki/Maria_Teresa_de_Filippis',
#   'givenName': 'Maria',
#   'familyName': 'de Filippis',
#   'dateOfBirth': '1926-11-11',
#   'nationality': 'Italian'},
#  'graffenried': {'driverId': 'graffenried',
#   'url': 'http://en.wikipedia.org/wiki/Toulo_de_Graffenried',
#   'givenName': 'Toulo',
#   'familyName': 'de Graffenried',
#   'dateOfBirth': '1914-05-18',
#   'nationality': 'Swiss'},
#  'klerk': {'driverId': 'klerk',
#   'url': 'http://en.wikipedia.org/wiki/Peter_de_Klerk',
#   'givenName': 'Peter',
#   'familyName': 'de Klerk',
#   'dateOfBirth': '1935-03-16',
#   'nationality': 'South African'},
#  'rosa': {'driverId': 'rosa',
#   'code': 'DLR',
#   'url': 'http://en.wikipedia.org/wiki/Pedro_de_la_Rosa',
#   'givenName': 'Pedro',
#   'familyName': 'de la Rosa',
#   'dateOfBirth': '1971-02-24',
#   'nationality': 'Spanish'},
#  'portago': {'driverId': 'portago',
#   'url': 'http://en.wikipedia.org/wiki/Alfonso_de_Portago',
#   'givenName': 'Alfonso',
#   'familyName': 'de Portago',
#   'dateOfBirth': '1928-10-11',
#   'nationality': 'Spanish'},
#  'riu': {'driverId': 'riu',
#   'url': 'http://en.wikipedia.org/wiki/Giovanni_de_Riu',
#   'givenName': 'Giovanni',
#   'familyName': 'de Riu',
#   'dateOfBirth': '1925-03-10',
#   'nationality': 'Italian'},
#  'terra': {'driverId': 'terra',
#   'url': 'http://en.wikipedia.org/wiki/Max_de_Terra',
#   'givenName': 'Max',
#   'familyName': 'de Terra',
#   'dateOfBirth': '1918-10-06',
#   'nationality': 'Swiss'},
#  'tomaso': {'driverId': 'tomaso',
#   'url': 'http://en.wikipedia.org/wiki/Alessandro_de_Tomaso',
#   'givenName': 'Alessandro',
#   'familyName': 'de Tomaso',
#   'dateOfBirth': '1928-07-10',
#   'nationality': 'Argentine-Italian'},
#  'tornaco': {'driverId': 'tornaco',
#   'url': 'http://en.wikipedia.org/wiki/Charles_de_Tornaco',
#   'givenName': 'Charles',
#   'familyName': 'de Tornaco',
#   'dateOfBirth': '1927-06-07',
#   'nationality': 'Belgian'},
#  'villota': {'driverId': 'villota',
#   'url': 'http://en.wikipedia.org/wiki/Emilio_de_Villota',
#   'givenName': 'Emilio',
#   'familyName': 'de Villota',
#   'dateOfBirth': '1946-07-26',
#   'nationality': 'Spanish'},
#  'vos': {'driverId': 'vos',
#   'url': 'http://en.wikipedia.org/wiki/Ernie_de_Vos',
#   'givenName': 'Ernie',
#   'familyName': 'de Vos',
#   'dateOfBirth': '1941-07-01',
#   'nationality': 'Dutch'},
#  'deletraz': {'driverId': 'deletraz',
#   'url': 'http://en.wikipedia.org/wiki/Jean-Denis_Deletraz',
#   'givenName': 'Jean-Denis',
#   'familyName': 'Délétraz',
#   'dateOfBirth': '1963-10-01',
#   'nationality': 'Swiss'},
#  'depailler': {'driverId': 'depailler',
#   'url': 'http://en.wikipedia.org/wiki/Patrick_Depailler',
#   'givenName': 'Patrick',
#   'familyName': 'Depailler',
#   'dateOfBirth': '1944-08-09',
#   'nationality': 'French'},
#  'grassi': {'driverId': 'grassi',
#   'code': 'DIG',
#   'url': 'http://en.wikipedia.org/wiki/Lucas_di_Grassi',
#   'givenName': 'Lucas',
#   'familyName': 'di Grassi',
#   'dateOfBirth': '1984-08-11',
#   'nationality': 'Brazilian'},
#  'resta': {'driverId': 'resta',
#   'code': 'DIR',
#   'url': 'http://en.wikipedia.org/wiki/Paul_di_Resta',
#   'givenName': 'Paul',
#   'familyName': 'di Resta',
#   'dateOfBirth': '1986-04-16',
#   'nationality': 'British'},
#  'diniz': {'driverId': 'diniz',
#   'url': 'http://en.wikipedia.org/wiki/Pedro_Diniz',
#   'givenName': 'Pedro',
#   'familyName': 'Diniz',
#   'dateOfBirth': '1970-05-22',
#   'nationality': 'Brazilian'},
#  'dinsmore': {'driverId': 'dinsmore',
#   'url': 'http://en.wikipedia.org/wiki/Duke_Dinsmore',
#   'givenName': 'Duke',
#   'familyName': 'Dinsmore',
#   'dateOfBirth': '1913-04-10',
#   'nationality': 'American'},
#  'dochnal': {'driverId': 'dochnal',
#   'url': 'http://en.wikipedia.org/wiki/Frank_Dochnal',
#   'givenName': 'Frank',
#   'familyName': 'Dochnal',
#   'dateOfBirth': '1920-10-08',
#   'nationality': 'American'},
#  'dolhem': {'driverId': 'dolhem',
#   'url': 'http://en.wikipedia.org/wiki/Jos%C3%A9_Dolhem',
#   'givenName': 'José',
#   'familyName': 'Dolhem',
#   'dateOfBirth': '1944-04-26',
#   'nationality': 'French'},
#  'donnelly': {'driverId': 'donnelly',
#   'url': 'http://en.wikipedia.org/wiki/Martin_Donnelly_(racing_driver)',
#   'givenName': 'Martin',
#   'familyName': 'Donnelly',
#   'dateOfBirth': '1964-03-26',
#   'nationality': 'British'},
#  'donohue': {'driverId': 'donohue',
#   'url': 'http://en.wikipedia.org/wiki/Mark_Donohue',
#   'givenName': 'Mark',
#   'familyName': 'Donohue',
#   'dateOfBirth': '1937-03-18',
#   'nationality': 'American'},
#  'doornbos': {'driverId': 'doornbos',
#   'code': 'DOO',
#   'url': 'http://en.wikipedia.org/wiki/Robert_Doornbos',
#   'givenName': 'Robert',
#   'familyName': 'Doornbos',
#   'dateOfBirth': '1981-09-23',
#   'nationality': 'Dutch'},
#  'downing': {'driverId': 'downing',
#   'url': 'http://en.wikipedia.org/wiki/Ken_Downing',
#   'givenName': 'Ken',
#   'familyName': 'Downing',
#   'dateOfBirth': '1917-12-05',
#   'nationality': 'British'},
#  'drake': {'driverId': 'drake',
#   'url': 'http://en.wikipedia.org/wiki/Bob_Drake_(Formula_One)',
#   'givenName': 'Bob',
#   'familyName': 'Drake',
#   'dateOfBirth': '1919-12-14',
#   'nationality': 'American'},
#  'driver': {'driverId': 'driver',
#   'url': 'http://en.wikipedia.org/wiki/Paddy_Driver',
#   'givenName': 'Paddy',
#   'familyName': 'Driver',
#   'dateOfBirth': '1934-05-13',
#   'nationality': 'South African'},
#  'drogo': {'driverId': 'drogo',
#   'url': 'http://en.wikipedia.org/wiki/Piero_Drogo',
#   'givenName': 'Piero',
#   'familyName': 'Drogo',
#   'dateOfBirth': '1926-08-08',
#   'nationality': 'Italian'},
#  'duke': {'driverId': 'duke',
#   'url': 'http://en.wikipedia.org/wiki/Geoff_Duke',
#   'givenName': 'Geoff',
#   'familyName': 'Duke',
#   'dateOfBirth': '1923-03-29',
# ...
#  'trintignant': {'driverId': 'trintignant',
#   'url': 'http://en.wikipedia.org/wiki/Maurice_Trintignant',
#   'givenName': 'Maurice',
#   'familyName': 'Trintignant',
#   'dateOfBirth': '1917-10-30',
#   'nationality': 'French'},
#  'trulli': {'driverId': 'trulli',
#   'code': 'TRU',
#   'url': 'http://en.wikipedia.org/wiki/Jarno_Trulli',
#   'givenName': 'Jarno',
#   'familyName': 'Trulli',
#   'dateOfBirth': '1974-07-13',
#   'nationality': 'Italian'},
#  'tuero': {'driverId': 'tuero',
#   'url': 'http://en.wikipedia.org/wiki/Esteban_Tuero',
#   'givenName': 'Esteban',
#   'familyName': 'Tuero',
#   'dateOfBirth': '1978-04-22',
#   'nationality': 'Argentine'},
#  'tunmer': {'driverId': 'tunmer',
#   'url': 'http://en.wikipedia.org/wiki/Guy_Tunmer',
#   'givenName': 'Guy',
#   'familyName': 'Tunmer',
#   'dateOfBirth': '1948-12-01',
#   'nationality': 'South African'},
#  'turner': {'driverId': 'turner',
#   'url': 'http://en.wikipedia.org/wiki/Jack_Turner_(driver)',
#   'givenName': 'Jack',
#   'familyName': 'Turner',
#   'dateOfBirth': '1920-02-12',
#   'nationality': 'American'},
#  'ulmen': {'driverId': 'ulmen',
#   'url': 'http://en.wikipedia.org/wiki/Toni_Ulmen',
#   'givenName': 'Toni',
#   'familyName': 'Ulmen',
#   'dateOfBirth': '1906-01-25',
#   'nationality': 'German'},
#  'unser': {'driverId': 'unser',
#   'url': 'http://en.wikipedia.org/wiki/Bobby_Unser',
#   'givenName': 'Bobby',
#   'familyName': 'Unser',
#   'dateOfBirth': '1934-02-20',
#   'nationality': 'American'},
#  'jerry_unser': {'driverId': 'jerry_unser',
#   'url': 'http://en.wikipedia.org/wiki/Jerry_Unser',
#   'givenName': 'Jerry',
#   'familyName': 'Unser',
#   'dateOfBirth': '1932-11-15',
#   'nationality': 'American'},
#  'uria': {'driverId': 'uria',
#   'url': 'http://en.wikipedia.org/wiki/Alberto_Uria',
#   'givenName': 'Alberto',
#   'familyName': 'Uria',
#   'dateOfBirth': '1924-07-11',
#   'nationality': 'Uruguayan'},
#  'vaccarella': {'driverId': 'vaccarella',
#   'url': 'http://en.wikipedia.org/wiki/Nino_Vaccarella',
#   'givenName': 'Nino',
#   'familyName': 'Vaccarella',
#   'dateOfBirth': '1933-03-04',
#   'nationality': 'Italian'},
#  'poele': {'driverId': 'poele',
#   'url': 'http://en.wikipedia.org/wiki/Eric_van_de_Poele',
#   'givenName': 'Eric',
#   'familyName': 'van de Poele',
#   'dateOfBirth': '1961-09-30',
#   'nationality': 'Belgian'},
#  'garde': {'driverId': 'garde',
#   'code': 'VDG',
#   'url': 'http://en.wikipedia.org/wiki/Giedo_van_der_Garde',
#   'givenName': 'Giedo',
#   'familyName': 'van der Garde',
#   'dateOfBirth': '1985-04-25',
#   'nationality': 'Dutch'},
#  'lof': {'driverId': 'lof',
#   'url': 'http://en.wikipedia.org/wiki/Dries_van_der_Lof',
#   'givenName': 'Dries',
#   'familyName': 'van der Lof',
#   'dateOfBirth': '1919-08-23',
#   'nationality': 'Dutch'},
#  'vyver': {'driverId': 'vyver',
#   'url': 'http://en.wikipedia.org/wiki/Syd_van_der_Vyver',
#   'givenName': 'Syd',
#   'familyName': 'van der Vyver',
#   'dateOfBirth': '1920-06-01',
#   'nationality': 'South African'},
#  'lennep': {'driverId': 'lennep',
#   'url': 'http://en.wikipedia.org/wiki/Gijs_Van_Lennep',
#   'givenName': 'Gijs',
#   'familyName': 'van Lennep',
#   'dateOfBirth': '1942-03-16',
#   'nationality': 'Dutch'},
#  'rooyen': {'driverId': 'rooyen',
#   'url': 'http://en.wikipedia.org/wiki/Basil_van_Rooyen',
#   'givenName': 'Basil',
#   'familyName': 'van Rooyen',
#   'dateOfBirth': '1939-04-19',
#   'nationality': 'South African'},
#  'vandoorne': {'driverId': 'vandoorne',
#   'permanentNumber': '2',
#   'code': 'VAN',
#   'url': 'http://en.wikipedia.org/wiki/Stoffel_Vandoorne',
#   'givenName': 'Stoffel',
#   'familyName': 'Vandoorne',
#   'dateOfBirth': '1992-03-26',
#   'nationality': 'Belgian'},
#  'veith': {'driverId': 'veith',
#   'url': 'http://en.wikipedia.org/wiki/Bob_Veith',
#   'givenName': 'Bob',
#   'familyName': 'Veith',
#   'dateOfBirth': '1926-11-01',
#   'nationality': 'American'},
#  'vergne': {'driverId': 'vergne',
#   'permanentNumber': '25',
#   'code': 'VER',
#   'url': 'http://en.wikipedia.org/wiki/Jean-%C3%89ric_Vergne',
#   'givenName': 'Jean-Éric',
#   'familyName': 'Vergne',
#   'dateOfBirth': '1990-04-25',
#   'nationality': 'French'},
#  'verstappen': {'driverId': 'verstappen',
#   'url': 'http://en.wikipedia.org/wiki/Jos_Verstappen',
#   'givenName': 'Jos',
#   'familyName': 'Verstappen',
#   'dateOfBirth': '1972-03-04',
#   'nationality': 'Dutch'},
#  'max_verstappen': {'driverId': 'max_verstappen',
#   'permanentNumber': '33',
#   'code': 'VER',
#   'url': 'http://en.wikipedia.org/wiki/Max_Verstappen',
#   'givenName': 'Max',
#   'familyName': 'Verstappen',
#   'dateOfBirth': '1997-09-30',
#   'nationality': 'Dutch'},
#  'vettel': {'driverId': 'vettel',
#   'permanentNumber': '5',
#   'code': 'VET',
#   'url': 'http://en.wikipedia.org/wiki/Sebastian_Vettel',
#   'givenName': 'Sebastian',
#   'familyName': 'Vettel',
#   'dateOfBirth': '1987-07-03',
#   'nationality': 'German'},
#  'villeneuve': {'driverId': 'villeneuve',
#   'code': 'VIL',
#   'url': 'http://en.wikipedia.org/wiki/Jacques_Villeneuve',
#   'givenName': 'Jacques',
#   'familyName': 'Villeneuve',
#   'dateOfBirth': '1971-04-09',
#   'nationality': 'Canadian'},
#  'gilles_villeneuve': {'driverId': 'gilles_villeneuve',
#   'url': 'http://en.wikipedia.org/wiki/Gilles_Villeneuve',
#   'givenName': 'Gilles',
#   'familyName': 'Villeneuve',
#   'dateOfBirth': '1950-01-18',
#   'nationality': 'Canadian'},
#  'villeneuve_sr': {'driverId': 'villeneuve_sr',
#   'url': 'http://en.wikipedia.org/wiki/Jacques_Villeneuve_(elder)',
#   'givenName': 'Jacques',
#   'familyName': 'Villeneuve Sr.',
#   'dateOfBirth': '1953-11-04',
#   'nationality': 'Canadian'},
#  'villoresi': {'driverId': 'villoresi',
#   'url': 'http://en.wikipedia.org/wiki/Luigi_Villoresi',
#   'givenName': 'Luigi',
#   'familyName': 'Villoresi',
#   'dateOfBirth': '1909-05-16',
#   'nationality': 'Italian'},
#  'volonterio': {'driverId': 'volonterio',
#   'url': 'http://en.wikipedia.org/wiki/Ottorino_Volonterio',
#   'givenName': 'Ottorino',
#   'familyName': 'Volonterio',
#   'dateOfBirth': '1917-12-07',
#   'nationality': 'Swiss'},
#  'opel': {'driverId': 'opel',
#   'url': 'http://en.wikipedia.org/wiki/Rikky_von_Opel',
#   'givenName': 'Rikky',
#   'familyName': 'von Opel',
#   'dateOfBirth': '1947-10-14',
#   'nationality': 'Liechtensteiner'},
#  'hans_stuck': {'driverId': 'hans_stuck',
#   'url': 'http://en.wikipedia.org/wiki/Hans_Von_Stuck',
#   'givenName': 'Hans',
#   'familyName': 'von Stuck',
#   'dateOfBirth': '1900-12-27',
#   'nationality': 'German'},
#  'trips': {'driverId': 'trips',
#   'url': 'http://en.wikipedia.org/wiki/Wolfgang_Graf_Berghe_von_Trips',
#   'givenName': 'Wolfgang',
#   'familyName': 'von Trips',
#   'dateOfBirth': '1928-05-04',
#   'nationality': 'German'},
#  'vonlanthen': {'driverId': 'vonlanthen',
#   'url': 'http://en.wikipedia.org/wiki/Jo_Vonlanthen',
#   'givenName': 'Jo',
#   'familyName': 'Vonlanthen',
#   'dateOfBirth': '1942-05-31',
#   'nationality': 'Swiss'},
#  'vukovich': {'driverId': 'vukovich',
#   'url': 'http://en.wikipedia.org/wiki/Bill_Vukovich',
#   'givenName': 'Bill',
#   'familyName': 'Vukovich',
#   'dateOfBirth': '1918-12-13',
#   'nationality': 'American'},
#  'wacker': {'driverId': 'wacker',
#   'url': 'http://en.wikipedia.org/wiki/Fred_Wacker',
#   'givenName': 'Fred',
#   'familyName': 'Wacker',
#   'dateOfBirth': '1918-07-10',
#   'nationality': 'American'},
#  'walker': {'driverId': 'walker',
#   'url': 'http://en.wikipedia.org/wiki/David_Walker_(racing_driver)',
#   'givenName': 'David',
#   'familyName': 'Walker',
#   'dateOfBirth': '1941-06-10',
#   'nationality': 'Australian'},
#  'peter_walker': {'driverId': 'peter_walker',
#   'url': 'http://en.wikipedia.org/wiki/Peter_Walker_(driver)',
#   'givenName': 'Peter',
#   'familyName': 'Walker',
#   'dateOfBirth': '1912-10-07',
#   'nationality': 'British'},
#  'wallard': {'driverId': 'wallard',
#   'url': 'http://en.wikipedia.org/wiki/Lee_Wallard',
#   'givenName': 'Lee',
#   'familyName': 'Wallard',
#   'dateOfBirth': '1910-09-07',
#   'nationality': 'American'},
#  'walter': {'driverId': 'walter',
#   'url': 'http://en.wikipedia.org/wiki/Heini_Walter',
#   'givenName': 'Heini',
#   'familyName': 'Walter',
#   'dateOfBirth': '1927-07-28',
#   'nationality': 'Swiss'},
#  'ward': {'driverId': 'ward',
#   'url': 'http://en.wikipedia.org/wiki/Rodger_Ward',
#   'givenName': 'Rodger',
#   'familyName': 'Ward',
#   'dateOfBirth': '1921-01-10',
#   'nationality': 'American'},
#  'warwick': {'driverId': 'warwick',
#   'url': 'http://en.wikipedia.org/wiki/Derek_Warwick',
#   'givenName': 'Derek',
#   'familyName': 'Warwick',
#   'dateOfBirth': '1954-08-27',
#   'nationality': 'British'},
#  'watson': {'driverId': 'watson',
#   'url': 'http://en.wikipedia.org/wiki/John_Watson_(racing_driver)',
#   'givenName': 'John',
#   'familyName': 'Watson',
#   'dateOfBirth': '1946-05-04',
#   'nationality': 'British'},
#  'webb': {'driverId': 'webb',
#   'url': 'http://en.wikipedia.org/wiki/Travis_Webb',
#   'givenName': 'Travis',
#   'familyName': 'Webb',
#   'dateOfBirth': '1910-10-08',
#   'nationality': 'American'},
#  'webber': {'driverId': 'webber',
#   'code': 'WEB',
#   'url': 'http://en.wikipedia.org/wiki/Mark_Webber',
#   'givenName': 'Mark',
#   'familyName': 'Webber',
#   'dateOfBirth': '1976-08-27',
#   'nationality': 'Australian'},
#  'wehrlein': {'driverId': 'wehrlein',
#   'permanentNumber': '94',
#   'code': 'WEH',
#   'url': 'http://en.wikipedia.org/wiki/Pascal_Wehrlein',
#   'givenName': 'Pascal',
#   'familyName': 'Wehrlein',
#   'dateOfBirth': '1994-10-18',
#   'nationality': 'German'},
#  'weidler': {'driverId': 'weidler',
#   'url': 'http://en.wikipedia.org/wiki/Volker_Weidler',
#   'givenName': 'Volker',
#   'familyName': 'Weidler',
#   'dateOfBirth': '1962-03-18',
#   'nationality': 'German'},
#  'weiler': {'driverId': 'weiler',
#   'url': 'http://en.wikipedia.org/wiki/Wayne_Weiler',
#   'givenName': 'Wayne',
#   'familyName': 'Weiler',
#   'dateOfBirth': '1934-12-09',
#   'nationality': 'American'},
#  'wendlinger': {'driverId': 'wendlinger',
#   'url': 'http://en.wikipedia.org/wiki/Karl_Wendlinger',
#   'givenName': 'Karl',
#   'familyName': 'Wendlinger',
#   'dateOfBirth': '1968-12-20',
#   'nationality': 'Austrian'},
#  'westbury': {'driverId': 'westbury',
#   'url': 'http://en.wikipedia.org/wiki/Peter_Westbury',
#   'givenName': 'Peter',
#   'familyName': 'Westbury',
#   'dateOfBirth': '1938-05-26',
#   'nationality': 'British'},
#  'weyant': {'driverId': 'weyant',
#   'url': 'http://en.wikipedia.org/wiki/Chuck_Weyant',
#   'givenName': 'Chuck',
#   'familyName': 'Weyant',
#   'dateOfBirth': '1923-04-03',
#   'nationality': 'American'},
#  'wharton': {'driverId': 'wharton',
#   'url': 'http://en.wikipedia.org/wiki/Ken_Wharton',
#   'givenName': 'Ken',
#   'familyName': 'Wharton',
#   'dateOfBirth': '1916-03-21',
#   'nationality': 'British'},
#  'whiteaway': {'driverId': 'whiteaway',
#   'url': 'http://en.wikipedia.org/wiki/Ted_Whiteaway',
#   'givenName': 'Ted',
#   'familyName': 'Whiteaway',
#   'dateOfBirth': '1928-11-01',
#   'nationality': 'British'},
#  'whitehead': {'driverId': 'whitehead',
#   'url': 'http://en.wikipedia.org/wiki/Peter_Whitehead_(racing_driver)',
#   'givenName': 'Peter',
#   'familyName': 'Whitehead',
#   'dateOfBirth': '1914-11-12',
#   'nationality': 'British'},
#  'graham_whitehead': {'driverId': 'graham_whitehead',
#   'url': 'http://en.wikipedia.org/wiki/Graham_Whitehead',
#   'givenName': 'Graham',
#   'familyName': 'Whitehead',
#   'dateOfBirth': '1922-04-15',
#   'nationality': 'British'},
#  'whitehouse': {'driverId': 'whitehouse',
#   'url': 'http://en.wikipedia.org/wiki/Bill_Whitehouse',
#   'givenName': 'Bill',
#   'familyName': 'Whitehouse',
#   'dateOfBirth': '1909-04-01',
#   'nationality': 'British'},
#  'widdows': {'driverId': 'widdows',
#   'url': 'http://en.wikipedia.org/wiki/Robin_Widdows',
#   'givenName': 'Robin',
#   'familyName': 'Widdows',
#   'dateOfBirth': '1942-05-27',
#   'nationality': 'British'},
#  'wietzes': {'driverId': 'wietzes',
#   'url': 'http://en.wikipedia.org/wiki/Eppie_Wietzes',
#   'givenName': 'Eppie',
#   'familyName': 'Wietzes',
#   'dateOfBirth': '1938-05-28',
#   'nationality': 'Canadian'},
#  'wilds': {'driverId': 'wilds',
#   'url': 'http://en.wikipedia.org/wiki/Mike_Wilds',
#   'givenName': 'Mike',
#   'familyName': 'Wilds',
#   'dateOfBirth': '1946-01-07',
#   'nationality': 'British'},
#  'williams': {'driverId': 'williams',
#   'url': 'http://en.wikipedia.org/wiki/Jonathan_Williams_(racing_driver)',
#   'givenName': 'Jonathan',
#   'familyName': 'Williams',
#   'dateOfBirth': '1942-10-26',
#   'nationality': 'British'},
#  'williamson': {'driverId': 'williamson',
#   'url': 'http://en.wikipedia.org/wiki/Roger_Williamson',
#   'givenName': 'Roger',
#   'familyName': 'Williamson',
#   'dateOfBirth': '1948-02-02',
#   'nationality': 'British'},
#  'wilson': {'driverId': 'wilson',
#   'url': 'http://en.wikipedia.org/wiki/Justin_Wilson_(racing_driver)',
#   'givenName': 'Justin',
#   'familyName': 'Wilson',
#   'dateOfBirth': '1978-07-31',
#   'nationality': 'British'},
#  'desire_wilson': {'driverId': 'desire_wilson',
#   'url': 'http://en.wikipedia.org/wiki/Desir%C3%A9_Wilson',
#   'givenName': 'Desiré',
#   'familyName': 'Wilson',
#   'dateOfBirth': '1953-11-26',
#   'nationality': 'South African'},
#  'vic_wilson': {'driverId': 'vic_wilson',
#   'url': 'http://en.wikipedia.org/wiki/Vic_Wilson_(motor_racing_driver)',
#   'givenName': 'Vic',
#   'familyName': 'Wilson',
#   'dateOfBirth': '1931-04-14',
#   'nationality': 'British'},
#  'dempsey_wilson': {'driverId': 'dempsey_wilson',
#   'url': 'http://en.wikipedia.org/wiki/Dempsey_Wilson',
#   'givenName': 'Dempsey',
#   'familyName': 'Wilson',
#   'dateOfBirth': '1927-03-11',
#   'nationality': 'American'},
#  'markus_winkelhock': {'driverId': 'markus_winkelhock',
#   'code': 'WIN',
#   'url': 'http://en.wikipedia.org/wiki/Markus_Winkelhock',
#   'givenName': 'Markus',
#   'familyName': 'Winkelhock',
#   'dateOfBirth': '1980-06-13',
#   'nationality': 'German'},
#  'joachim_winkelhock': {'driverId': 'joachim_winkelhock',
#   'url': 'http://en.wikipedia.org/wiki/Joachim_Winkelhock',
#   'givenName': 'Joachim',
#   'familyName': 'Winkelhock',
#   'dateOfBirth': '1960-10-24',
#   'nationality': 'German'},
#  'manfred_winkelhock': {'driverId': 'manfred_winkelhock',
#   'url': 'http://en.wikipedia.org/wiki/Manfred_Winkelhock',
#   'givenName': 'Manfred',
#   'familyName': 'Winkelhock',
#   'dateOfBirth': '1951-10-06',
#   'nationality': 'German'},
#  'wisell': {'driverId': 'wisell',
#   'url': 'http://en.wikipedia.org/wiki/Reine_Wisell',
#   'givenName': 'Reine',
#   'familyName': 'Wisell',
#   'dateOfBirth': '1941-09-30',
#   'nationality': 'Swedish'},
#  'wunderink': {'driverId': 'wunderink',
#   'url': 'http://en.wikipedia.org/wiki/Roelof_Wunderink',
#   'givenName': 'Roelof',
#   'familyName': 'Wunderink',
#   'dateOfBirth': '1948-12-12',
#   'nationality': 'Dutch'},
#  'wurz': {'driverId': 'wurz',
#   'code': 'WUR',
#   'url': 'http://en.wikipedia.org/wiki/Alexander_Wurz',
#   'givenName': 'Alexander',
#   'familyName': 'Wurz',
#   'dateOfBirth': '1974-02-15',
#   'nationality': 'Austrian'},
#  'yamamoto': {'driverId': 'yamamoto',
#   'code': 'YAM',
#   'url': 'http://en.wikipedia.org/wiki/Sakon_Yamamoto',
#   'givenName': 'Sakon',
#   'familyName': 'Yamamoto',
#   'dateOfBirth': '1982-07-09',
#   'nationality': 'Japanese'},
#  'yoong': {'driverId': 'yoong',
#   'url': 'http://en.wikipedia.org/wiki/Alex_Yoong',
#   'givenName': 'Alex',
#   'familyName': 'Yoong',
#   'dateOfBirth': '1976-07-20',
#   'nationality': 'Malaysian'},
#  'zanardi': {'driverId': 'zanardi',
#   'url': 'http://en.wikipedia.org/wiki/Alex_Zanardi',
#   'givenName': 'Alessandro',
#   'familyName': 'Zanardi',
#   'dateOfBirth': '1966-10-23',
#   'nationality': 'Italian'},
#  'zapico': {'driverId': 'zapico',
#   'url': 'http://en.wikipedia.org/wiki/Emilio_Zapico',
#   'givenName': 'Emilio',
#   'familyName': 'Zapico',
#   'dateOfBirth': '1944-05-27',
#   'nationality': 'Spanish'},
#  'zonta': {'driverId': 'zonta',
#   'code': 'ZON',
#   'url': 'http://en.wikipedia.org/wiki/Ricardo_Zonta',
#   'givenName': 'Ricardo',
#   'familyName': 'Zonta',
#   'dateOfBirth': '1976-03-23',
#   'nationality': 'Brazilian'},
#  'zorzi': {'driverId': 'zorzi',
#   'url': 'http://en.wikipedia.org/wiki/Renzo_Zorzi',
#   'givenName': 'Renzo',
#   'familyName': 'Zorzi',
#   'dateOfBirth': '1946-12-12',
#   'nationality': 'Italian'},
#  'zunino': {'driverId': 'zunino',
#   'url': 'http://en.wikipedia.org/wiki/Ricardo_Zunino',
#   'givenName': 'Ricardo',
#   'familyName': 'Zunino',
#   'dateOfBirth': '1949-04-13',
#   'nationality': 'Argentine'}}

# %%
#Function that takes a dictionary of lists (the return of the season_drivers_info) and returns the ids of all the drivers
def unique_drivers(drivers_dict):
    drivers_list = []
    for season in drivers_dict.keys():
        for driver in drivers_dict[season]:
            drivers_list.append(driver['driverId'])
    unique_drivers = set(drivers_list)
    return unique_drivers

# %% [markdown]
# #Mixing season_drivers_info, with unique drivers function. Returns
# def all_drivers(from_year, to_year):
#     all_drivers = unique_drivers(season_drivers_info(from_year,to_year))
#     return all_drivers

# %%
#Create a dictionary with all the circuits and their information. The key is the id and the value is the returned dict by the api
def circuits_info():
    circuits_req = requests.get(site+ circuits +json).json()['MRData']['CircuitTable']['Circuits']
    circuits_info = {}
    for circuit in circuits_req:
        circuits_info[circuit['circuitId']] = circuit
    return circuits_info
circuits_info = circuits_info()
circuits_info
# Out:
# {'adelaide': {'circuitId': 'adelaide',
#   'url': 'http://en.wikipedia.org/wiki/Adelaide_Street_Circuit',
#   'circuitName': 'Adelaide Street Circuit',
#   'Location': {'lat': '-34.9272',
#    'long': '138.617',
#    'locality': 'Adelaide',
#    'country': 'Australia'}},
#  'ain-diab': {'circuitId': 'ain-diab',
#   'url': 'http://en.wikipedia.org/wiki/Ain-Diab_Circuit',
#   'circuitName': 'Ain Diab',
#   'Location': {'lat': '33.5786',
#    'long': '-7.6875',
#    'locality': 'Casablanca',
#    'country': 'Morocco'}},
#  'aintree': {'circuitId': 'aintree',
#   'url': 'http://en.wikipedia.org/wiki/Aintree_Motor_Racing_Circuit',
#   'circuitName': 'Aintree',
#   'Location': {'lat': '53.4769',
#    'long': '-2.94056',
#    'locality': 'Liverpool',
#    'country': 'UK'}},
#  'albert_park': {'circuitId': 'albert_park',
#   'url': 'http://en.wikipedia.org/wiki/Melbourne_Grand_Prix_Circuit',
#   'circuitName': 'Albert Park Grand Prix Circuit',
#   'Location': {'lat': '-37.8497',
#    'long': '144.968',
#    'locality': 'Melbourne',
#    'country': 'Australia'}},
#  'americas': {'circuitId': 'americas',
#   'url': 'http://en.wikipedia.org/wiki/Circuit_of_the_Americas',
#   'circuitName': 'Circuit of the Americas',
#   'Location': {'lat': '30.1328',
#    'long': '-97.6411',
#    'locality': 'Austin',
#    'country': 'USA'}},
#  'anderstorp': {'circuitId': 'anderstorp',
#   'url': 'http://en.wikipedia.org/wiki/Scandinavian_Raceway',
#   'circuitName': 'Scandinavian Raceway',
#   'Location': {'lat': '57.2653',
#    'long': '13.6042',
#    'locality': 'Anderstorp',
#    'country': 'Sweden'}},
#  'avus': {'circuitId': 'avus',
#   'url': 'http://en.wikipedia.org/wiki/AVUS',
#   'circuitName': 'AVUS',
#   'Location': {'lat': '52.4806',
#    'long': '13.2514',
#    'locality': 'Berlin',
#    'country': 'Germany'}},
#  'bahrain': {'circuitId': 'bahrain',
#   'url': 'http://en.wikipedia.org/wiki/Bahrain_International_Circuit',
#   'circuitName': 'Bahrain International Circuit',
#   'Location': {'lat': '26.0325',
#    'long': '50.5106',
#    'locality': 'Sakhir',
#    'country': 'Bahrain'}},
#  'BAK': {'circuitId': 'BAK',
#   'url': 'http://en.wikipedia.org/wiki/Baku_City_Circuit',
#   'circuitName': 'Baku City Circuit',
#   'Location': {'lat': '40.3725',
#    'long': '49.8533',
#    'locality': 'Baku',
#    'country': 'Azerbaijan'}},
#  'boavista': {'circuitId': 'boavista',
#   'url': 'http://en.wikipedia.org/wiki/Circuito_da_Boavista',
#   'circuitName': 'Circuito da Boavista',
#   'Location': {'lat': '41.1705',
#    'long': '-8.67325',
#    'locality': 'Oporto',
#    'country': 'Portugal'}},
#  'brands_hatch': {'circuitId': 'brands_hatch',
#   'url': 'http://en.wikipedia.org/wiki/Brands_Hatch',
#   'circuitName': 'Brands Hatch',
#   'Location': {'lat': '51.3569',
#    'long': '0.263056',
#    'locality': 'Kent',
#    'country': 'UK'}},
#  'bremgarten': {'circuitId': 'bremgarten',
#   'url': 'http://en.wikipedia.org/wiki/Circuit_Bremgarten',
#   'circuitName': 'Circuit Bremgarten',
#   'Location': {'lat': '46.9589',
#    'long': '7.40194',
#    'locality': 'Bern',
#    'country': 'Switzerland'}},
#  'buddh': {'circuitId': 'buddh',
#   'url': 'http://en.wikipedia.org/wiki/Buddh_International_Circuit',
#   'circuitName': 'Buddh International Circuit',
#   'Location': {'lat': '28.3487',
#    'long': '77.5331',
#    'locality': 'Uttar Pradesh',
#    'country': 'India'}},
#  'catalunya': {'circuitId': 'catalunya',
#   'url': 'http://en.wikipedia.org/wiki/Circuit_de_Barcelona-Catalunya',
#   'circuitName': 'Circuit de Barcelona-Catalunya',
#   'Location': {'lat': '41.57',
#    'long': '2.26111',
#    'locality': 'Montmeló',
#    'country': 'Spain'}},
#  'charade': {'circuitId': 'charade',
#   'url': 'http://en.wikipedia.org/wiki/Charade_Circuit',
#   'circuitName': 'Charade Circuit',
#   'Location': {'lat': '45.7472',
#    'long': '3.03889',
#    'locality': 'Clermont-Ferrand',
#    'country': 'France'}},
#  'dallas': {'circuitId': 'dallas',
#   'url': 'http://en.wikipedia.org/wiki/Fair_Park',
#   'circuitName': 'Fair Park',
#   'Location': {'lat': '32.7774',
#    'long': '-96.7587',
#    'locality': 'Dallas',
#    'country': 'USA'}},
#  'detroit': {'circuitId': 'detroit',
#   'url': 'http://en.wikipedia.org/wiki/Detroit_street_circuit',
#   'circuitName': 'Detroit Street Circuit',
#   'Location': {'lat': '42.3298',
#    'long': '-83.0401',
#    'locality': 'Detroit',
#    'country': 'USA'}},
#  'dijon': {'circuitId': 'dijon',
#   'url': 'http://en.wikipedia.org/wiki/Dijon-Prenois',
#   'circuitName': 'Dijon-Prenois',
#   'Location': {'lat': '47.3625',
#    'long': '4.89913',
#    'locality': 'Dijon',
#    'country': 'France'}},
#  'donington': {'circuitId': 'donington',
#   'url': 'http://en.wikipedia.org/wiki/Donington_Park',
#   'circuitName': 'Donington Park',
#   'Location': {'lat': '52.8306',
#    'long': '-1.37528',
#    'locality': 'Castle Donington',
#    'country': 'UK'}},
#  'essarts': {'circuitId': 'essarts',
#   'url': 'http://en.wikipedia.org/wiki/Rouen-Les-Essarts',
#   'circuitName': 'Rouen-Les-Essarts',
#   'Location': {'lat': '49.3306',
#    'long': '1.00458',
#    'locality': 'Rouen',
#    'country': 'France'}},
#  'estoril': {'circuitId': 'estoril',
#   'url': 'http://en.wikipedia.org/wiki/Aut%C3%B3dromo_do_Estoril',
#   'circuitName': 'Autódromo do Estoril',
#   'Location': {'lat': '38.7506',
#    'long': '-9.39417',
#    'locality': 'Estoril',
#    'country': 'Portugal'}},
#  'fuji': {'circuitId': 'fuji',
#   'url': 'http://en.wikipedia.org/wiki/Fuji_Speedway',
#   'circuitName': 'Fuji Speedway',
#   'Location': {'lat': '35.3717',
#    'long': '138.927',
#    'locality': 'Oyama',
#    'country': 'Japan'}},
#  'galvez': {'circuitId': 'galvez',
#   'url': 'http://en.wikipedia.org/wiki/Aut%C3%B3dromo_Oscar_Alfredo_G%C3%A1lvez',
#   'circuitName': 'Autódromo Juan y Oscar Gálvez',
#   'Location': {'lat': '-34.6943',
#    'long': '-58.4593',
#    'locality': 'Buenos Aires',
#    'country': 'Argentina'}},
#  'george': {'circuitId': 'george',
#   'url': 'http://en.wikipedia.org/wiki/Prince_George_Circuit',
#   'circuitName': 'Prince George Circuit',
#   'Location': {'lat': '-33.0486',
#    'long': '27.8736',
#    'locality': 'Eastern Cape Province',
#    'country': 'South Africa'}},
#  'hanoi': {'circuitId': 'hanoi',
#   'url': 'http://en.wikipedia.org/wiki/Hanoi_Street_Circuit',
#   'circuitName': 'Hanoi Street Circuit',
#   'Location': {'lat': '21.0166',
#    'long': '105.766',
#    'locality': 'Hanoi',
#    'country': 'Vietnam'}},
#  'hockenheimring': {'circuitId': 'hockenheimring',
#   'url': 'http://en.wikipedia.org/wiki/Hockenheimring',
#   'circuitName': 'Hockenheimring',
#   'Location': {'lat': '49.3278',
#    'long': '8.56583',
#    'locality': 'Hockenheim',
#    'country': 'Germany'}},
#  'hungaroring': {'circuitId': 'hungaroring',
#   'url': 'http://en.wikipedia.org/wiki/Hungaroring',
#   'circuitName': 'Hungaroring',
#   'Location': {'lat': '47.5789',
#    'long': '19.2486',
#    'locality': 'Budapest',
#    'country': 'Hungary'}},
#  'imola': {'circuitId': 'imola',
#   'url': 'http://en.wikipedia.org/wiki/Autodromo_Enzo_e_Dino_Ferrari',
#   'circuitName': 'Autodromo Enzo e Dino Ferrari',
#   'Location': {'lat': '44.3439',
#    'long': '11.7167',
#    'locality': 'Imola',
#    'country': 'Italy'}},
#  'indianapolis': {'circuitId': 'indianapolis',
#   'url': 'http://en.wikipedia.org/wiki/Indianapolis_Motor_Speedway',
#   'circuitName': 'Indianapolis Motor Speedway',
#   'Location': {'lat': '39.795',
#    'long': '-86.2347',
#    'locality': 'Indianapolis',
#    'country': 'USA'}},
#  'interlagos': {'circuitId': 'interlagos',
#   'url': 'http://en.wikipedia.org/wiki/Aut%C3%B3dromo_Jos%C3%A9_Carlos_Pace',
#   'circuitName': 'Autódromo José Carlos Pace',
#   'Location': {'lat': '-23.7036',
#    'long': '-46.6997',
#    'locality': 'São Paulo',
#    'country': 'Brazil'}},
#  'istanbul': {'circuitId': 'istanbul',
#   'url': 'http://en.wikipedia.org/wiki/Istanbul_Park',
#   'circuitName': 'Istanbul Park',
#   'Location': {'lat': '40.9517',
#    'long': '29.405',
#    'locality': 'Istanbul',
#    'country': 'Turkey'}},
#  'jacarepagua': {'circuitId': 'jacarepagua',
#   'url': 'http://en.wikipedia.org/wiki/Aut%C3%B3dromo_Internacional_Nelson_Piquet',
#   'circuitName': 'Autódromo Internacional Nelson Piquet',
#   'Location': {'lat': '-22.9756',
#    'long': '-43.395',
#    'locality': 'Rio de Janeiro',
#    'country': 'Brazil'}},
#  'jarama': {'circuitId': 'jarama',
#   'url': 'http://en.wikipedia.org/wiki/Circuito_Permanente_Del_Jarama',
#   'circuitName': 'Jarama',
#   'Location': {'lat': '40.6171',
#    'long': '-3.58558',
#    'locality': 'Madrid',
#    'country': 'Spain'}},
#  'jerez': {'circuitId': 'jerez',
#   'url': 'http://en.wikipedia.org/wiki/Circuito_Permanente_de_Jerez',
#   'circuitName': 'Circuito de Jerez',
#   'Location': {'lat': '36.7083',
#    'long': '-6.03417',
#    'locality': 'Jerez de la Frontera',
#    'country': 'Spain'}},
#  'kyalami': {'circuitId': 'kyalami',
#   'url': 'http://en.wikipedia.org/wiki/Kyalami',
#   'circuitName': 'Kyalami',
#   'Location': {'lat': '-25.9894',
#    'long': '28.0767',
#    'locality': 'Midrand',
#    'country': 'South Africa'}},
#  'las_vegas': {'circuitId': 'las_vegas',
#   'url': 'http://en.wikipedia.org/wiki/Las_Vegas,_Nevada',
#   'circuitName': 'Las Vegas Street Circuit',
#   'Location': {'lat': '36.1162',
#    'long': '-115.174',
#    'locality': 'Nevada',
#    'country': 'USA'}},
#  'lemans': {'circuitId': 'lemans',
#   'url': 'http://en.wikipedia.org/wiki/Circuit_de_la_Sarthe#Bugatti_Circuit',
#   'circuitName': 'Le Mans',
#   'Location': {'lat': '47.95',
#    'long': '0.224231',
#    'locality': 'Le Mans',
#    'country': 'France'}},
#  'long_beach': {'circuitId': 'long_beach',
#   'url': 'http://en.wikipedia.org/wiki/Long_Beach,_California',
#   'circuitName': 'Long Beach',
#   'Location': {'lat': '33.7651',
#    'long': '-118.189',
#    'locality': 'California',
#    'country': 'USA'}},
#  'magny_cours': {'circuitId': 'magny_cours',
#   'url': 'http://en.wikipedia.org/wiki/Circuit_de_Nevers_Magny-Cours',
#   'circuitName': 'Circuit de Nevers Magny-Cours',
#   'Location': {'lat': '46.8642',
#    'long': '3.16361',
#    'locality': 'Magny Cours',
#    'country': 'France'}},
#  'marina_bay': {'circuitId': 'marina_bay',
#   'url': 'http://en.wikipedia.org/wiki/Marina_Bay_Street_Circuit',
#   'circuitName': 'Marina Bay Street Circuit',
#   'Location': {'lat': '1.2914',
#    'long': '103.864',
#    'locality': 'Marina Bay',
#    'country': 'Singapore'}},
#  'monaco': {'circuitId': 'monaco',
#   'url': 'http://en.wikipedia.org/wiki/Circuit_de_Monaco',
#   'circuitName': 'Circuit de Monaco',
#   'Location': {'lat': '43.7347',
#    'long': '7.42056',
#    'locality': 'Monte-Carlo',
#    'country': 'Monaco'}},
#  'monsanto': {'circuitId': 'monsanto',
#   'url': 'http://en.wikipedia.org/wiki/Monsanto_Park_Circuit',
#   'circuitName': 'Monsanto Park Circuit',
#   'Location': {'lat': '38.7197',
#    'long': '-9.20306',
#    'locality': 'Lisbon',
#    'country': 'Portugal'}},
#  'montjuic': {'circuitId': 'montjuic',
#   'url': 'http://en.wikipedia.org/wiki/Montju%C3%AFc_circuit',
#   'circuitName': 'Montjuïc',
#   'Location': {'lat': '41.3664',
#    'long': '2.15167',
#    'locality': 'Barcelona',
#    'country': 'Spain'}},
#  'monza': {'circuitId': 'monza',
#   'url': 'http://en.wikipedia.org/wiki/Autodromo_Nazionale_Monza',
#   'circuitName': 'Autodromo Nazionale di Monza',
#   'Location': {'lat': '45.6156',
#    'long': '9.28111',
#    'locality': 'Monza',
#    'country': 'Italy'}},
#  'mosport': {'circuitId': 'mosport',
#   'url': 'http://en.wikipedia.org/wiki/Mosport',
#   'circuitName': 'Mosport International Raceway',
#   'Location': {'lat': '44.0481',
#    'long': '-78.6756',
#    'locality': 'Ontario',
#    'country': 'Canada'}},
#  'nivelles': {'circuitId': 'nivelles',
#   'url': 'http://en.wikipedia.org/wiki/Nivelles-Baulers',
#   'circuitName': 'Nivelles-Baulers',
#   'Location': {'lat': '50.6211',
#    'long': '4.32694',
#    'locality': 'Brussels',
#    'country': 'Belgium'}},
#  'nurburgring': {'circuitId': 'nurburgring',
#   'url': 'http://en.wikipedia.org/wiki/N%C3%BCrburgring',
#   'circuitName': 'Nürburgring',
#   'Location': {'lat': '50.3356',
#    'long': '6.9475',
#    'locality': 'Nürburg',
#    'country': 'Germany'}},
#  'okayama': {'circuitId': 'okayama',
#   'url': 'http://en.wikipedia.org/wiki/TI_Circuit',
#   'circuitName': 'Okayama International Circuit',
#   'Location': {'lat': '34.915',
#    'long': '134.221',
#    'locality': 'Okayama',
#    'country': 'Japan'}},
#  'osterreichring': {'circuitId': 'osterreichring',
#   'url': 'http://en.wikipedia.org/wiki/A1-Ring',
#   'circuitName': 'A1-Ring',
#   'Location': {'lat': '47.2197',
#    'long': '14.7647',
#    'locality': 'Spielburg',
#    'country': 'Austria'}},
#  'pedralbes': {'circuitId': 'pedralbes',
#   'url': 'http://en.wikipedia.org/wiki/Pedralbes_Circuit',
#   'circuitName': 'Circuit de Pedralbes',
#   'Location': {'lat': '41.3903',
#    'long': '2.11667',
#    'locality': 'Barcelona',
#    'country': 'Spain'}},
#  'pescara': {'circuitId': 'pescara',
#   'url': 'http://en.wikipedia.org/wiki/Pescara_Circuit',
#   'circuitName': 'Pescara Circuit',
#   'Location': {'lat': '42.475',
#    'long': '14.1508',
#    'locality': 'Pescara',
#    'country': 'Italy'}},
#  'phoenix': {'circuitId': 'phoenix',
#   'url': 'http://en.wikipedia.org/wiki/Phoenix_street_circuit',
#   'circuitName': 'Phoenix street circuit',
#   'Location': {'lat': '33.4479',
#    'long': '-112.075',
#    'locality': 'Phoenix',
#    'country': 'USA'}},
#  'port_imperial': {'circuitId': 'port_imperial',
#   'url': 'http://en.wikipedia.org/wiki/Port_Imperial_Street_Circuit',
#   'circuitName': 'Port Imperial Street Circuit',
#   'Location': {'lat': '40.7769',
#    'long': '-74.0111',
#    'locality': 'New Jersey',
#    'country': 'USA'}},
#  'red_bull_ring': {'circuitId': 'red_bull_ring',
#   'url': 'http://en.wikipedia.org/wiki/Red_Bull_Ring',
#   'circuitName': 'Red Bull Ring',
#   'Location': {'lat': '47.2197',
#    'long': '14.7647',
#    'locality': 'Spielburg',
#    'country': 'Austria'}},
#  'reims': {'circuitId': 'reims',
#   'url': 'http://en.wikipedia.org/wiki/Reims-Gueux',
#   'circuitName': 'Reims-Gueux',
#   'Location': {'lat': '49.2542',
#    'long': '3.93083',
#    'locality': 'Reims',
#    'country': 'France'}},
#  'ricard': {'circuitId': 'ricard',
#   'url': 'http://en.wikipedia.org/wiki/Paul_Ricard_Circuit',
#   'circuitName': 'Circuit Paul Ricard',
#   'Location': {'lat': '43.2506',
#    'long': '5.79167',
#    'locality': 'Le Castellet',
#    'country': 'France'}},
#  'riverside': {'circuitId': 'riverside',
#   'url': 'http://en.wikipedia.org/wiki/Riverside_International_Raceway',
#   'circuitName': 'Riverside International Raceway',
#   'Location': {'lat': '33.937',
#    'long': '-117.273',
#    'locality': 'California',
#    'country': 'USA'}},
#  'rodriguez': {'circuitId': 'rodriguez',
#   'url': 'http://en.wikipedia.org/wiki/Aut%C3%B3dromo_Hermanos_Rodr%C3%ADguez',
#   'circuitName': 'Autódromo Hermanos Rodríguez',
#   'Location': {'lat': '19.4042',
#    'long': '-99.0907',
#    'locality': 'Mexico City',
#    'country': 'Mexico'}},
#  'sebring': {'circuitId': 'sebring',
#   'url': 'http://en.wikipedia.org/wiki/Sebring_Raceway',
#   'circuitName': 'Sebring International Raceway',
#   'Location': {'lat': '27.4547',
#    'long': '-81.3483',
#    'locality': 'Florida',
#    'country': 'USA'}},
#  'sepang': {'circuitId': 'sepang',
#   'url': 'http://en.wikipedia.org/wiki/Sepang_International_Circuit',
#   'circuitName': 'Sepang International Circuit',
#   'Location': {'lat': '2.76083',
#    'long': '101.738',
#    'locality': 'Kuala Lumpur',
#    'country': 'Malaysia'}},
#  'shanghai': {'circuitId': 'shanghai',
#   'url': 'http://en.wikipedia.org/wiki/Shanghai_International_Circuit',
#   'circuitName': 'Shanghai International Circuit',
#   'Location': {'lat': '31.3389',
#    'long': '121.22',
#    'locality': 'Shanghai',
#    'country': 'China'}},
#  'silverstone': {'circuitId': 'silverstone',
#   'url': 'http://en.wikipedia.org/wiki/Silverstone_Circuit',
#   'circuitName': 'Silverstone Circuit',
#   'Location': {'lat': '52.0786',
#    'long': '-1.01694',
#    'locality': 'Silverstone',
#    'country': 'UK'}},
#  'sochi': {'circuitId': 'sochi',
#   'url': 'http://en.wikipedia.org/wiki/Sochi_Autodrom',
#   'circuitName': 'Sochi Autodrom',
#   'Location': {'lat': '43.4057',
#    'long': '39.9578',
#    'locality': 'Sochi',
#    'country': 'Russia'}},
#  'spa': {'circuitId': 'spa',
#   'url': 'http://en.wikipedia.org/wiki/Circuit_de_Spa-Francorchamps',
#   'circuitName': 'Circuit de Spa-Francorchamps',
#   'Location': {'lat': '50.4372',
#    'long': '5.97139',
#    'locality': 'Spa',
#    'country': 'Belgium'}},
#  'suzuka': {'circuitId': 'suzuka',
#   'url': 'http://en.wikipedia.org/wiki/Suzuka_Circuit',
#   'circuitName': 'Suzuka Circuit',
#   'Location': {'lat': '34.8431',
#    'long': '136.541',
#    'locality': 'Suzuka',
#    'country': 'Japan'}},
#  'tremblant': {'circuitId': 'tremblant',
#   'url': 'http://en.wikipedia.org/wiki/Circuit_Mont-Tremblant',
#   'circuitName': 'Circuit Mont-Tremblant',
#   'Location': {'lat': '46.1877',
#    'long': '-74.6099',
#    'locality': 'Quebec',
#    'country': 'Canada'}},
#  'valencia': {'circuitId': 'valencia',
#   'url': 'http://en.wikipedia.org/wiki/Valencia_Street_Circuit',
#   'circuitName': 'Valencia Street Circuit',
#   'Location': {'lat': '39.4589',
#    'long': '-0.331667',
#    'locality': 'Valencia',
#    'country': 'Spain'}},
#  'villeneuve': {'circuitId': 'villeneuve',
#   'url': 'http://en.wikipedia.org/wiki/Circuit_Gilles_Villeneuve',
#   'circuitName': 'Circuit Gilles Villeneuve',
#   'Location': {'lat': '45.5',
#    'long': '-73.5228',
#    'locality': 'Montreal',
#    'country': 'Canada'}},
#  'watkins_glen': {'circuitId': 'watkins_glen',
#   'url': 'http://en.wikipedia.org/wiki/Watkins_Glen_International',
#   'circuitName': 'Watkins Glen',
#   'Location': {'lat': '42.3369',
#    'long': '-76.9272',
#    'locality': 'New York State',
#    'country': 'USA'}},
#  'yas_marina': {'circuitId': 'yas_marina',
#   'url': 'http://en.wikipedia.org/wiki/Yas_Marina_Circuit',
#   'circuitName': 'Yas Marina Circuit',
#   'Location': {'lat': '24.4672',
#    'long': '54.6031',
#    'locality': 'Abu Dhabi',
#    'country': 'UAE'}},
#  'yeongam': {'circuitId': 'yeongam',
#   'url': 'http://en.wikipedia.org/wiki/Korean_International_Circuit',
#   'circuitName': 'Korean International Circuit',
#   'Location': {'lat': '34.7333',
#    'long': '126.417',
#    'locality': 'Yeongam County',
#    'country': 'Korea'}},
#  'zandvoort': {'circuitId': 'zandvoort',
#   'url': 'http://en.wikipedia.org/wiki/Circuit_Zandvoort',
#   'circuitName': 'Circuit Park Zandvoort',
#   'Location': {'lat': '52.3888',
#    'long': '4.54092',
#    'locality': 'Zandvoort',
#    'country': 'Netherlands'}},
#  'zeltweg': {'circuitId': 'zeltweg',
#   'url': 'http://en.wikipedia.org/wiki/Zeltweg_Airfield',
#   'circuitName': 'Zeltweg',
#   'Location': {'lat': '47.2039',
#    'long': '14.7478',
#    'locality': 'Styria',
#    'country': 'Austria'}},
#  'zolder': {'circuitId': 'zolder',
#   'url': 'http://en.wikipedia.org/wiki/Zolder',
#   'circuitName': 'Zolder',
#   'Location': {'lat': '50.9894',
#    'long': '5.25694',
#    'locality': 'Heusden-Zolder',
#    'country': 'Belgium'}}}

# %%
def constructors_info():
    constructors_req = requests.get(site+ constructors+json).json()['MRData']['ConstructorTable']['Constructors']
    constructors_info = {}
    for constructor in constructors_req:
        constructors_info[constructor['constructorId']] = constructor
    return constructors_info
constructors_info = constructors_info()
constructors_info
# Out:
# {'adams': {'constructorId': 'adams',
#   'url': 'http://en.wikipedia.org/wiki/Adams_(constructor)',
#   'name': 'Adams',
#   'nationality': 'American'},
#  'afm': {'constructorId': 'afm',
#   'url': 'http://en.wikipedia.org/wiki/Alex_von_Falkenhausen_Motorenbau',
#   'name': 'AFM',
#   'nationality': 'German'},
#  'ags': {'constructorId': 'ags',
#   'url': 'http://en.wikipedia.org/wiki/Automobiles_Gonfaronnaises_Sportives',
#   'name': 'AGS',
#   'nationality': 'French'},
#  'alfa': {'constructorId': 'alfa',
#   'url': 'http://en.wikipedia.org/wiki/Alfa_Romeo_in_Formula_One',
#   'name': 'Alfa Romeo',
#   'nationality': 'Italian'},
#  'alta': {'constructorId': 'alta',
#   'url': 'http://en.wikipedia.org/wiki/Alta_auto_racing_team',
#   'name': 'Alta',
#   'nationality': 'British'},
#  'amon': {'constructorId': 'amon',
#   'url': 'http://en.wikipedia.org/wiki/Amon_(Formula_One_team)',
#   'name': 'Amon',
#   'nationality': 'New Zealand'},
#  'moda': {'constructorId': 'moda',
#   'url': 'http://en.wikipedia.org/wiki/Andrea_Moda_Formula',
#   'name': 'Andrea Moda',
#   'nationality': 'Italian'},
#  'apollon': {'constructorId': 'apollon',
#   'url': 'http://en.wikipedia.org/wiki/Apollon_(Formula_One)',
#   'name': 'Apollon',
#   'nationality': 'Swiss'},
#  'arrows': {'constructorId': 'arrows',
#   'url': 'http://en.wikipedia.org/wiki/Arrows_Grand_Prix_International',
#   'name': 'Arrows',
#   'nationality': 'British'},
#  'arzani-volpini': {'constructorId': 'arzani-volpini',
#   'url': 'http://en.wikipedia.org/wiki/Arzani-Volpini',
#   'name': 'Arzani-Volpini',
#   'nationality': 'Italian'},
#  'butterworth': {'constructorId': 'butterworth',
#   'url': 'http://en.wikipedia.org/wiki/Aston_Butterworth',
#   'name': 'Aston Butterworth',
#   'nationality': 'British'},
#  'aston_martin': {'constructorId': 'aston_martin',
#   'url': 'http://en.wikipedia.org/wiki/Aston_Martin',
#   'name': 'Aston Martin',
#   'nationality': 'British'},
#  'ats': {'constructorId': 'ats',
#   'url': 'http://en.wikipedia.org/wiki/ATS_(wheels)',
#   'name': 'ATS',
#   'nationality': 'Italian'},
#  'bar': {'constructorId': 'bar',
#   'url': 'http://en.wikipedia.org/wiki/British_American_Racing',
#   'name': 'BAR',
#   'nationality': 'British'},
#  'behra-porsche': {'constructorId': 'behra-porsche',
#   'url': 'http://en.wikipedia.org/wiki/Behra-Porsche',
#   'name': 'Behra-Porsche',
#   'nationality': 'Italian'},
#  'bellasi': {'constructorId': 'bellasi',
#   'url': 'http://en.wikipedia.org/wiki/Bellasi',
#   'name': 'Bellasi',
#   'nationality': 'Swiss'},
#  'benetton': {'constructorId': 'benetton',
#   'url': 'http://en.wikipedia.org/wiki/Benetton_Formula',
#   'name': 'Benetton',
#   'nationality': 'Italian'},
#  'bmw': {'constructorId': 'bmw',
#   'url': 'http://en.wikipedia.org/wiki/BMW',
#   'name': 'BMW',
#   'nationality': 'German'},
#  'bmw_sauber': {'constructorId': 'bmw_sauber',
#   'url': 'http://en.wikipedia.org/wiki/BMW_Sauber',
#   'name': 'BMW Sauber',
#   'nationality': 'German'},
#  'boro': {'constructorId': 'boro',
#   'url': 'http://en.wikipedia.org/wiki/Boro_(Formula_One)',
#   'name': 'Boro',
#   'nationality': 'Dutch'},
#  'brabham': {'constructorId': 'brabham',
#   'url': 'http://en.wikipedia.org/wiki/Brabham',
#   'name': 'Brabham',
#   'nationality': 'British'},
#  'brabham-alfa_romeo': {'constructorId': 'brabham-alfa_romeo',
#   'url': 'http://en.wikipedia.org/wiki/Brabham',
#   'name': 'Brabham-Alfa Romeo',
#   'nationality': 'British'},
#  'brabham-brm': {'constructorId': 'brabham-brm',
#   'url': 'http://en.wikipedia.org/wiki/Brabham',
#   'name': 'Brabham-BRM',
#   'nationality': 'British'},
#  'brabham-climax': {'constructorId': 'brabham-climax',
#   'url': 'http://en.wikipedia.org/wiki/Brabham',
#   'name': 'Brabham-Climax',
#   'nationality': 'British'},
#  'brabham-ford': {'constructorId': 'brabham-ford',
#   'url': 'http://en.wikipedia.org/wiki/Brabham',
#   'name': 'Brabham-Ford',
#   'nationality': 'British'},
#  'brabham-repco': {'constructorId': 'brabham-repco',
#   'url': 'http://en.wikipedia.org/wiki/Brabham',
#   'name': 'Brabham-Repco',
#   'nationality': 'British'},
#  'brawn': {'constructorId': 'brawn',
#   'url': 'http://en.wikipedia.org/wiki/Brawn_GP',
#   'name': 'Brawn',
#   'nationality': 'British'},
#  'brm': {'constructorId': 'brm',
#   'url': 'http://en.wikipedia.org/wiki/BRM',
#   'name': 'BRM',
#   'nationality': 'British'},
#  'brm-ford': {'constructorId': 'brm-ford',
#   'url': 'http://en.wikipedia.org/wiki/BRM',
#   'name': 'BRM-Ford',
#   'nationality': 'British'},
#  'bromme': {'constructorId': 'bromme',
#   'url': 'http://en.wikipedia.org/wiki/Bromme',
#   'name': 'Bromme',
#   'nationality': 'American'},
#  'brp': {'constructorId': 'brp',
#   'url': 'http://en.wikipedia.org/wiki/British_Racing_Partnership',
#   'name': 'BRP',
#   'nationality': 'British'},
#  'bugatti': {'constructorId': 'bugatti',
#   'url': 'http://en.wikipedia.org/wiki/Bugatti',
#   'name': 'Bugatti',
#   'nationality': 'French'},
#  'caterham': {'constructorId': 'caterham',
#   'url': 'http://en.wikipedia.org/wiki/Caterham_F1',
#   'name': 'Caterham',
#   'nationality': 'Malaysian'},
#  'vhristensen': {'constructorId': 'vhristensen',
#   'url': 'http://en.wikipedia.org/wiki/Christensen_(constructor)',
#   'name': 'Christensen',
#   'nationality': 'American'},
#  'cisitalia': {'constructorId': 'cisitalia',
#   'url': 'http://en.wikipedia.org/wiki/Cisitalia',
#   'name': 'Cisitalia',
#   'nationality': 'Italian'},
#  'coloni': {'constructorId': 'coloni',
#   'url': 'http://en.wikipedia.org/wiki/Enzo_Coloni_Racing_Car_Systems',
#   'name': 'Coloni',
#   'nationality': 'Italian'},
#  'connaught': {'constructorId': 'connaught',
#   'url': 'http://en.wikipedia.org/wiki/Connaught_Engineering',
#   'name': 'Connaught',
#   'nationality': 'British'},
#  'connew': {'constructorId': 'connew',
#   'url': 'http://en.wikipedia.org/wiki/Connew',
#   'name': 'Connew',
#   'nationality': 'British'},
#  'cooper': {'constructorId': 'cooper',
#   'url': 'http://en.wikipedia.org/wiki/Cooper_Car_Company',
#   'name': 'Cooper',
#   'nationality': 'British'},
#  'cooper-alfa_romeo': {'constructorId': 'cooper-alfa_romeo',
#   'url': 'http://en.wikipedia.org/wiki/Cooper_Car_Company',
#   'name': 'Cooper-Alfa Romeo',
#   'nationality': 'British'},
#  'cooper-ats': {'constructorId': 'cooper-ats',
#   'url': 'http://en.wikipedia.org/wiki/Cooper_Car_Company',
#   'name': 'Cooper-ATS',
#   'nationality': 'British'},
#  'cooper-borgward': {'constructorId': 'cooper-borgward',
#   'url': 'http://en.wikipedia.org/wiki/Cooper_Car_Company',
#   'name': 'Cooper-Borgward',
#   'nationality': 'British'},
#  'cooper-brm': {'constructorId': 'cooper-brm',
#   'url': 'http://en.wikipedia.org/wiki/Cooper_Car_Company',
#   'name': 'Cooper-BRM',
#   'nationality': 'British'},
#  'cooper-castellotti': {'constructorId': 'cooper-castellotti',
#   'url': 'http://en.wikipedia.org/wiki/Cooper_Car_Company',
#   'name': 'Cooper-Castellotti',
#   'nationality': 'British'},
#  'cooper-climax': {'constructorId': 'cooper-climax',
#   'url': 'http://en.wikipedia.org/wiki/Cooper_Car_Company',
#   'name': 'Cooper-Climax',
#   'nationality': 'British'},
#  'cooper-ferrari': {'constructorId': 'cooper-ferrari',
#   'url': 'http://en.wikipedia.org/wiki/Cooper_Car_Company',
#   'name': 'Cooper-Ferrari',
#   'nationality': 'British'},
#  'cooper-ford': {'constructorId': 'cooper-ford',
#   'url': 'http://en.wikipedia.org/wiki/Cooper_Car_Company',
#   'name': 'Cooper-Ford',
#   'nationality': 'British'},
#  'cooper-maserati': {'constructorId': 'cooper-maserati',
#   'url': 'http://en.wikipedia.org/wiki/Cooper_Car_Company',
#   'name': 'Cooper-Maserati',
#   'nationality': 'British'},
#  'cooper-osca': {'constructorId': 'cooper-osca',
#   'url': 'http://en.wikipedia.org/wiki/Cooper_Car_Company',
#   'name': 'Cooper-OSCA',
#   'nationality': 'British'},
#  'dallara': {'constructorId': 'dallara',
#   'url': 'http://en.wikipedia.org/wiki/Dallara',
#   'name': 'Dallara',
#   'nationality': 'Italian'},
#  'tomaso': {'constructorId': 'tomaso',
#   'url': 'http://en.wikipedia.org/wiki/De_Tomaso',
#   'name': 'De Tomaso',
#   'nationality': 'Italian'},
#  'de_tomaso-alfa_romeo': {'constructorId': 'de_tomaso-alfa_romeo',
#   'url': 'http://en.wikipedia.org/wiki/De_Tomaso',
#   'name': 'De Tomaso-Alfa Romeo',
#   'nationality': 'Italian'},
#  'de_tomaso-ferrari': {'constructorId': 'de_tomaso-ferrari',
#   'url': 'http://en.wikipedia.org/wiki/De_Tomaso',
#   'name': 'De Tomaso-Ferrari',
#   'nationality': 'Italian'},
#  'de_tomaso-osca': {'constructorId': 'de_tomaso-osca',
#   'url': 'http://en.wikipedia.org/wiki/De_Tomaso',
#   'name': 'De Tomaso-Osca',
#   'nationality': 'Italian'},
#  'deidt': {'constructorId': 'deidt',
#   'url': 'http://en.wikipedia.org/wiki/Deidt',
#   'name': 'Deidt',
#   'nationality': 'American'},
#  'del_roy': {'constructorId': 'del_roy',
#   'url': 'http://en.wikipedia.org/wiki/Del_Roy',
#   'name': 'Del Roy',
#   'nationality': 'American'},
#  'derrington': {'constructorId': 'derrington',
#   'url': 'http://en.wikipedia.org/wiki/Derrington-Francis',
#   'name': 'Derrington',
#   'nationality': 'British'},
#  'dunn': {'constructorId': 'dunn',
#   'url': 'http://en.wikipedia.org/wiki/Dunn_Engineering',
#   'name': 'Dunn',
#   'nationality': 'American'},
#  'eagle': {'constructorId': 'eagle',
#   'url': 'http://en.wikipedia.org/wiki/Anglo_American_Racers',
#   'name': 'Eagle',
#   'nationality': 'American'},
#  'eagle-climax': {'constructorId': 'eagle-climax',
#   'url': 'http://en.wikipedia.org/wiki/Anglo_American_Racers',
#   'name': 'Eagle-Climax',
#   'nationality': 'American'},
#  'eagle-weslake': {'constructorId': 'eagle-weslake',
#   'url': 'http://en.wikipedia.org/wiki/Anglo_American_Racers',
#   'name': 'Eagle-Weslake',
#   'nationality': 'American'},
#  'elder': {'constructorId': 'elder',
#   'url': 'http://en.wikipedia.org/wiki/Elder_(constructor)',
#   'name': 'Elder',
#   'nationality': 'American'},
#  'hill': {'constructorId': 'hill',
#   'url': 'http://en.wikipedia.org/wiki/Hill_(constructor)',
#   'name': 'Embassy Hill',
#   'nationality': 'British'},
#  'emeryson': {'constructorId': 'emeryson',
#   'url': 'http://en.wikipedia.org/wiki/Emeryson',
#   'name': 'Emeryson',
#   'nationality': 'British'},
#  'emw': {'constructorId': 'emw',
#   'url': 'http://en.wikipedia.org/wiki/Eisenacher_Motorenwerk',
#   'name': 'EMW',
#   'nationality': 'East German'},
#  'enb': {'constructorId': 'enb',
#   'url': 'http://en.wikipedia.org/wiki/Ecurie_Nationale_Belge',
#   'name': 'ENB',
#   'nationality': 'Belgium'},
#  'ensign': {'constructorId': 'ensign',
#   'url': 'http://en.wikipedia.org/wiki/Ensign_%28racing_team%29',
#   'name': 'Ensign',
#   'nationality': 'British'},
#  'epperly': {'constructorId': 'epperly',
#   'url': 'http://en.wikipedia.org/wiki/Epperly',
#   'name': 'Epperly',
#   'nationality': 'American'},
#  'era': {'constructorId': 'era',
#   'url': 'http://en.wikipedia.org/wiki/English_Racing_Automobiles',
#   'name': 'ERA',
#   'nationality': 'British'},
#  'eurobrun': {'constructorId': 'eurobrun',
#   'url': 'http://en.wikipedia.org/wiki/Euro_Brun',
#   'name': 'Euro Brun',
#   'nationality': 'Italian'},
#  'ewing': {'constructorId': 'ewing',
#   'url': 'http://en.wikipedia.org/wiki/Ewing_(constructor)',
#   'name': 'Ewing',
#   'nationality': 'American'},
#  'ferguson': {'constructorId': 'ferguson',
#   'url': 'http://en.wikipedia.org/wiki/Ferguson_Research_Ltd.',
#   'name': 'Ferguson',
#   'nationality': 'British'},
#  'ferrari': {'constructorId': 'ferrari',
#   'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#   'name': 'Ferrari',
#   'nationality': 'Italian'},
#  'fittipaldi': {'constructorId': 'fittipaldi',
#   'url': 'http://en.wikipedia.org/wiki/Fittipaldi_%28constructor%29',
#   'name': 'Fittipaldi',
#   'nationality': 'Brazilian'},
#  'fondmetal': {'constructorId': 'fondmetal',
#   'url': 'http://en.wikipedia.org/wiki/Fondmetal',
#   'name': 'Fondmetal',
#   'nationality': 'Italian'},
#  'footwork': {'constructorId': 'footwork',
#   'url': 'http://en.wikipedia.org/wiki/Footwork_Arrows',
#   'name': 'Footwork',
#   'nationality': 'British'},
#  'force_india': {'constructorId': 'force_india',
#   'url': 'http://en.wikipedia.org/wiki/Racing_Point_Force_India',
#   'name': 'Force India',
#   'nationality': 'Indian'},
#  'forti': {'constructorId': 'forti',
#   'url': 'http://en.wikipedia.org/wiki/Forti',
#   'name': 'Forti',
#   'nationality': 'Italian'},
#  'frazer_nash': {'constructorId': 'frazer_nash',
#   'url': 'http://en.wikipedia.org/wiki/Frazer_Nash',
#   'name': 'Frazer Nash',
#   'nationality': 'British'},
#  'fry': {'constructorId': 'fry',
#   'url': 'http://en.wikipedia.org/wiki/Fry_(racing_team)',
#   'name': 'Fry',
#   'nationality': 'British'},
#  'gilby': {'constructorId': 'gilby',
#   'url': 'http://en.wikipedia.org/wiki/Gilby',
#   'name': 'Gilby',
#   'nationality': 'British'},
#  'gordini': {'constructorId': 'gordini',
#   'url': 'http://en.wikipedia.org/wiki/Gordini',
#   'name': 'Gordini',
#   'nationality': 'French'},
#  'haas': {'constructorId': 'haas',
#   'url': 'http://en.wikipedia.org/wiki/Haas_F1_Team',
#   'name': 'Haas F1 Team',
#   'nationality': 'American'},
#  'hall': {'constructorId': 'hall',
#   'url': 'http://en.wikipedia.org/wiki/Hall_(constructor)',
#   'name': 'Hall',
#   'nationality': 'American'},
#  'hesketh': {'constructorId': 'hesketh',
#   'url': 'http://en.wikipedia.org/wiki/Hesketh_Racing',
#   'name': 'Hesketh',
#   'nationality': 'British'},
#  'honda': {'constructorId': 'honda',
#   'url': 'http://en.wikipedia.org/wiki/Honda_Racing_F1',
#   'name': 'Honda',
#   'nationality': 'Japanese'},
#  'hrt': {'constructorId': 'hrt',
#   'url': 'http://en.wikipedia.org/wiki/Hispania_Racing',
#   'name': 'HRT',
#   'nationality': 'Spanish'},
#  'hwm': {'constructorId': 'hwm',
#   'url': 'http://en.wikipedia.org/wiki/Hersham_and_Walton_Motors',
#   'name': 'HWM',
#   'nationality': 'British'},
#  'iso_marlboro': {'constructorId': 'iso_marlboro',
#   'url': 'http://en.wikipedia.org/wiki/Iso_Marlboro',
#   'name': 'Iso Marlboro',
#   'nationality': 'British'},
#  'jaguar': {'constructorId': 'jaguar',
#   'url': 'http://en.wikipedia.org/wiki/Jaguar_Racing',
#   'name': 'Jaguar',
#   'nationality': 'British'},
#  'jbw': {'constructorId': 'jbw',
#   'url': 'http://en.wikipedia.org/wiki/JBW',
#   'name': 'JBW',
#   'nationality': 'British'},
#  'jordan': {'constructorId': 'jordan',
#   'url': 'http://en.wikipedia.org/wiki/Jordan_Grand_Prix',
#   'name': 'Jordan',
#   'nationality': 'Irish'},
#  'kauhsen': {'constructorId': 'kauhsen',
#   'url': 'http://en.wikipedia.org/wiki/Kauhsen',
#   'name': 'Kauhsen',
#   'nationality': 'German'},
#  'klenk': {'constructorId': 'klenk',
#   'url': 'http://en.wikipedia.org/wiki/Klenk',
#   'name': 'Klenk',
#   'nationality': 'German'},
#  'kojima': {'constructorId': 'kojima',
#   'url': 'http://en.wikipedia.org/wiki/Kojima_Engineering',
#   'name': 'Kojima',
#   'nationality': 'Japanese'},
#  'kurtis_kraft': {'constructorId': 'kurtis_kraft',
#   'url': 'http://en.wikipedia.org/wiki/Kurtis_Kraft',
#   'name': 'Kurtis Kraft',
#   'nationality': 'American'},
#  'kuzma': {'constructorId': 'kuzma',
#   'url': 'http://en.wikipedia.org/wiki/Kuzma_(constructor)',
#   'name': 'Kuzma',
#   'nationality': 'American'},
#  'lambo': {'constructorId': 'lambo',
#   'url': 'http://en.wikipedia.org/wiki/Modena_(racing_team)',
#   'name': 'Lambo',
#   'nationality': 'Italian'},
#  'lancia': {'constructorId': 'lancia',
#   'url': 'http://en.wikipedia.org/wiki/Lancia_in_Formula_One',
#   'name': 'Lancia',
#   'nationality': 'Italian'},
#  'langley': {'constructorId': 'langley',
#   'url': 'http://en.wikipedia.org/wiki/Langley_(constructor)',
#   'name': 'Langley',
#   'nationality': 'American'},
#  'larrousse': {'constructorId': 'larrousse',
#   'url': 'http://en.wikipedia.org/wiki/Larrousse',
#   'name': 'Larrousse',
#   'nationality': 'French'},
#  'lds': {'constructorId': 'lds',
#   'url': 'http://en.wikipedia.org/wiki/LDS_(automobile)',
#   'name': 'LDS',
#   'nationality': 'South African'},
#  'lds-alfa_romeo': {'constructorId': 'lds-alfa_romeo',
#   'url': 'http://en.wikipedia.org/wiki/LDS_(automobile)',
#   'name': 'LDS-Alfa Romeo',
#   'nationality': 'South African'},
#  'lds-climax': {'constructorId': 'lds-climax',
#   'url': 'http://en.wikipedia.org/wiki/LDS_(automobile)',
#   'name': 'LDS-Climax',
#   'nationality': 'South African'},
#  'lec': {'constructorId': 'lec',
#   'url': 'http://en.wikipedia.org/wiki/LEC_(Formula_One)',
#   'name': 'LEC',
#   'nationality': 'British'},
#  'lesovsky': {'constructorId': 'lesovsky',
#   'url': 'http://en.wikipedia.org/wiki/Lesovsky',
#   'name': 'Lesovsky',
#   'nationality': 'American'},
#  'leyton': {'constructorId': 'leyton',
#   'url': 'http://en.wikipedia.org/wiki/Leyton_House',
#   'name': 'Leyton House',
#   'nationality': 'British'},
#  'life': {'constructorId': 'life',
#   'url': 'http://en.wikipedia.org/wiki/Life_(Racing_Team)',
#   'name': 'Life',
#   'nationality': 'Italian'},
#  'ligier': {'constructorId': 'ligier',
#   'url': 'http://en.wikipedia.org/wiki/Ligier',
#   'name': 'Ligier',
#   'nationality': 'French'},
#  'lola': {'constructorId': 'lola',
#   'url': 'http://en.wikipedia.org/wiki/MasterCard_Lola',
#   'name': 'Lola',
#   'nationality': 'British'},
#  'lotus_racing': {'constructorId': 'lotus_racing',
#   'url': 'http://en.wikipedia.org/wiki/Lotus_Racing',
#   'name': 'Lotus',
#   'nationality': 'Malaysian'},
#  'lotus_f1': {'constructorId': 'lotus_f1',
#   'url': 'http://en.wikipedia.org/wiki/Lotus_F1',
#   'name': 'Lotus F1',
#   'nationality': 'British'},
#  'lotus-borgward': {'constructorId': 'lotus-borgward',
#   'url': 'http://en.wikipedia.org/wiki/Team_Lotus',
#   'name': 'Lotus-Borgward',
#   'nationality': 'British'},
#  'lotus-brm': {'constructorId': 'lotus-brm',
#   'url': 'http://en.wikipedia.org/wiki/Team_Lotus',
#   'name': 'Lotus-BRM',
#   'nationality': 'British'},
#  'lotus-climax': {'constructorId': 'lotus-climax',
#   'url': 'http://en.wikipedia.org/wiki/Team_Lotus',
#   'name': 'Lotus-Climax',
#   'nationality': 'British'},
#  'lotus-ford': {'constructorId': 'lotus-ford',
#   'url': 'http://en.wikipedia.org/wiki/Team_Lotus',
#   'name': 'Lotus-Ford',
#   'nationality': 'British'},
#  'lotus-maserati': {'constructorId': 'lotus-maserati',
#   'url': 'http://en.wikipedia.org/wiki/Team_Lotus',
#   'name': 'Lotus-Maserati',
#   'nationality': 'British'},
#  'lotus-pw': {'constructorId': 'lotus-pw',
#   'url': 'http://en.wikipedia.org/wiki/Team_Lotus',
#   'name': 'Lotus-Pratt &amp; Whitney',
#   'nationality': 'British'},
#  'lyncar': {'constructorId': 'lyncar',
#   'url': 'http://en.wikipedia.org/wiki/Lyncar',
#   'name': 'Lyncar',
#   'nationality': 'British'},
#  'maki': {'constructorId': 'maki',
#   'url': 'http://en.wikipedia.org/wiki/Maki_(cars)',
#   'name': 'Maki',
#   'nationality': 'Japanese'},
#  'manor': {'constructorId': 'manor',
#   'url': 'http://en.wikipedia.org/wiki/Manor_Motorsport',
#   'name': 'Manor Marussia',
#   'nationality': 'British'},
#  'march': {'constructorId': 'march',
#   'url': 'http://en.wikipedia.org/wiki/March_Engineering',
#   'name': 'March',
#   'nationality': 'British'},
#  'march-alfa_romeo': {'constructorId': 'march-alfa_romeo',
#   'url': 'http://en.wikipedia.org/wiki/March_Engineering',
#   'name': 'March-Alfa Romeo',
#   'nationality': 'British'},
#  'march-ford': {'constructorId': 'march-ford',
#   'url': 'http://en.wikipedia.org/wiki/March_Engineering',
#   'name': 'March-Ford',
#   'nationality': 'British'},
#  'marchese': {'constructorId': 'marchese',
#   'url': 'http://en.wikipedia.org/wiki/Marchese_(constructor)',
#   'name': 'Marchese',
#   'nationality': 'American'},
#  'martini': {'constructorId': 'martini',
#   'url': 'http://en.wikipedia.org/wiki/Martini_(cars)',
#   'name': 'Martini',
#   'nationality': 'French'},
#  'marussia': {'constructorId': 'marussia',
#   'url': 'http://en.wikipedia.org/wiki/Marussia_F1',
#   'name': 'Marussia',
#   'nationality': 'Russian'},
#  'maserati': {'constructorId': 'maserati',
#   'url': 'http://en.wikipedia.org/wiki/Maserati',
#   'name': 'Maserati',
#   'nationality': 'Italian'},
#  'matra': {'constructorId': 'matra',
#   'url': 'http://en.wikipedia.org/wiki/Matra',
#   'name': 'Matra',
#   'nationality': 'French'},
#  'matra-ford': {'constructorId': 'matra-ford',
#   'url': 'http://en.wikipedia.org/wiki/Matra',
#   'name': 'Matra-Ford',
#   'nationality': 'French'},
#  'mbm': {'constructorId': 'mbm',
#   'url': 'http://en.wikipedia.org/wiki/Monteverdi_Basel_Motors',
#   'name': 'MBM',
#   'nationality': 'Swiss'},
#  'mcguire': {'constructorId': 'mcguire',
#   'url': 'http://en.wikipedia.org/wiki/McGuire_(Formula_One)',
#   'name': 'McGuire',
#   'nationality': 'Australian'},
#  'mclaren': {'constructorId': 'mclaren',
#   'url': 'http://en.wikipedia.org/wiki/McLaren',
#   'name': 'McLaren',
#   'nationality': 'British'},
#  'mclaren-alfa_romeo': {'constructorId': 'mclaren-alfa_romeo',
#   'url': 'http://en.wikipedia.org/wiki/McLaren_(racing)',
#   'name': 'McLaren-Alfa Romeo',
#   'nationality': 'British'},
#  'mclaren-brm': {'constructorId': 'mclaren-brm',
#   'url': 'http://en.wikipedia.org/wiki/McLaren_(racing)',
#   'name': 'McLaren-BRM',
#   'nationality': 'British'},
#  'mclaren-ford': {'constructorId': 'mclaren-ford',
#   'url': 'http://en.wikipedia.org/wiki/Team_McLaren',
#   'name': 'McLaren-Ford',
#   'nationality': 'British'},
#  'mclaren-seren': {'constructorId': 'mclaren-seren',
#   'url': 'http://en.wikipedia.org/wiki/Team_McLaren',
#   'name': 'McLaren-Serenissima',
#   'nationality': 'British'},
#  'mercedes': {'constructorId': 'mercedes',
#   'url': 'http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One',
#   'name': 'Mercedes',
#   'nationality': 'German'},
#  'merzario': {'constructorId': 'merzario',
#   'url': 'http://en.wikipedia.org/wiki/Merzario',
#   'name': 'Merzario',
#   'nationality': 'Italian'},
#  'meskowski': {'constructorId': 'meskowski',
#   'url': 'http://en.wikipedia.org/wiki/Meskowski',
#   'name': 'Meskowski',
#   'nationality': 'American'},
#  'mf1': {'constructorId': 'mf1',
#   'url': 'http://en.wikipedia.org/wiki/Midland_F1_Racing',
#   'name': 'MF1',
#   'nationality': 'Russian'},
#  'milano': {'constructorId': 'milano',
#   'url': 'http://en.wikipedia.org/wiki/Scuderia_Milano',
#   'name': 'Milano',
#   'nationality': 'Italian'},
#  'minardi': {'constructorId': 'minardi',
#   'url': 'http://en.wikipedia.org/wiki/Minardi',
#   'name': 'Minardi',
#   'nationality': 'Italian'},
#  'moore': {'constructorId': 'moore',
#   'url': 'http://en.wikipedia.org/wiki/Moore_(constructor)',
#   'name': 'Moore',
#   'nationality': 'American'},
#  'nichels': {'constructorId': 'nichels',
#   'url': 'http://en.wikipedia.org/wiki/Nichels',
#   'name': 'Nichels',
#   'nationality': 'American'},
#  'olson': {'constructorId': 'olson',
#   'url': 'http://en.wikipedia.org/wiki/Olson_(constructor)',
#   'name': 'Olson',
#   'nationality': 'American'},
#  'onyx': {'constructorId': 'onyx',
#   'url': 'http://en.wikipedia.org/wiki/Onyx_(racing_team)',
#   'name': 'Onyx',
#   'nationality': 'British'},
#  'osca': {'constructorId': 'osca',
#   'url': 'http://en.wikipedia.org/wiki/Officine_Specializate_Costruzione_Automobili',
#   'name': 'OSCA',
#   'nationality': 'Italian'},
#  'osella': {'constructorId': 'osella',
#   'url': 'http://en.wikipedia.org/wiki/Osella',
#   'name': 'Osella',
#   'nationality': 'Italian'},
#  'pacific': {'constructorId': 'pacific',
#   'url': 'http://en.wikipedia.org/wiki/Pacific_Racing',
#   'name': 'Pacific',
#   'nationality': 'British'},
#  'pankratz': {'constructorId': 'pankratz',
#   'url': 'http://en.wikipedia.org/wiki/Pankratz',
#   'name': 'Pankratz',
#   'nationality': 'American'},
#  'parnelli': {'constructorId': 'parnelli',
#   'url': 'http://en.wikipedia.org/wiki/Parnelli',
#   'name': 'Parnelli',
#   'nationality': 'American'},
#  'pawl': {'constructorId': 'pawl',
#   'url': 'http://en.wikipedia.org/wiki/Pawl_(constructor)',
#   'name': 'Pawl',
#   'nationality': 'American'},
#  'penske': {'constructorId': 'penske',
#   'url': 'http://en.wikipedia.org/wiki/Penske_Racing',
#   'name': 'Penske',
#   'nationality': 'American'},
#  'phillips': {'constructorId': 'phillips',
#   'url': 'http://en.wikipedia.org/wiki/Phillips_(constructor)',
#   'name': 'Phillips',
#   'nationality': 'American'},
#  'politoys': {'constructorId': 'politoys',
#   'url': 'http://en.wikipedia.org/wiki/Frank_Williams_Racing_Cars',
#   'name': 'Politoys',
#   'nationality': 'British'},
#  'porsche': {'constructorId': 'porsche',
#   'url': 'http://en.wikipedia.org/wiki/Porsche_in_Formula_One',
#   'name': 'Porsche',
#   'nationality': 'German'},
#  'prost': {'constructorId': 'prost',
#   'url': 'http://en.wikipedia.org/wiki/Prost_Grand_Prix',
#   'name': 'Prost',
#   'nationality': 'French'},
#  'protos': {'constructorId': 'protos',
#   'url': 'http://en.wikipedia.org/wiki/Protos_(constructor)',
#   'name': 'Protos',
#   'nationality': 'British'},
#  'racing_point': {'constructorId': 'racing_point',
#   'url': 'http://en.wikipedia.org/wiki/Racing_Point_F1_Team',
#   'name': 'Racing Point',
#   'nationality': 'British'},
#  'rae': {'constructorId': 'rae',
#   'url': 'http://en.wikipedia.org/wiki/Rae_(motorsport)',
#   'name': 'Rae',
#   'nationality': 'American'},
#  'ram': {'constructorId': 'ram',
#   'url': 'http://en.wikipedia.org/wiki/RAM_Racing',
#   'name': 'RAM',
#   'nationality': 'British'},
#  're': {'constructorId': 're',
#   'url': 'http://en.wikipedia.org/wiki/RE_%28automobile%29',
#   'name': 'RE',
#   'nationality': 'Rhodesian'},
#  'rebaque': {'constructorId': 'rebaque',
#   'url': 'http://en.wikipedia.org/wiki/Rebaque',
#   'name': 'Rebaque',
#   'nationality': 'Mexican'},
#  'red_bull': {'constructorId': 'red_bull',
#   'url': 'http://en.wikipedia.org/wiki/Red_Bull_Racing',
#   'name': 'Red Bull',
#   'nationality': 'Austrian'},
#  'renault': {'constructorId': 'renault',
#   'url': 'http://en.wikipedia.org/wiki/Renault_in_Formula_One',
#   'name': 'Renault',
#   'nationality': 'French'},
#  'rial': {'constructorId': 'rial',
#   'url': 'http://en.wikipedia.org/wiki/Rial_%28racing_team%29',
#   'name': 'Rial',
#   'nationality': 'German'},
#  'sauber': {'constructorId': 'sauber',
#   'url': 'http://en.wikipedia.org/wiki/Sauber',
#   'name': 'Sauber',
#   'nationality': 'Swiss'},
#  'scarab': {'constructorId': 'scarab',
#   'url': 'http://en.wikipedia.org/wiki/Scarab_(constructor)',
#   'name': 'Scarab',
#   'nationality': 'American'},
#  'schroeder': {'constructorId': 'schroeder',
#   'url': 'http://en.wikipedia.org/wiki/Schroeder_(constructor)',
#   'name': 'Schroeder',
#   'nationality': 'American'},
#  'scirocco': {'constructorId': 'scirocco',
#   'url': 'http://en.wikipedia.org/wiki/Scirocco-Powell',
#   'name': 'Scirocco',
#   'nationality': 'British'},
#  'alpha_tauri': {'constructorId': 'alpha_tauri',
#   'url': 'http://en.wikipedia.org/wiki/Scuderia_Alpha_Tauri',
#   'name': 'Scuderia Alpha Tauri',
#   'nationality': 'Italian'},
#  'shadow': {'constructorId': 'shadow',
#   'url': 'http://en.wikipedia.org/wiki/Shadow_Racing_Cars',
#   'name': 'Shadow',
#   'nationality': 'British'},
#  'shadow-ford': {'constructorId': 'shadow-ford',
#   'url': 'http://en.wikipedia.org/wiki/Shadow_Racing_Cars',
#   'name': 'Shadow-Ford',
#   'nationality': 'British'},
#  'shadow-matra': {'constructorId': 'shadow-matra',
#   'url': 'http://en.wikipedia.org/wiki/Shadow_Racing_Cars',
#   'name': 'Shadow-Matra',
#   'nationality': 'British'},
#  'shannon': {'constructorId': 'shannon',
#   'url': 'http://en.wikipedia.org/wiki/Shannon_(Formula_One)',
#   'name': 'Shannon',
#   'nationality': 'British'},
#  'sherman': {'constructorId': 'sherman',
#   'url': 'http://en.wikipedia.org/wiki/Sherman_(constructor)',
#   'name': 'Sherman',
#   'nationality': 'American'},
#  'simca': {'constructorId': 'simca',
#   'url': 'http://en.wikipedia.org/wiki/Simca',
#   'name': 'Simca',
#   'nationality': 'French'},
#  'simtek': {'constructorId': 'simtek',
#   'url': 'http://en.wikipedia.org/wiki/Simtek',
#   'name': 'Simtek',
#   'nationality': 'British'},
#  'snowberger': {'constructorId': 'snowberger',
#   'url': 'http://en.wikipedia.org/wiki/Snowberger',
#   'name': 'Snowberger',
#   'nationality': 'American'},
#  'spirit': {'constructorId': 'spirit',
#   'url': 'http://en.wikipedia.org/wiki/Spirit_(racing_team)',
#   'name': 'Spirit',
#   'nationality': 'British'},
#  'spyker': {'constructorId': 'spyker',
#   'url': 'http://en.wikipedia.org/wiki/Spyker_F1',
#   'name': 'Spyker',
#   'nationality': 'Dutch'},
#  'spyker_mf1': {'constructorId': 'spyker_mf1',
#   'url': 'http://en.wikipedia.org/wiki/Midland_F1_Racing',
#   'name': 'Spyker MF1',
#   'nationality': 'Dutch'},
#  'stebro': {'constructorId': 'stebro',
#   'url': 'http://en.wikipedia.org/wiki/Stebro',
#   'name': 'Stebro',
#   'nationality': 'Canadian'},
#  'stevens': {'constructorId': 'stevens',
#   'url': 'http://en.wikipedia.org/wiki/Stevens_(constructor)',
#   'name': 'Stevens',
#   'nationality': 'American'},
#  'stewart': {'constructorId': 'stewart',
#   'url': 'http://en.wikipedia.org/wiki/Stewart_Grand_Prix',
#   'name': 'Stewart',
#   'nationality': 'British'},
#  'super_aguri': {'constructorId': 'super_aguri',
#   'url': 'http://en.wikipedia.org/wiki/Super_Aguri_F1',
#   'name': 'Super Aguri',
#   'nationality': 'Japanese'},
#  'surtees': {'constructorId': 'surtees',
#   'url': 'http://en.wikipedia.org/wiki/Surtees',
#   'name': 'Surtees',
#   'nationality': 'British'},
#  'sutton': {'constructorId': 'sutton',
#   'url': 'http://en.wikipedia.org/wiki/Sutton_(constructor)',
#   'name': 'Sutton',
#   'nationality': 'American'},
#  'lago': {'constructorId': 'lago',
#   'url': 'http://en.wikipedia.org/wiki/Talbot-Lago',
#   'name': 'Talbot-Lago',
#   'nationality': 'French'},
#  'team_lotus': {'constructorId': 'team_lotus',
#   'url': 'http://en.wikipedia.org/wiki/Team_Lotus',
#   'name': 'Team Lotus',
#   'nationality': 'British'},
#  'tec-mec': {'constructorId': 'tec-mec',
#   'url': 'http://en.wikipedia.org/wiki/Tec-Mec',
#   'name': 'Tec-Mec',
#   'nationality': 'Italian'},
#  'tecno': {'constructorId': 'tecno',
#   'url': 'http://en.wikipedia.org/wiki/Tecno',
#   'name': 'Tecno',
#   'nationality': 'Italian'},
#  'theodore': {'constructorId': 'theodore',
#   'url': 'http://en.wikipedia.org/wiki/Theodore_Racing',
#   'name': 'Theodore',
#   'nationality': 'Hong Kong'},
#  'token': {'constructorId': 'token',
#   'url': 'http://en.wikipedia.org/wiki/Token_(Racing_team)',
#   'name': 'Token',
#   'nationality': 'British'},
#  'toleman': {'constructorId': 'toleman',
#   'url': 'http://en.wikipedia.org/wiki/Toleman',
#   'name': 'Toleman',
#   'nationality': 'British'},
#  'toro_rosso': {'constructorId': 'toro_rosso',
#   'url': 'http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso',
#   'name': 'Toro Rosso',
#   'nationality': 'Italian'},
#  'toyota': {'constructorId': 'toyota',
#   'url': 'http://en.wikipedia.org/wiki/Toyota_Racing',
#   'name': 'Toyota',
#   'nationality': 'Japanese'},
#  'trevis': {'constructorId': 'trevis',
#   'url': 'http://en.wikipedia.org/wiki/Trevis',
#   'name': 'Trevis',
#   'nationality': 'American'},
#  'trojan': {'constructorId': 'trojan',
#   'url': 'http://en.wikipedia.org/wiki/Trojan_(Racing_team)',
#   'name': 'Trojan',
#   'nationality': 'British'},
#  'turner': {'constructorId': 'turner',
#   'url': 'http://en.wikipedia.org/wiki/Turner_(constructor)',
#   'name': 'Turner',
#   'nationality': 'American'},
#  'tyrrell': {'constructorId': 'tyrrell',
#   'url': 'http://en.wikipedia.org/wiki/Tyrrell_Racing',
#   'name': 'Tyrrell',
#   'nationality': 'British'},
#  'vanwall': {'constructorId': 'vanwall',
#   'url': 'http://en.wikipedia.org/wiki/Vanwall',
#   'name': 'Vanwall',
#   'nationality': 'British'},
#  'veritas': {'constructorId': 'veritas',
#   'url': 'http://en.wikipedia.org/wiki/Veritas_(constructor)',
#   'name': 'Veritas',
#   'nationality': 'German'},
#  'virgin': {'constructorId': 'virgin',
#   'url': 'http://en.wikipedia.org/wiki/Virgin_Racing',
#   'name': 'Virgin',
#   'nationality': 'British'},
#  'watson': {'constructorId': 'watson',
#   'url': 'http://en.wikipedia.org/wiki/A.J._Watson',
#   'name': 'Watson',
#   'nationality': 'American'},
#  'wetteroth': {'constructorId': 'wetteroth',
#   'url': 'http://en.wikipedia.org/wiki/Wetteroth',
#   'name': 'Wetteroth',
#   'nationality': 'American'},
#  'williams': {'constructorId': 'williams',
#   'url': 'http://en.wikipedia.org/wiki/Williams_Grand_Prix_Engineering',
#   'name': 'Williams',
#   'nationality': 'British'},
#  'wolf': {'constructorId': 'wolf',
#   'url': 'http://en.wikipedia.org/wiki/Walter_Wolf_Racing',
#   'name': 'Wolf',
#   'nationality': 'Canadian'},
#  'zakspeed': {'constructorId': 'zakspeed',
#   'url': 'http://en.wikipedia.org/wiki/Zakspeed',
#   'name': 'Zakspeed',
#   'nationality': 'German'}}

# %%
def all_races(from_year, to_year):
    
    driver_race = {}
    total_races = []
    result_fields = ['position', 'points', 'laps']
    
    for y in season_drivers(from_year,to_year).keys():       
        for driver in season_drivers(y, y+1)[y]:
            driver_req = requests.get(site+str(y)+'/drivers/'+driver['driverId']+'/results.json').json()['MRData']['RaceTable']['Races']
            driver_race[driver['driverId']] = driver_req
            for race in driver_race[driver['driverId']]:
                current_race = ([driver['driverId'], 
                                y,
                                race['round'],
                                race['Circuit']['circuitId'],
                                race['Results'][0]['Constructor']['constructorId'],
                                race['Results'][0]['status'],
                                ] + 
                                [race['Results'][0][field] for field in result_fields])
                if race['Results'][0]['status'] == 'Finished':
                    current_race = current_race + [race['Results'][0]['Time']['time']]
                else:
                    current_race = current_race + ['N/A']
                if 'FastestLap' in race['Results'][0]:
                    current_race = (current_race + 
                    [race['Results'][0]['FastestLap']['Time']['time'],
                    race['Results'][0]['FastestLap']['lap'],
                    race['Results'][0]['FastestLap']['rank'],
                    race['Results'][0]['FastestLap']['AverageSpeed']['speed']])
                else:
                    current_race = (current_race + [['N/A'],['N/A'],['N/A'],['N/A']])
                total_races.append(current_race)
    return total_races

# %%
df_races = pd.read_csv('Data_F1_Attempt',index_col = 0)
df_races
# Out:
#            driver  year  round       circuit   constructor      status  \
# 0            ader  1950      3  indianapolis           rae    +15 Laps
# 1      agabashian  1950      3  indianapolis  kurtis_kraft    Oil leak
# 2          ascari  1950      2        monaco       ferrari      +1 Lap
# 3          ascari  1950      4    bremgarten       ferrari    Oil pump
# 4          ascari  1950      5           spa       ferrari      +1 Lap
# ...           ...   ...    ...           ...           ...         ...
# 24524      vettel  2019     17        suzuka       ferrari    Finished
# 24525      vettel  2019     18     rodriguez       ferrari    Finished
# 24526      vettel  2019     19      americas       ferrari  Suspension
# 24527      vettel  2019     20    interlagos       ferrari   Collision
# 24528      vettel  2019     21    yas_marina       ferrari    Finished
#
#        position  points  laps fastest_lap_time   lap  fastest_lap_rank  \
# 0            22     0.0   123              NaN   NaN               NaN
# 1            28     0.0    64              NaN   NaN               NaN
# 2             2     6.0    99              NaN   NaN               NaN
# 3            17     0.0     4              NaN   NaN               NaN
# 4             5     2.0    34              NaN   NaN               NaN
# ...         ...     ...   ...              ...   ...               ...
# 24524         2    18.0    52         1:32.122  38.0               5.0
# 24525         2    18.0    71         1:19.381  68.0               3.0
# 24526        20     0.0     7         1:42.165   6.0              19.0
# 24527        17     0.0    65         1:11.384  51.0               5.0
# 24528         5    10.0    55         1:40.128  55.0               3.0
#
#        average_speed
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 24524        226.929
# 24525        195.190
# 24526        194.262
# 24527        217.309
# 24528        199.688
#
# [24529 rows x 13 columns]

# %%
df_races = pd.DataFrame(all_races(1950,2020), columns=['driver', 'year', 'round', 'circuit', 'constructor','status', 'position', 'points', 'laps','race_time', 'fastest_lap_time','lap', 'fastest_lap_rank','average_speed'])
df_races
df_races.to_csv('Data_F1_2')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-c530e4033821> in <module>
# ----> 1 df_races = pd.DataFrame(all_races(1950,2020), columns=['driver', 'year', 'round', 'circuit', 'constructor','status', 'position', 'points', 'laps','race_time', 'fastest_lap_time','lap', 'fastest_lap_rank','average_speed'])
#       2 df_races
#       3 df_races.to_csv('Data_F1_2')
#
# <ipython-input-22-3827ffa52b2f> in all_races(from_year, to_year)
#      19                                 [race['Results'][0][field] for field in result_fields])
#      20                 if race['Results'][0]['status'] == 'Finished':
# ---> 21                     current_race = current_race + [race['Results'][0]['Time']['time']]
#      22                 else:
#      23                     current_race = current_race + ['N/A']
#
# KeyError: 'Time'

# %%
df_races['fastestlap']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3d4816ae1d68> in <module>
# ----> 1 df_races['fastestlap']
#
# NameError: name 'df_races' is not defined

# %%
def attempts_fastestlap(from_year, to_year):
    
    driver_race = {}
    total_races = []
    result_fields = ['position', 'points', 'laps'] 
    
    for y in season_drivers(from_year,to_year).keys():       
        for driver in season_drivers(y, y+1)[y]:
            driver_req = requests.get(site+str(y)+'/drivers/'+driver['driverId']+'/results.json').json()['MRData']['RaceTable']['Races']
            driver_race[driver['driverId']] = driver_req
            for race in driver_race[driver['driverId']]:
                current_race = ([driver['driverId'], 
                                y,
                                race['round'],
                                race['Circuit']['circuitId'],
                                race['Results'][0]['Constructor']['constructorId']
                                ] + 
                                [race['Results'][0][field] for field in result_fields])
                total_races.append(current_race)
    return total_races
attempt = attempts_fastestlap(2005,2006)

# %%
df_races = season_drivers(2005,2006)
df_races
# Out:
# {2005: [{'driverId': 'albers',
#    'code': 'ALB',
#    'url': 'http://en.wikipedia.org/wiki/Christijan_Albers',
#    'givenName': 'Christijan',
#    'familyName': 'Albers',
#    'dateOfBirth': '1979-04-16',
#    'nationality': 'Dutch'},
#   {'driverId': 'alonso',
#    'permanentNumber': '14',
#    'code': 'ALO',
#    'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#    'givenName': 'Fernando',
#    'familyName': 'Alonso',
#    'dateOfBirth': '1981-07-29',
#    'nationality': 'Spanish'},
#   {'driverId': 'barrichello',
#    'code': 'BAR',
#    'url': 'http://en.wikipedia.org/wiki/Rubens_Barrichello',
#    'givenName': 'Rubens',
#    'familyName': 'Barrichello',
#    'dateOfBirth': '1972-05-23',
#    'nationality': 'Brazilian'},
#   {'driverId': 'button',
#    'permanentNumber': '22',
#    'code': 'BUT',
#    'url': 'http://en.wikipedia.org/wiki/Jenson_Button',
#    'givenName': 'Jenson',
#    'familyName': 'Button',
#    'dateOfBirth': '1980-01-19',
#    'nationality': 'British'},
#   {'driverId': 'coulthard',
#    'code': 'COU',
#    'url': 'http://en.wikipedia.org/wiki/David_Coulthard',
#    'givenName': 'David',
#    'familyName': 'Coulthard',
#    'dateOfBirth': '1971-03-27',
#    'nationality': 'British'},
#   {'driverId': 'davidson',
#    'code': 'DAV',
#    'url': 'http://en.wikipedia.org/wiki/Anthony_Davidson',
#    'givenName': 'Anthony',
#    'familyName': 'Davidson',
#    'dateOfBirth': '1979-04-18',
#    'nationality': 'British'},
#   {'driverId': 'rosa',
#    'code': 'DLR',
#    'url': 'http://en.wikipedia.org/wiki/Pedro_de_la_Rosa',
#    'givenName': 'Pedro',
#    'familyName': 'de la Rosa',
#    'dateOfBirth': '1971-02-24',
#    'nationality': 'Spanish'},
#   {'driverId': 'doornbos',
#    'code': 'DOO',
#    'url': 'http://en.wikipedia.org/wiki/Robert_Doornbos',
#    'givenName': 'Robert',
#    'familyName': 'Doornbos',
#    'dateOfBirth': '1981-09-23',
#    'nationality': 'Dutch'},
#   {'driverId': 'fisichella',
#    'code': 'FIS',
#    'url': 'http://en.wikipedia.org/wiki/Giancarlo_Fisichella',
#    'givenName': 'Giancarlo',
#    'familyName': 'Fisichella',
#    'dateOfBirth': '1973-01-14',
#    'nationality': 'Italian'},
#   {'driverId': 'friesacher',
#    'code': 'FRI',
#    'url': 'http://en.wikipedia.org/wiki/Patrick_Friesacher',
#    'givenName': 'Patrick',
#    'familyName': 'Friesacher',
#    'dateOfBirth': '1980-09-26',
#    'nationality': 'Austrian'},
#   {'driverId': 'heidfeld',
#    'code': 'HEI',
#    'url': 'http://en.wikipedia.org/wiki/Nick_Heidfeld',
#    'givenName': 'Nick',
#    'familyName': 'Heidfeld',
#    'dateOfBirth': '1977-05-10',
#    'nationality': 'German'},
#   {'driverId': 'karthikeyan',
#    'code': 'KAR',
#    'url': 'http://en.wikipedia.org/wiki/Narain_Karthikeyan',
#    'givenName': 'Narain',
#    'familyName': 'Karthikeyan',
#    'dateOfBirth': '1977-01-14',
#    'nationality': 'Indian'},
#   {'driverId': 'klien',
#    'code': 'KLI',
#    'url': 'http://en.wikipedia.org/wiki/Christian_Klien',
#    'givenName': 'Christian',
#    'familyName': 'Klien',
#    'dateOfBirth': '1983-02-07',
#    'nationality': 'Austrian'},
#   {'driverId': 'liuzzi',
#    'code': 'LIU',
#    'url': 'http://en.wikipedia.org/wiki/Vitantonio_Liuzzi',
#    'givenName': 'Vitantonio',
#    'familyName': 'Liuzzi',
#    'dateOfBirth': '1980-08-06',
#    'nationality': 'Italian'},
#   {'driverId': 'massa',
#    'permanentNumber': '19',
#    'code': 'MAS',
#    'url': 'http://en.wikipedia.org/wiki/Felipe_Massa',
#    'givenName': 'Felipe',
#    'familyName': 'Massa',
#    'dateOfBirth': '1981-04-25',
#    'nationality': 'Brazilian'},
#   {'driverId': 'monteiro',
#    'code': 'TMO',
#    'url': 'http://en.wikipedia.org/wiki/Tiago_Monteiro',
#    'givenName': 'Tiago',
#    'familyName': 'Monteiro',
#    'dateOfBirth': '1976-07-24',
#    'nationality': 'Portuguese'},
#   {'driverId': 'montoya',
#    'code': 'MON',
#    'url': 'http://en.wikipedia.org/wiki/Juan_Pablo_Montoya',
#    'givenName': 'Juan',
#    'familyName': 'Pablo Montoya',
#    'dateOfBirth': '1975-09-20',
#    'nationality': 'Colombian'},
#   {'driverId': 'pizzonia',
#    'code': 'PIZ',
#    'url': 'http://en.wikipedia.org/wiki/Ant%C3%B4nio_Pizzonia',
#    'givenName': 'Antônio',
#    'familyName': 'Pizzonia',
#    'dateOfBirth': '1980-09-11',
#    'nationality': 'Brazilian'},
#   {'driverId': 'raikkonen',
#    'permanentNumber': '7',
#    'code': 'RAI',
#    'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#    'givenName': 'Kimi',
#    'familyName': 'Räikkönen',
#    'dateOfBirth': '1979-10-17',
#    'nationality': 'Finnish'},
#   {'driverId': 'sato',
#    'code': 'SAT',
#    'url': 'http://en.wikipedia.org/wiki/Takuma_Sato',
#    'givenName': 'Takuma',
#    'familyName': 'Sato',
#    'dateOfBirth': '1977-01-28',
#    'nationality': 'Japanese'},
#   {'driverId': 'michael_schumacher',
#    'code': 'MSC',
#    'url': 'http://en.wikipedia.org/wiki/Michael_Schumacher',
#    'givenName': 'Michael',
#    'familyName': 'Schumacher',
#    'dateOfBirth': '1969-01-03',
#    'nationality': 'German'},
#   {'driverId': 'ralf_schumacher',
#    'code': 'SCH',
#    'url': 'http://en.wikipedia.org/wiki/Ralf_Schumacher',
#    'givenName': 'Ralf',
#    'familyName': 'Schumacher',
#    'dateOfBirth': '1975-06-30',
#    'nationality': 'German'},
#   {'driverId': 'trulli',
#    'code': 'TRU',
#    'url': 'http://en.wikipedia.org/wiki/Jarno_Trulli',
#    'givenName': 'Jarno',
#    'familyName': 'Trulli',
#    'dateOfBirth': '1974-07-13',
#    'nationality': 'Italian'},
#   {'driverId': 'villeneuve',
#    'code': 'VIL',
#    'url': 'http://en.wikipedia.org/wiki/Jacques_Villeneuve',
#    'givenName': 'Jacques',
#    'familyName': 'Villeneuve',
#    'dateOfBirth': '1971-04-09',
#    'nationality': 'Canadian'},
#   {'driverId': 'webber',
#    'code': 'WEB',
#    'url': 'http://en.wikipedia.org/wiki/Mark_Webber',
#    'givenName': 'Mark',
#    'familyName': 'Webber',
#    'dateOfBirth': '1976-08-27',
#    'nationality': 'Australian'},
#   {'driverId': 'wurz',
#    'code': 'WUR',
#    'url': 'http://en.wikipedia.org/wiki/Alexander_Wurz',
#    'givenName': 'Alexander',
#    'familyName': 'Wurz',
#    'dateOfBirth': '1974-02-15',
#    'nationality': 'Austrian'},
#   {'driverId': 'zonta',
#    'code': 'ZON',
#    'url': 'http://en.wikipedia.org/wiki/Ricardo_Zonta',
#    'givenName': 'Ricardo',
#    'familyName': 'Zonta',
#    'dateOfBirth': '1976-03-23',
#    'nationality': 'Brazilian'}],
#  2006: [{'driverId': 'albers',
#    'code': 'ALB',
#    'url': 'http://en.wikipedia.org/wiki/Christijan_Albers',
#    'givenName': 'Christijan',
#    'familyName': 'Albers',
#    'dateOfBirth': '1979-04-16',
#    'nationality': 'Dutch'},
#   {'driverId': 'alonso',
#    'permanentNumber': '14',
#    'code': 'ALO',
#    'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#    'givenName': 'Fernando',
#    'familyName': 'Alonso',
#    'dateOfBirth': '1981-07-29',
#    'nationality': 'Spanish'},
#   {'driverId': 'barrichello',
#    'code': 'BAR',
#    'url': 'http://en.wikipedia.org/wiki/Rubens_Barrichello',
#    'givenName': 'Rubens',
#    'familyName': 'Barrichello',
#    'dateOfBirth': '1972-05-23',
#    'nationality': 'Brazilian'},
#   {'driverId': 'button',
#    'permanentNumber': '22',
#    'code': 'BUT',
#    'url': 'http://en.wikipedia.org/wiki/Jenson_Button',
#    'givenName': 'Jenson',
#    'familyName': 'Button',
#    'dateOfBirth': '1980-01-19',
#    'nationality': 'British'},
#   {'driverId': 'coulthard',
#    'code': 'COU',
#    'url': 'http://en.wikipedia.org/wiki/David_Coulthard',
#    'givenName': 'David',
#    'familyName': 'Coulthard',
#    'dateOfBirth': '1971-03-27',
#    'nationality': 'British'},
#   {'driverId': 'rosa',
#    'code': 'DLR',
#    'url': 'http://en.wikipedia.org/wiki/Pedro_de_la_Rosa',
#    'givenName': 'Pedro',
#    'familyName': 'de la Rosa',
#    'dateOfBirth': '1971-02-24',
#    'nationality': 'Spanish'},
#   {'driverId': 'doornbos',
#    'code': 'DOO',
#    'url': 'http://en.wikipedia.org/wiki/Robert_Doornbos',
#    'givenName': 'Robert',
#    'familyName': 'Doornbos',
#    'dateOfBirth': '1981-09-23',
#    'nationality': 'Dutch'},
#   {'driverId': 'fisichella',
#    'code': 'FIS',
#    'url': 'http://en.wikipedia.org/wiki/Giancarlo_Fisichella',
#    'givenName': 'Giancarlo',
#    'familyName': 'Fisichella',
#    'dateOfBirth': '1973-01-14',
#    'nationality': 'Italian'},
#   {'driverId': 'heidfeld',
#    'code': 'HEI',
#    'url': 'http://en.wikipedia.org/wiki/Nick_Heidfeld',
#    'givenName': 'Nick',
#    'familyName': 'Heidfeld',
#    'dateOfBirth': '1977-05-10',
#    'nationality': 'German'},
#   {'driverId': 'ide',
#    'code': 'IDE',
#    'url': 'http://en.wikipedia.org/wiki/Yuji_Ide',
#    'givenName': 'Yuji',
#    'familyName': 'Ide',
#    'dateOfBirth': '1975-01-21',
#    'nationality': 'Japanese'},
#   {'driverId': 'klien',
#    'code': 'KLI',
#    'url': 'http://en.wikipedia.org/wiki/Christian_Klien',
#    'givenName': 'Christian',
#    'familyName': 'Klien',
#    'dateOfBirth': '1983-02-07',
#    'nationality': 'Austrian'},
#   {'driverId': 'kubica',
#    'permanentNumber': '88',
#    'code': 'KUB',
#    'url': 'http://en.wikipedia.org/wiki/Robert_Kubica',
#    'givenName': 'Robert',
#    'familyName': 'Kubica',
#    'dateOfBirth': '1984-12-07',
#    'nationality': 'Polish'},
#   {'driverId': 'liuzzi',
#    'code': 'LIU',
#    'url': 'http://en.wikipedia.org/wiki/Vitantonio_Liuzzi',
#    'givenName': 'Vitantonio',
#    'familyName': 'Liuzzi',
#    'dateOfBirth': '1980-08-06',
#    'nationality': 'Italian'},
#   {'driverId': 'massa',
#    'permanentNumber': '19',
#    'code': 'MAS',
#    'url': 'http://en.wikipedia.org/wiki/Felipe_Massa',
#    'givenName': 'Felipe',
#    'familyName': 'Massa',
#    'dateOfBirth': '1981-04-25',
#    'nationality': 'Brazilian'},
#   {'driverId': 'montagny',
#    'code': 'FMO',
#    'url': 'http://en.wikipedia.org/wiki/Franck_Montagny',
#    'givenName': 'Franck',
#    'familyName': 'Montagny',
#    'dateOfBirth': '1978-01-05',
#    'nationality': 'French'},
#   {'driverId': 'monteiro',
#    'code': 'TMO',
#    'url': 'http://en.wikipedia.org/wiki/Tiago_Monteiro',
#    'givenName': 'Tiago',
#    'familyName': 'Monteiro',
#    'dateOfBirth': '1976-07-24',
#    'nationality': 'Portuguese'},
#   {'driverId': 'montoya',
#    'code': 'MON',
#    'url': 'http://en.wikipedia.org/wiki/Juan_Pablo_Montoya',
#    'givenName': 'Juan',
#    'familyName': 'Pablo Montoya',
#    'dateOfBirth': '1975-09-20',
#    'nationality': 'Colombian'},
#   {'driverId': 'raikkonen',
#    'permanentNumber': '7',
#    'code': 'RAI',
#    'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#    'givenName': 'Kimi',
#    'familyName': 'Räikkönen',
#    'dateOfBirth': '1979-10-17',
#    'nationality': 'Finnish'},
#   {'driverId': 'rosberg',
#    'permanentNumber': '6',
#    'code': 'ROS',
#    'url': 'http://en.wikipedia.org/wiki/Nico_Rosberg',
#    'givenName': 'Nico',
#    'familyName': 'Rosberg',
#    'dateOfBirth': '1985-06-27',
#    'nationality': 'German'},
#   {'driverId': 'sato',
#    'code': 'SAT',
#    'url': 'http://en.wikipedia.org/wiki/Takuma_Sato',
#    'givenName': 'Takuma',
#    'familyName': 'Sato',
#    'dateOfBirth': '1977-01-28',
#    'nationality': 'Japanese'},
#   {'driverId': 'ralf_schumacher',
#    'code': 'SCH',
#    'url': 'http://en.wikipedia.org/wiki/Ralf_Schumacher',
#    'givenName': 'Ralf',
#    'familyName': 'Schumacher',
#    'dateOfBirth': '1975-06-30',
#    'nationality': 'German'},
#   {'driverId': 'michael_schumacher',
#    'code': 'MSC',
#    'url': 'http://en.wikipedia.org/wiki/Michael_Schumacher',
#    'givenName': 'Michael',
#    'familyName': 'Schumacher',
#    'dateOfBirth': '1969-01-03',
#    'nationality': 'German'},
#   {'driverId': 'speed',
#    'code': 'SPE',
#    'url': 'http://en.wikipedia.org/wiki/Scott_Speed',
#    'givenName': 'Scott',
#    'familyName': 'Speed',
#    'dateOfBirth': '1983-01-24',
#    'nationality': 'American'},
#   {'driverId': 'trulli',
#    'code': 'TRU',
#    'url': 'http://en.wikipedia.org/wiki/Jarno_Trulli',
#    'givenName': 'Jarno',
#    'familyName': 'Trulli',
#    'dateOfBirth': '1974-07-13',
#    'nationality': 'Italian'},
#   {'driverId': 'villeneuve',
#    'code': 'VIL',
#    'url': 'http://en.wikipedia.org/wiki/Jacques_Villeneuve',
#    'givenName': 'Jacques',
#    'familyName': 'Villeneuve',
#    'dateOfBirth': '1971-04-09',
#    'nationality': 'Canadian'},
#   {'driverId': 'webber',
#    'code': 'WEB',
#    'url': 'http://en.wikipedia.org/wiki/Mark_Webber',
#    'givenName': 'Mark',
#    'familyName': 'Webber',
#    'dateOfBirth': '1976-08-27',
#    'nationality': 'Australian'},
#   {'driverId': 'yamamoto',
#    'code': 'YAM',
#    'url': 'http://en.wikipedia.org/wiki/Sakon_Yamamoto',
#    'givenName': 'Sakon',
#    'familyName': 'Yamamoto',
#    'dateOfBirth': '1982-07-09',
#    'nationality': 'Japanese'}]}

# %%
driver_req = requests.get(site+'2006'+'/drivers/'+'alonso'+'/results.json').json()['MRData']['RaceTable']['Races']
driver_req
# Out:
# [{'season': '2006',
#   'round': '1',
#   'url': 'http://en.wikipedia.org/wiki/2006_Bahrain_Grand_Prix',
#   'raceName': 'Bahrain Grand Prix',
#   'Circuit': {'circuitId': 'bahrain',
#    'url': 'http://en.wikipedia.org/wiki/Bahrain_International_Circuit',
#    'circuitName': 'Bahrain International Circuit',
#    'Location': {'lat': '26.0325',
#     'long': '50.5106',
#     'locality': 'Sakhir',
#     'country': 'Bahrain'}},
#   'date': '2006-03-12',
#   'time': '14:30:00Z',
#   'Results': [{'number': '1',
#     'position': '1',
#     'positionText': '1',
#     'points': '10',
#     'Driver': {'driverId': 'alonso',
#      'permanentNumber': '14',
#      'code': 'ALO',
#      'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#      'givenName': 'Fernando',
#      'familyName': 'Alonso',
#      'dateOfBirth': '1981-07-29',
#      'nationality': 'Spanish'},
#     'Constructor': {'constructorId': 'renault',
#      'url': 'http://en.wikipedia.org/wiki/Renault_in_Formula_One',
#      'name': 'Renault',
#      'nationality': 'French'},
#     'grid': '4',
#     'laps': '57',
#     'status': 'Finished',
#     'Time': {'millis': '5386205', 'time': '1:29:46.205'},
#     'FastestLap': {'rank': '3',
#      'lap': '21',
#      'Time': {'time': '1:32.534'},
#      'AverageSpeed': {'units': 'kph', 'speed': '210.551'}}}]},
#  {'season': '2006',
#   'round': '2',
#   'url': 'http://en.wikipedia.org/wiki/2006_Malaysian_Grand_Prix',
#   'raceName': 'Malaysian Grand Prix',
#   'Circuit': {'circuitId': 'sepang',
#    'url': 'http://en.wikipedia.org/wiki/Sepang_International_Circuit',
#    'circuitName': 'Sepang International Circuit',
#    'Location': {'lat': '2.76083',
#     'long': '101.738',
#     'locality': 'Kuala Lumpur',
#     'country': 'Malaysia'}},
#   'date': '2006-03-19',
#   'time': '15:00:00Z',
#   'Results': [{'number': '1',
#     'position': '2',
#     'positionText': '2',
#     'points': '8',
#     'Driver': {'driverId': 'alonso',
#      'permanentNumber': '14',
#      'code': 'ALO',
#      'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#      'givenName': 'Fernando',
#      'familyName': 'Alonso',
#      'dateOfBirth': '1981-07-29',
#      'nationality': 'Spanish'},
#     'Constructor': {'constructorId': 'renault',
#      'url': 'http://en.wikipedia.org/wiki/Renault_in_Formula_One',
#      'name': 'Renault',
#      'nationality': 'French'},
#     'grid': '7',
#     'laps': '56',
#     'status': 'Finished',
#     'Time': {'millis': '5445114', 'time': '+4.585'},
#     'FastestLap': {'rank': '1',
#      'lap': '45',
#      'Time': {'time': '1:34.803'},
#      'AverageSpeed': {'units': 'kph', 'speed': '210.487'}}}]},
#  {'season': '2006',
#   'round': '3',
#   'url': 'http://en.wikipedia.org/wiki/2006_Australian_Grand_Prix',
#   'raceName': 'Australian Grand Prix',
#   'Circuit': {'circuitId': 'albert_park',
#    'url': 'http://en.wikipedia.org/wiki/Melbourne_Grand_Prix_Circuit',
#    'circuitName': 'Albert Park Grand Prix Circuit',
#    'Location': {'lat': '-37.8497',
#     'long': '144.968',
#     'locality': 'Melbourne',
#     'country': 'Australia'}},
#   'date': '2006-04-02',
#   'time': '14:00:00Z',
#   'Results': [{'number': '1',
#     'position': '1',
#     'positionText': '1',
#     'points': '10',
#     'Driver': {'driverId': 'alonso',
#      'permanentNumber': '14',
#      'code': 'ALO',
#      'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#      'givenName': 'Fernando',
#      'familyName': 'Alonso',
#      'dateOfBirth': '1981-07-29',
#      'nationality': 'Spanish'},
#     'Constructor': {'constructorId': 'renault',
#      'url': 'http://en.wikipedia.org/wiki/Renault_in_Formula_One',
#      'name': 'Renault',
#      'nationality': 'French'},
#     'grid': '3',
#     'laps': '57',
#     'status': 'Finished',
#     'Time': {'millis': '5667870', 'time': '1:34:27.870'},
#     'FastestLap': {'rank': '2',
#      'lap': '49',
#      'Time': {'time': '1:26.189'},
#      'AverageSpeed': {'units': 'kph', 'speed': '221.499'}}}]},
#  {'season': '2006',
#   'round': '4',
#   'url': 'http://en.wikipedia.org/wiki/2006_San_Marino_Grand_Prix',
#   'raceName': 'San Marino Grand Prix',
#   'Circuit': {'circuitId': 'imola',
#    'url': 'http://en.wikipedia.org/wiki/Autodromo_Enzo_e_Dino_Ferrari',
#    'circuitName': 'Autodromo Enzo e Dino Ferrari',
#    'Location': {'lat': '44.3439',
#     'long': '11.7167',
#     'locality': 'Imola',
#     'country': 'Italy'}},
#   'date': '2006-04-23',
#   'time': '14:00:00Z',
#   'Results': [{'number': '1',
#     'position': '2',
#     'positionText': '2',
#     'points': '8',
#     'Driver': {'driverId': 'alonso',
#      'permanentNumber': '14',
#      'code': 'ALO',
#      'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#      'givenName': 'Fernando',
#      'familyName': 'Alonso',
#      'dateOfBirth': '1981-07-29',
#      'nationality': 'Spanish'},
#     'Constructor': {'constructorId': 'renault',
#      'url': 'http://en.wikipedia.org/wiki/Renault_in_Formula_One',
#      'name': 'Renault',
#      'nationality': 'French'},
#     'grid': '5',
#     'laps': '62',
#     'status': 'Finished',
#     'Time': {'millis': '5468582', 'time': '+2.096'},
#     'FastestLap': {'rank': '1',
#      'lap': '23',
#      'Time': {'time': '1:24.569'},
#      'AverageSpeed': {'units': 'kph', 'speed': '211.098'}}}]},
#  {'season': '2006',
#   'round': '5',
#   'url': 'http://en.wikipedia.org/wiki/2006_European_Grand_Prix',
#   'raceName': 'European Grand Prix',
#   'Circuit': {'circuitId': 'nurburgring',
#    'url': 'http://en.wikipedia.org/wiki/N%C3%BCrburgring',
#    'circuitName': 'Nürburgring',
#    'Location': {'lat': '50.3356',
#     'long': '6.9475',
#     'locality': 'Nürburg',
#     'country': 'Germany'}},
#   'date': '2006-05-07',
#   'time': '14:00:00Z',
#   'Results': [{'number': '1',
#     'position': '2',
#     'positionText': '2',
#     'points': '8',
#     'Driver': {'driverId': 'alonso',
#      'permanentNumber': '14',
#      'code': 'ALO',
#      'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#      'givenName': 'Fernando',
#      'familyName': 'Alonso',
#      'dateOfBirth': '1981-07-29',
#      'nationality': 'Spanish'},
#     'Constructor': {'constructorId': 'renault',
#      'url': 'http://en.wikipedia.org/wiki/Renault_in_Formula_One',
#      'name': 'Renault',
#      'nationality': 'French'},
#     'grid': '1',
#     'laps': '60',
#     'status': 'Finished',
#     'Time': {'millis': '5762516', 'time': '+3.751'},
#     'FastestLap': {'rank': '3',
#      'lap': '37',
#      'Time': {'time': '1:32.532'},
#      'AverageSpeed': {'units': 'kph', 'speed': '200.285'}}}]},
#  {'season': '2006',
#   'round': '6',
#   'url': 'http://en.wikipedia.org/wiki/2006_Spanish_Grand_Prix',
#   'raceName': 'Spanish Grand Prix',
#   'Circuit': {'circuitId': 'catalunya',
#    'url': 'http://en.wikipedia.org/wiki/Circuit_de_Barcelona-Catalunya',
#    'circuitName': 'Circuit de Barcelona-Catalunya',
#    'Location': {'lat': '41.57',
#     'long': '2.26111',
#     'locality': 'Montmeló',
#     'country': 'Spain'}},
#   'date': '2006-05-14',
#   'time': '14:00:00Z',
#   'Results': [{'number': '1',
#     'position': '1',
#     'positionText': '1',
#     'points': '10',
#     'Driver': {'driverId': 'alonso',
#      'permanentNumber': '14',
#      'code': 'ALO',
#      'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#      'givenName': 'Fernando',
#      'familyName': 'Alonso',
#      'dateOfBirth': '1981-07-29',
#      'nationality': 'Spanish'},
#     'Constructor': {'constructorId': 'renault',
#      'url': 'http://en.wikipedia.org/wiki/Renault_in_Formula_One',
#      'name': 'Renault',
#      'nationality': 'French'},
#     'grid': '1',
#     'laps': '66',
#     'status': 'Finished',
#     'Time': {'millis': '5181759', 'time': '1:26:21.759'},
#     'FastestLap': {'rank': '2',
#      'lap': '39',
#      'Time': {'time': '1:16.723'},
#      'AverageSpeed': {'units': 'kph', 'speed': '217.108'}}}]},
#  {'season': '2006',
#   'round': '7',
#   'url': 'http://en.wikipedia.org/wiki/2006_Monaco_Grand_Prix',
#   'raceName': 'Monaco Grand Prix',
#   'Circuit': {'circuitId': 'monaco',
#    'url': 'http://en.wikipedia.org/wiki/Circuit_de_Monaco',
#    'circuitName': 'Circuit de Monaco',
#    'Location': {'lat': '43.7347',
#     'long': '7.42056',
#     'locality': 'Monte-Carlo',
#     'country': 'Monaco'}},
#   'date': '2006-05-28',
#   'time': '14:00:00Z',
#   'Results': [{'number': '1',
#     'position': '1',
#     'positionText': '1',
#     'points': '10',
#     'Driver': {'driverId': 'alonso',
#      'permanentNumber': '14',
#      'code': 'ALO',
#      'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#      'givenName': 'Fernando',
#      'familyName': 'Alonso',
#      'dateOfBirth': '1981-07-29',
#      'nationality': 'Spanish'},
#     'Constructor': {'constructorId': 'renault',
#      'url': 'http://en.wikipedia.org/wiki/Renault_in_Formula_One',
#      'name': 'Renault',
#      'nationality': 'French'},
#     'grid': '1',
#     'laps': '78',
#     'status': 'Finished',
#     'Time': {'millis': '6223116', 'time': '1:43:43.116'},
#     'FastestLap': {'rank': '3',
#      'lap': '11',
#      'Time': {'time': '1:15.671'},
#      'AverageSpeed': {'units': 'kph', 'speed': '158.898'}}}]},
#  {'season': '2006',
#   'round': '8',
#   'url': 'http://en.wikipedia.org/wiki/2006_British_Grand_Prix',
#   'raceName': 'British Grand Prix',
#   'Circuit': {'circuitId': 'silverstone',
#    'url': 'http://en.wikipedia.org/wiki/Silverstone_Circuit',
#    'circuitName': 'Silverstone Circuit',
#    'Location': {'lat': '52.0786',
#     'long': '-1.01694',
#     'locality': 'Silverstone',
#     'country': 'UK'}},
#   'date': '2006-06-11',
#   'time': '12:00:00Z',
#   'Results': [{'number': '1',
#     'position': '1',
#     'positionText': '1',
#     'points': '10',
#     'Driver': {'driverId': 'alonso',
#      'permanentNumber': '14',
#      'code': 'ALO',
#      'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#      'givenName': 'Fernando',
#      'familyName': 'Alonso',
#      'dateOfBirth': '1981-07-29',
#      'nationality': 'Spanish'},
#     'Constructor': {'constructorId': 'renault',
#      'url': 'http://en.wikipedia.org/wiki/Renault_in_Formula_One',
#      'name': 'Renault',
#      'nationality': 'French'},
#     'grid': '1',
#     'laps': '60',
#     'status': 'Finished',
#     'Time': {'millis': '5151927', 'time': '1:25:51.927'},
#     'FastestLap': {'rank': '1',
#      'lap': '21',
#      'Time': {'time': '1:21.599'},
#      'AverageSpeed': {'units': 'kph', 'speed': '226.811'}}}]},
#  {'season': '2006',
#   'round': '9',
#   'url': 'http://en.wikipedia.org/wiki/2006_Canadian_Grand_Prix',
#   'raceName': 'Canadian Grand Prix',
#   'Circuit': {'circuitId': 'villeneuve',
#    'url': 'http://en.wikipedia.org/wiki/Circuit_Gilles_Villeneuve',
#    'circuitName': 'Circuit Gilles Villeneuve',
#    'Location': {'lat': '45.5',
#     'long': '-73.5228',
#     'locality': 'Montreal',
#     'country': 'Canada'}},
#   'date': '2006-06-25',
#   'time': '13:00:00Z',
#   'Results': [{'number': '1',
#     'position': '1',
#     'positionText': '1',
#     'points': '10',
#     'Driver': {'driverId': 'alonso',
#      'permanentNumber': '14',
#      'code': 'ALO',
#      'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#      'givenName': 'Fernando',
#      'familyName': 'Alonso',
#      'dateOfBirth': '1981-07-29',
#      'nationality': 'Spanish'},
#     'Constructor': {'constructorId': 'renault',
#      'url': 'http://en.wikipedia.org/wiki/Renault_in_Formula_One',
#      'name': 'Renault',
#      'nationality': 'French'},
#     'grid': '1',
#     'laps': '70',
#     'status': 'Finished',
#     'Time': {'millis': '5677308', 'time': '1:34:37.308'},
#     'FastestLap': {'rank': '2',
#      'lap': '22',
#      'Time': {'time': '1:15.911'},
#      'AverageSpeed': {'units': 'kph', 'speed': '206.815'}}}]},
#  {'season': '2006',
#   'round': '10',
#   'url': 'http://en.wikipedia.org/wiki/2006_United_States_Grand_Prix',
#   'raceName': 'United States Grand Prix',
#   'Circuit': {'circuitId': 'indianapolis',
#    'url': 'http://en.wikipedia.org/wiki/Indianapolis_Motor_Speedway',
#    'circuitName': 'Indianapolis Motor Speedway',
#    'Location': {'lat': '39.795',
#     'long': '-86.2347',
#     'locality': 'Indianapolis',
#     'country': 'USA'}},
#   'date': '2006-07-02',
#   'time': '14:00:00Z',
#   'Results': [{'number': '1',
#     'position': '5',
#     'positionText': '5',
#     'points': '4',
#     'Driver': {'driverId': 'alonso',
#      'permanentNumber': '14',
#      'code': 'ALO',
#      'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#      'givenName': 'Fernando',
#      'familyName': 'Alonso',
#      'dateOfBirth': '1981-07-29',
#      'nationality': 'Spanish'},
#     'Constructor': {'constructorId': 'renault',
#      'url': 'http://en.wikipedia.org/wiki/Renault_in_Formula_One',
#      'name': 'Renault',
#      'nationality': 'French'},
#     'grid': '5',
#     'laps': '73',
#     'status': 'Finished',
#     'Time': {'millis': '5703609', 'time': '+28.410'},
#     'FastestLap': {'rank': '6',
#      'lap': '72',
#      'Time': {'time': '1:13.316'},
#      'AverageSpeed': {'units': 'kph', 'speed': '205.837'}}}]},
#  {'season': '2006',
#   'round': '11',
#   'url': 'http://en.wikipedia.org/wiki/2006_French_Grand_Prix',
#   'raceName': 'French Grand Prix',
#   'Circuit': {'circuitId': 'magny_cours',
#    'url': 'http://en.wikipedia.org/wiki/Circuit_de_Nevers_Magny-Cours',
#    'circuitName': 'Circuit de Nevers Magny-Cours',
#    'Location': {'lat': '46.8642',
#     'long': '3.16361',
#     'locality': 'Magny Cours',
#     'country': 'France'}},
#   'date': '2006-07-16',
#   'time': '14:00:00Z',
#   'Results': [{'number': '1',
#     'position': '2',
#     'positionText': '2',
#     'points': '8',
#     'Driver': {'driverId': 'alonso',
#      'permanentNumber': '14',
#      'code': 'ALO',
#      'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#      'givenName': 'Fernando',
#      'familyName': 'Alonso',
#      'dateOfBirth': '1981-07-29',
#      'nationality': 'Spanish'},
#     'Constructor': {'constructorId': 'renault',
#      'url': 'http://en.wikipedia.org/wiki/Renault_in_Formula_One',
#      'name': 'Renault',
#      'nationality': 'French'},
#     'grid': '3',
#     'laps': '70',
#     'status': 'Finished',
#     'Time': {'millis': '5537903', 'time': '+10.1'},
#     'FastestLap': {'rank': '5',
#      'lap': '23',
#      'Time': {'time': '1:17.770'},
#      'AverageSpeed': {'units': 'kph', 'speed': '204.186'}}}]},
#  {'season': '2006',
#   'round': '12',
#   'url': 'http://en.wikipedia.org/wiki/2006_German_Grand_Prix',
#   'raceName': 'German Grand Prix',
#   'Circuit': {'circuitId': 'hockenheimring',
#    'url': 'http://en.wikipedia.org/wiki/Hockenheimring',
#    'circuitName': 'Hockenheimring',
#    'Location': {'lat': '49.3278',
#     'long': '8.56583',
#     'locality': 'Hockenheim',
#     'country': 'Germany'}},
#   'date': '2006-07-30',
#   'time': '14:00:00Z',
#   'Results': [{'number': '1',
#     'position': '5',
#     'positionText': '5',
#     'points': '4',
#     'Driver': {'driverId': 'alonso',
#      'permanentNumber': '14',
#      'code': 'ALO',
#      'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#      'givenName': 'Fernando',
#      'familyName': 'Alonso',
#      'dateOfBirth': '1981-07-29',
#      'nationality': 'Spanish'},
#     'Constructor': {'constructorId': 'renault',
#      'url': 'http://en.wikipedia.org/wiki/Renault_in_Formula_One',
#      'name': 'Renault',
#      'nationality': 'French'},
#     'grid': '7',
#     'laps': '67',
#     'status': 'Finished',
#     'Time': {'millis': '5295393', 'time': '+23.7'},
#     'FastestLap': {'rank': '9',
#      'lap': '66',
#      'Time': {'time': '1:17.256'},
#      'AverageSpeed': {'units': 'kph', 'speed': '213.140'}}}]},
#  {'season': '2006',
#   'round': '13',
#   'url': 'http://en.wikipedia.org/wiki/2006_Hungarian_Grand_Prix',
#   'raceName': 'Hungarian Grand Prix',
#   'Circuit': {'circuitId': 'hungaroring',
#    'url': 'http://en.wikipedia.org/wiki/Hungaroring',
#    'circuitName': 'Hungaroring',
#    'Location': {'lat': '47.5789',
#     'long': '19.2486',
#     'locality': 'Budapest',
#     'country': 'Hungary'}},
#   'date': '2006-08-06',
#   'time': '14:00:00Z',
#   'Results': [{'number': '1',
#     'position': '14',
#     'positionText': 'R',
#     'points': '0',
#     'Driver': {'driverId': 'alonso',
#      'permanentNumber': '14',
#      'code': 'ALO',
#      'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#      'givenName': 'Fernando',
#      'familyName': 'Alonso',
#      'dateOfBirth': '1981-07-29',
#      'nationality': 'Spanish'},
#     'Constructor': {'constructorId': 'renault',
#      'url': 'http://en.wikipedia.org/wiki/Renault_in_Formula_One',
#      'name': 'Renault',
#      'nationality': 'French'},
#     'grid': '15',
#     'laps': '51',
#     'status': 'Driveshaft',
#     'FastestLap': {'rank': '14',
#      'lap': '50',
#      'Time': {'time': '1:29.408'},
#      'AverageSpeed': {'units': 'kph', 'speed': '176.400'}}}]},
#  {'season': '2006',
#   'round': '14',
#   'url': 'http://en.wikipedia.org/wiki/2006_Turkish_Grand_Prix',
#   'raceName': 'Turkish Grand Prix',
#   'Circuit': {'circuitId': 'istanbul',
#    'url': 'http://en.wikipedia.org/wiki/Istanbul_Park',
#    'circuitName': 'Istanbul Park',
#    'Location': {'lat': '40.9517',
#     'long': '29.405',
#     'locality': 'Istanbul',
#     'country': 'Turkey'}},
#   'date': '2006-08-27',
#   'time': '15:00:00Z',
#   'Results': [{'number': '1',
#     'position': '2',
#     'positionText': '2',
#     'points': '8',
#     'Driver': {'driverId': 'alonso',
#      'permanentNumber': '14',
#      'code': 'ALO',
#      'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#      'givenName': 'Fernando',
#      'familyName': 'Alonso',
#      'dateOfBirth': '1981-07-29',
#      'nationality': 'Spanish'},
#     'Constructor': {'constructorId': 'renault',
#      'url': 'http://en.wikipedia.org/wiki/Renault_in_Formula_One',
#      'name': 'Renault',
#      'nationality': 'French'},
#     'grid': '3',
#     'laps': '58',
#     'status': 'Finished',
#     'Time': {'millis': '5336657', 'time': '+5.575'},
#     'FastestLap': {'rank': '3',
#      'lap': '38',
#      'Time': {'time': '1:28.245'},
#      'AverageSpeed': {'units': 'kph', 'speed': '217.766'}}}]},
#  {'season': '2006',
#   'round': '15',
#   'url': 'http://en.wikipedia.org/wiki/2006_Italian_Grand_Prix',
#   'raceName': 'Italian Grand Prix',
#   'Circuit': {'circuitId': 'monza',
#    'url': 'http://en.wikipedia.org/wiki/Autodromo_Nazionale_Monza',
#    'circuitName': 'Autodromo Nazionale di Monza',
#    'Location': {'lat': '45.6156',
#     'long': '9.28111',
#     'locality': 'Monza',
#     'country': 'Italy'}},
#   'date': '2006-09-10',
#   'time': '14:00:00Z',
#   'Results': [{'number': '1',
#     'position': '19',
#     'positionText': 'R',
#     'points': '0',
#     'Driver': {'driverId': 'alonso',
#      'permanentNumber': '14',
#      'code': 'ALO',
#      'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#      'givenName': 'Fernando',
#      'familyName': 'Alonso',
#      'dateOfBirth': '1981-07-29',
#      'nationality': 'Spanish'},
#     'Constructor': {'constructorId': 'renault',
#      'url': 'http://en.wikipedia.org/wiki/Renault_in_Formula_One',
#      'name': 'Renault',
#      'nationality': 'French'},
#     'grid': '10',
#     'laps': '43',
#     'status': 'Engine',
#     'FastestLap': {'rank': '5',
#      'lap': '38',
#      'Time': {'time': '1:23.121'},
#      'AverageSpeed': {'units': 'kph', 'speed': '250.896'}}}]},
#  {'season': '2006',
#   'round': '16',
#   'url': 'http://en.wikipedia.org/wiki/2006_Chinese_Grand_Prix',
#   'raceName': 'Chinese Grand Prix',
#   'Circuit': {'circuitId': 'shanghai',
#    'url': 'http://en.wikipedia.org/wiki/Shanghai_International_Circuit',
#    'circuitName': 'Shanghai International Circuit',
#    'Location': {'lat': '31.3389',
#     'long': '121.22',
#     'locality': 'Shanghai',
#     'country': 'China'}},
#   'date': '2006-10-01',
#   'time': '14:00:00Z',
#   'Results': [{'number': '1',
#     'position': '2',
#     'positionText': '2',
#     'points': '8',
#     'Driver': {'driverId': 'alonso',
#      'permanentNumber': '14',
#      'code': 'ALO',
#      'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#      'givenName': 'Fernando',
#      'familyName': 'Alonso',
#      'dateOfBirth': '1981-07-29',
#      'nationality': 'Spanish'},
#     'Constructor': {'constructorId': 'renault',
#      'url': 'http://en.wikipedia.org/wiki/Renault_in_Formula_One',
#      'name': 'Renault',
#      'nationality': 'French'},
#     'grid': '1',
#     'laps': '56',
#     'status': 'Finished',
#     'Time': {'millis': '5855868', 'time': '+3.121'},
#     'FastestLap': {'rank': '1',
#      'lap': '49',
#      'Time': {'time': '1:37.586'},
#      'AverageSpeed': {'units': 'kph', 'speed': '201.090'}}}]},
#  {'season': '2006',
#   'round': '17',
#   'url': 'http://en.wikipedia.org/wiki/2006_Japanese_Grand_Prix',
#   'raceName': 'Japanese Grand Prix',
#   'Circuit': {'circuitId': 'suzuka',
#    'url': 'http://en.wikipedia.org/wiki/Suzuka_Circuit',
#    'circuitName': 'Suzuka Circuit',
#    'Location': {'lat': '34.8431',
#     'long': '136.541',
#     'locality': 'Suzuka',
#     'country': 'Japan'}},
#   'date': '2006-10-08',
#   'time': '14:00:00Z',
#   'Results': [{'number': '1',
#     'position': '1',
#     'positionText': '1',
#     'points': '10',
#     'Driver': {'driverId': 'alonso',
#      'permanentNumber': '14',
#      'code': 'ALO',
#      'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#      'givenName': 'Fernando',
#      'familyName': 'Alonso',
#      'dateOfBirth': '1981-07-29',
#      'nationality': 'Spanish'},
#     'Constructor': {'constructorId': 'renault',
#      'url': 'http://en.wikipedia.org/wiki/Renault_in_Formula_One',
#      'name': 'Renault',
#      'nationality': 'French'},
#     'grid': '5',
#     'laps': '53',
#     'status': 'Finished',
#     'Time': {'millis': '5032413', 'time': '1:23:52.413'},
#     'FastestLap': {'rank': '1',
#      'lap': '14',
#      'Time': {'time': '1:32.676'},
#      'AverageSpeed': {'units': 'kph', 'speed': '225.572'}}}]},
#  {'season': '2006',
#   'round': '18',
#   'url': 'http://en.wikipedia.org/wiki/2006_Brazilian_Grand_Prix',
#   'raceName': 'Brazilian Grand Prix',
#   'Circuit': {'circuitId': 'interlagos',
#    'url': 'http://en.wikipedia.org/wiki/Aut%C3%B3dromo_Jos%C3%A9_Carlos_Pace',
#    'circuitName': 'Autódromo José Carlos Pace',
#    'Location': {'lat': '-23.7036',
#     'long': '-46.6997',
#     'locality': 'São Paulo',
#     'country': 'Brazil'}},
#   'date': '2006-10-22',
#   'time': '14:00:00Z',
#   'Results': [{'number': '1',
#     'position': '2',
#     'positionText': '2',
#     'points': '8',
#     'Driver': {'driverId': 'alonso',
#      'permanentNumber': '14',
#      'code': 'ALO',
#      'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#      'givenName': 'Fernando',
#      'familyName': 'Alonso',
#      'dateOfBirth': '1981-07-29',
#      'nationality': 'Spanish'},
#     'Constructor': {'constructorId': 'renault',
#      'url': 'http://en.wikipedia.org/wiki/Renault_in_Formula_One',
#      'name': 'Renault',
#      'nationality': 'French'},
#     'grid': '4',
#     'laps': '71',
#     'status': 'Finished',
#     'Time': {'millis': '5532409', 'time': '+18.658'},
#     'FastestLap': {'rank': '3',
#      'lap': '70',
#      'Time': {'time': '1:12.961'},
#      'AverageSpeed': {'units': 'kph', 'speed': '212.612'}}}]}]
