# %%
import requests
import json
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
# Define the base url to concatenate url strings
urlBase = "https://www.motogp.com"

# %%
# Returns JSON
def getCircuits(year):
    endpoint = urlBase + "/en/ajax/results/selector/" + str(year)
    req = requests.get(endpoint)
    return req.json()

# Returns HTML | This shows the final ranking
def getDriversTableYear(year):
    endpoint = urlBase + "/en/ajax/results/parse_final_standing/" + str(year)
    req = requests.get(endpoint)
    soup = BeautifulSoup(req.content, 'html.parser')
    return soup

# Returns HTML | This gets the final chart by race 
def getWinnersCircuit(circuit, year):
    url = urlBase + "/en/ajax/results/files/" + str(year) + "/" + circuit  + "/500cc/RAC"
    req = requests.get(url)

    return req

def getCategory(year):
    endpoint = urlBase + "en/ajax/results/selector/" + str(year) + "/VEN"
    return endpoint

# Create Dataframes with JSON Inputs
def dataToJson(data):
    return pd.DataFrame(data.json())

# %%
# Circuits Name Dataframe by year
df = np.transpose(pd.DataFrame(getCircuits(2000)))
df
# Out:
#    shortname                                 title  \
# 1        RSA              SOUTH AFRICAN GRAND PRIX
# 2        MAL                  MALAYSIAN GRAND PRIX
# 3        JPN                   JAPANESE GRAND PRIX
# 4        SPA                    SPANISH GRAND PRIX
# 5        FRA                     FRENCH GRAND PRIX
# 6        ITA                    ITALIAN GRAND PRIX
# 7        CAT                  CATALUNYA GRAND PRIX
# 8        NED                              DUTCH TT
# 9        GBR                    BRITISH GRAND PRIX
# 10       GER                     GERMAN GRAND PRIX
# 11       CZE  Gauloises Grand Prix České republiky
# 12       POR                 PORTUGUESE GRAND PRIX
# 13       VAL                   VALENCIA GRAND PRIX
# 14       RIO                        RIO GRAND PRIX
# 15       PAC                    PACIFIC GRAND PRIX
# 16       AUS                 AUSTRALIAN GRAND PRIX
#
#                                  circuit sequence  \
# 1                        Phakisa Freeway        1
# 2           Sepang International Circuit        2
# 3                         Suzuka Circuit        3
# 4        Circuito de Jerez - Angel Nieto        4
# 5                                Le Mans        5
# 6   Autodromo Internazionale del Mugello        6
# 7         Circuit de Barcelona-Catalunya        7
# 8                       TT Circuit Assen        8
# 9                 Donington Park Circuit        9
# 10                           Sachsenring       10
# 11                     Automotodrom Brno       11
# 12                       Estoril Circuit       12
# 13                 Circuit Ricardo Tormo       13
# 14                 Nelson Piquet Circuit       14
# 15                      Twin Ring Motegi       15
# 16                        Phillip Island       16
#
#                                    url
# 1   /en/ajax/results/selector/2000/RSA
# 2   /en/ajax/results/selector/2000/MAL
# 3   /en/ajax/results/selector/2000/JPN
# 4   /en/ajax/results/selector/2000/SPA
# 5   /en/ajax/results/selector/2000/FRA
# 6   /en/ajax/results/selector/2000/ITA
# 7   /en/ajax/results/selector/2000/CAT
# 8   /en/ajax/results/selector/2000/NED
# 9   /en/ajax/results/selector/2000/GBR
# 10  /en/ajax/results/selector/2000/GER
# 11  /en/ajax/results/selector/2000/CZE
# 12  /en/ajax/results/selector/2000/POR
# 13  /en/ajax/results/selector/2000/VAL
# 14  /en/ajax/results/selector/2000/RIO
# 15  /en/ajax/results/selector/2000/PAC
# 16  /en/ajax/results/selector/2000/AUS

# %%
#Export all the circuits to json just in case :)
allCircuits = [getCircuits(i) for i in range(1950, 2020)]
allCircuits
# Out:
# [{'1': {'shortname': 'TT',
#    'title': 'TOURIST TROPHY',
#    'circuit': 'Isle of Man',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1950/TT'},
#   '2': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1950/BEL'},
#   '3': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1950/NED'},
#   '4': {'shortname': 'SWI',
#    'title': 'SWITZERLAND GRAND PRIX',
#    'circuit': 'Geneva',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1950/SWI'},
#   '5': {'shortname': 'ULST',
#    'title': 'ULSTER GRAND PRIX',
#    'circuit': 'Belfast',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1950/ULST'},
#   '6': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Monza',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1950/NAT'}},
#  {'1': {'shortname': 'SPA',
#    'title': 'SPANISH GRAND PRIX',
#    'circuit': 'Montjuïc',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1951/SPA'},
#   '2': {'shortname': 'SWI',
#    'title': 'SWITZERLAND GRAND PRIX',
#    'circuit': 'Berne',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1951/SWI'},
#   '3': {'shortname': 'TT',
#    'title': 'TOURIST TROPHY',
#    'circuit': 'Isle of Man',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1951/TT'},
#   '4': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1951/BEL'},
#   '5': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1951/NED'},
#   '6': {'shortname': 'FRA',
#    'title': 'FRENCH GRAND PRIX',
#    'circuit': 'Albi',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1951/FRA'},
#   '7': {'shortname': 'ULST',
#    'title': 'ULSTER GRAND PRIX',
#    'circuit': 'Belfast',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1951/ULST'},
#   '8': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Monza',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/1951/NAT'}},
#  {'1': {'shortname': 'SWI',
#    'title': 'SWITZERLAND GRAND PRIX',
#    'circuit': 'Berne',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1952/SWI'},
#   '2': {'shortname': 'TT',
#    'title': 'TOURIST TROPHY',
#    'circuit': 'Isle of Man',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1952/TT'},
#   '3': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1952/NED'},
#   '4': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1952/BEL'},
#   '5': {'shortname': 'WGER',
#    'title': 'WEST GERMANY GRAND PRIX',
#    'circuit': 'Solitude',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1952/WGER'},
#   '6': {'shortname': 'ULST',
#    'title': 'ULSTER GRAND PRIX',
#    'circuit': 'Belfast',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1952/ULST'},
#   '7': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Monza',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1952/NAT'},
#   '8': {'shortname': 'SPA',
#    'title': 'SPANISH GRAND PRIX',
#    'circuit': 'Montjuïc',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/1952/SPA'}},
#  {'1': {'shortname': 'TT',
#    'title': 'TOURIST TROPHY',
#    'circuit': 'Isle of Man',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1953/TT'},
#   '2': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1953/NED'},
#   '3': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1953/BEL'},
#   '4': {'shortname': 'FRA',
#    'title': 'FRENCH GRAND PRIX',
#    'circuit': 'Rouen',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1953/FRA'},
#   '5': {'shortname': 'ULST',
#    'title': 'ULSTER GRAND PRIX',
#    'circuit': 'Belfast',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1953/ULST'},
#   '6': {'shortname': 'SWI',
#    'title': 'SWITZERLAND GRAND PRIX',
#    'circuit': 'Berne',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1953/SWI'},
#   '7': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Monza',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1953/NAT'},
#   '8': {'shortname': 'SPA',
#    'title': 'SPANISH GRAND PRIX',
#    'circuit': 'Montjuïc',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/1953/SPA'}},
#  {'1': {'shortname': 'FRA',
#    'title': 'FRENCH GRAND PRIX',
#    'circuit': 'Reims',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1954/FRA'},
#   '2': {'shortname': 'TT',
#    'title': 'TOURIST TROPHY',
#    'circuit': 'Isle of Man',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1954/TT'},
#   '3': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1954/BEL'},
#   '4': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1954/NED'},
#   '5': {'shortname': 'WGER',
#    'title': 'WEST GERMANY GRAND PRIX',
#    'circuit': 'Solitude',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1954/WGER'},
#   '6': {'shortname': 'SWI',
#    'title': 'SWITZERLAND GRAND PRIX',
#    'circuit': 'Berne',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1954/SWI'},
#   '7': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Monza',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1954/NAT'},
#   '8': {'shortname': 'SPA',
#    'title': 'SPANISH GRAND PRIX',
#    'circuit': 'Montjuïc',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/1954/SPA'}},
#  {'1': {'shortname': 'SPA',
#    'title': 'SPANISH GRAND PRIX',
#    'circuit': 'Montjuïc',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1955/SPA'},
#   '2': {'shortname': 'FRA',
#    'title': 'FRENCH GRAND PRIX',
#    'circuit': 'Reims',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1955/FRA'},
#   '3': {'shortname': 'TT',
#    'title': 'TOURIST TROPHY',
#    'circuit': 'Isle of Man',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1955/TT'},
#   '4': {'shortname': 'WGER',
#    'title': 'WEST GERMANY GRAND PRIX',
#    'circuit': 'Nurburgring',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1955/WGER'},
#   '5': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1955/BEL'},
#   '6': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1955/NED'},
#   '7': {'shortname': 'ULST',
#    'title': 'ULSTER GRAND PRIX',
#    'circuit': 'Belfast',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1955/ULST'},
#   '8': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Monza',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/1955/NAT'}},
#  {'1': {'shortname': 'TT',
#    'title': 'TOURIST TROPHY',
#    'circuit': 'Isle of Man',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1956/TT'},
#   '2': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1956/NED'},
#   '3': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1956/BEL'},
#   '4': {'shortname': 'WGER',
#    'title': 'WEST GERMANY GRAND PRIX',
#    'circuit': 'Solitude',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1956/WGER'},
#   '5': {'shortname': 'ULST',
#    'title': 'ULSTER GRAND PRIX',
#    'circuit': 'Belfast',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1956/ULST'},
#   '6': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Monza',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1956/NAT'}},
#  {'1': {'shortname': 'WGER',
#    'title': 'WEST GERMANY GRAND PRIX',
#    'circuit': 'Hockenheim',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1957/WGER'},
#   '2': {'shortname': 'TT',
#    'title': 'TOURIST TROPHY',
#    'circuit': 'Isle of Man',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1957/TT'},
#   '3': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1957/NED'},
#   '4': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1957/BEL'},
#   '5': {'shortname': 'ULST',
#    'title': 'ULSTER GRAND PRIX',
#    'circuit': 'Belfast',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1957/ULST'},
#   '6': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Monza',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1957/NAT'}},
#  {'1': {'shortname': 'TT',
#    'title': 'TOURIST TROPHY',
#    'circuit': 'Isle of Man',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1958/TT'},
#   '2': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1958/NED'},
#   '3': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1958/BEL'},
#   '4': {'shortname': 'WGER',
#    'title': 'WEST GERMANY GRAND PRIX',
#    'circuit': 'Nurburgring',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1958/WGER'},
#   '5': {'shortname': 'SWE',
#    'title': 'SWEDISH GRAND PRIX',
#    'circuit': 'Hedemora',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1958/SWE'},
#   '6': {'shortname': 'ULST',
#    'title': 'ULSTER GRAND PRIX',
#    'circuit': 'Belfast',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1958/ULST'},
#   '7': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Monza',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1958/NAT'}},
#  {'1': {'shortname': 'FRA',
#    'title': 'FRENCH GRAND PRIX',
#    'circuit': 'Clermont-Ferrand',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1959/FRA'},
#   '2': {'shortname': 'TT',
#    'title': 'TOURIST TROPHY',
#    'circuit': 'Isle of Man',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1959/TT'},
#   '3': {'shortname': 'WGER',
#    'title': 'WEST GERMANY GRAND PRIX',
#    'circuit': 'Hockenheim',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1959/WGER'},
#   '4': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1959/NED'},
#   '5': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1959/BEL'},
#   '6': {'shortname': 'ULST',
#    'title': 'ULSTER GRAND PRIX',
#    'circuit': 'Belfast',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1959/ULST'},
#   '7': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Monza',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1959/NAT'}},
#  {'1': {'shortname': 'FRA',
#    'title': 'FRENCH GRAND PRIX',
#    'circuit': 'Clermont-Ferrand',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1960/FRA'},
#   '2': {'shortname': 'TT',
#    'title': 'TOURIST TROPHY',
#    'circuit': 'Isle of Man',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1960/TT'},
#   '3': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1960/NED'},
#   '4': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1960/BEL'},
#   '5': {'shortname': 'WGER',
#    'title': 'WEST GERMANY GRAND PRIX',
#    'circuit': 'Solitude',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1960/WGER'},
#   '6': {'shortname': 'ULST',
#    'title': 'ULSTER GRAND PRIX',
#    'circuit': 'Belfast',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1960/ULST'},
#   '7': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Monza',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1960/NAT'}},
#  {'1': {'shortname': 'WGER',
#    'title': 'WEST GERMANY GRAND PRIX',
#    'circuit': 'Hockenheim',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1961/WGER'},
#   '2': {'shortname': 'FRA',
#    'title': 'FRENCH GRAND PRIX',
#    'circuit': 'Clermont-Ferrand',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1961/FRA'},
#   '3': {'shortname': 'TT',
#    'title': 'TOURIST TROPHY',
#    'circuit': 'Isle of Man',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1961/TT'},
#   '4': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1961/NED'},
#   '5': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1961/BEL'},
#   '6': {'shortname': 'EGER',
#    'title': 'EAST GERMANY GRAND PRIX',
#    'circuit': 'Sachsenring',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1961/EGER'},
#   '7': {'shortname': 'ULST',
#    'title': 'ULSTER GRAND PRIX',
#    'circuit': 'Belfast',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1961/ULST'},
#   '8': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Monza',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/1961/NAT'},
#   '9': {'shortname': 'SWE',
#    'title': 'SWEDISH GRAND PRIX',
#    'circuit': 'Kristianstad',
#    'sequence': '9',
#    'url': '/en/ajax/results/selector/1961/SWE'},
#   '10': {'shortname': 'ARG',
#    'title': 'Argentinian Grand Prix',
#    'circuit': 'Autodromo Oscar A. Galvez',
#    'sequence': '10',
#    'url': '/en/ajax/results/selector/1961/ARG'}},
#  {'1': {'shortname': 'TT',
#    'title': 'TOURIST TROPHY',
#    'circuit': 'Isle of Man',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1962/TT'},
#   '2': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1962/NED'},
#   '3': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1962/BEL'},
#   '4': {'shortname': 'ULST',
#    'title': 'ULSTER GRAND PRIX',
#    'circuit': 'Belfast',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1962/ULST'},
#   '5': {'shortname': 'EGER',
#    'title': 'EAST GERMANY GRAND PRIX',
#    'circuit': 'Sachsenring',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1962/EGER'},
#   '6': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Monza',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1962/NAT'},
#   '7': {'shortname': 'FIN',
#    'title': 'FINLAND GRAND PRIX',
#    'circuit': 'Tampere',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1962/FIN'},
#   '8': {'shortname': 'ARG',
#    'title': 'Argentinian Grand Prix',
#    'circuit': 'Autodromo Oscar A. Galvez',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/1962/ARG'}},
#  {'1': {'shortname': 'TT',
#    'title': 'TOURIST TROPHY',
#    'circuit': 'Isle of Man',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1963/TT'},
#   '2': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1963/NED'},
#   '3': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1963/BEL'},
#   '4': {'shortname': 'ULST',
#    'title': 'ULSTER GRAND PRIX',
#    'circuit': 'Belfast',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1963/ULST'},
#   '5': {'shortname': 'EGER',
#    'title': 'EAST GERMANY GRAND PRIX',
#    'circuit': 'Sachsenring',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1963/EGER'},
#   '6': {'shortname': 'FIN',
#    'title': 'FINLAND GRAND PRIX',
#    'circuit': 'Tampere',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1963/FIN'},
#   '7': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Monza',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1963/NAT'},
#   '8': {'shortname': 'ARG',
#    'title': 'Argentinian Grand Prix',
#    'circuit': 'Autodromo Oscar A. Galvez',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/1963/ARG'}},
#  {'1': {'shortname': 'USA',
#    'title': 'UNITED STATES GRAND PRIX',
#    'circuit': 'Daytona',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1964/USA'},
#   '2': {'shortname': 'TT',
#    'title': 'TOURIST TROPHY',
#    'circuit': 'Isle of Man',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1964/TT'},
#   '3': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1964/NED'},
#   '4': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1964/BEL'},
#   '5': {'shortname': 'WGER',
#    'title': 'WEST GERMANY GRAND PRIX',
#    'circuit': 'Solitude',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1964/WGER'},
#   '6': {'shortname': 'EGER',
#    'title': 'EAST GERMANY GRAND PRIX',
#    'circuit': 'Sachsenring',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1964/EGER'},
#   '7': {'shortname': 'ULST',
#    'title': 'ULSTER GRAND PRIX',
#    'circuit': 'Belfast',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1964/ULST'},
#   '8': {'shortname': 'FIN',
#    'title': 'FINLAND GRAND PRIX',
#    'circuit': 'Imatra',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/1964/FIN'},
#   '9': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Monza',
#    'sequence': '9',
#    'url': '/en/ajax/results/selector/1964/NAT'}},
#  {'1': {'shortname': 'USA',
#    'title': 'UNITED STATES GRAND PRIX',
#    'circuit': 'Daytona',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1965/USA'},
#   '2': {'shortname': 'WGER',
#    'title': 'WEST GERMANY GRAND PRIX',
#    'circuit': 'Nurburgring',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1965/WGER'},
#   '3': {'shortname': 'TT',
#    'title': 'TOURIST TROPHY',
#    'circuit': 'Isle of Man',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1965/TT'},
#   '4': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1965/NED'},
#   '5': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1965/BEL'},
#   '6': {'shortname': 'EGER',
#    'title': 'EAST GERMANY GRAND PRIX',
#    'circuit': 'Sachsenring',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1965/EGER'},
#   '7': {'shortname': 'TCH',
#    'title': 'CZECHOSLOVAKIAN GRAND PRIX',
#    'circuit': 'Automotodrom Brno',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1965/TCH'},
#   '8': {'shortname': 'ULST',
#    'title': 'ULSTER GRAND PRIX',
#    'circuit': 'Belfast',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/1965/ULST'},
#   '9': {'shortname': 'FIN',
#    'title': 'FINLAND GRAND PRIX',
#    'circuit': 'Imatra',
#    'sequence': '9',
#    'url': '/en/ajax/results/selector/1965/FIN'},
#   '10': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Monza',
#    'sequence': '10',
#    'url': '/en/ajax/results/selector/1965/NAT'}},
#  {'1': {'shortname': 'WGER',
#    'title': 'WEST GERMANY GRAND PRIX',
#    'circuit': 'Hockenheim',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1966/WGER'},
#   '2': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1966/NED'},
#   '3': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1966/BEL'},
#   '4': {'shortname': 'EGER',
#    'title': 'EAST GERMANY GRAND PRIX',
#    'circuit': 'Sachsenring',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1966/EGER'},
#   '5': {'shortname': 'TCH',
#    'title': 'CZECHOSLOVAKIAN GRAND PRIX',
#    'circuit': 'Automotodrom Brno',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1966/TCH'},
#   '6': {'shortname': 'FIN',
#    'title': 'FINLAND GRAND PRIX',
#    'circuit': 'Imatra',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1966/FIN'},
#   '7': {'shortname': 'ULST',
#    'title': 'ULSTER GRAND PRIX',
#    'circuit': 'Belfast',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1966/ULST'},
#   '8': {'shortname': 'TT',
#    'title': 'TOURIST TROPHY',
#    'circuit': 'Isle of Man',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/1966/TT'},
#   '9': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Monza',
#    'sequence': '9',
#    'url': '/en/ajax/results/selector/1966/NAT'}},
#  {'1': {'shortname': 'WGER',
#    'title': 'WEST GERMANY GRAND PRIX',
#    'circuit': 'Hockenheim',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1967/WGER'},
#   '2': {'shortname': 'TT',
#    'title': 'TOURIST TROPHY',
#    'circuit': 'Isle of Man',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1967/TT'},
#   '3': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1967/NED'},
#   '4': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1967/BEL'},
#   '5': {'shortname': 'EGER',
#    'title': 'EAST GERMANY GRAND PRIX',
#    'circuit': 'Sachsenring',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1967/EGER'},
#   '6': {'shortname': 'TCH',
#    'title': 'CZECHOSLOVAKIAN GRAND PRIX',
#    'circuit': 'Automotodrom Brno',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1967/TCH'},
#   '7': {'shortname': 'FIN',
#    'title': 'FINLAND GRAND PRIX',
#    'circuit': 'Imatra',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1967/FIN'},
#   '8': {'shortname': 'ULST',
#    'title': 'ULSTER GRAND PRIX',
#    'circuit': 'Belfast',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/1967/ULST'},
#   '9': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Monza',
#    'sequence': '9',
#    'url': '/en/ajax/results/selector/1967/NAT'},
#   '10': {'shortname': 'CAN',
#    'title': 'CANADIAN GRAND PRIX',
#    'circuit': 'Mosport',
#    'sequence': '10',
#    'url': '/en/ajax/results/selector/1967/CAN'}},
#  {'1': {'shortname': 'WGER',
#    'title': 'WEST GERMANY GRAND PRIX',
#    'circuit': 'Nurburgring',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1968/WGER'},
#   '2': {'shortname': 'SPA',
#    'title': 'SPANISH GRAND PRIX',
#    'circuit': 'Montjuïc',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1968/SPA'},
#   '3': {'shortname': 'TT',
#    'title': 'TOURIST TROPHY',
#    'circuit': 'Isle of Man',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1968/TT'},
#   '4': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1968/NED'},
#   '5': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1968/BEL'},
#   '6': {'shortname': 'EGER',
#    'title': 'EAST GERMANY GRAND PRIX',
#    'circuit': 'Sachsenring',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1968/EGER'},
#   '7': {'shortname': 'TCH',
#    'title': 'CZECHOSLOVAKIAN GRAND PRIX',
#    'circuit': 'Automotodrom Brno',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1968/TCH'},
#   '8': {'shortname': 'FIN',
#    'title': 'FINLAND GRAND PRIX',
#    'circuit': 'Imatra',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/1968/FIN'},
#   '9': {'shortname': 'ULST',
#    'title': 'ULSTER GRAND PRIX',
#    'circuit': 'Belfast',
#    'sequence': '9',
#    'url': '/en/ajax/results/selector/1968/ULST'},
#   '10': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Monza',
#    'sequence': '10',
#    'url': '/en/ajax/results/selector/1968/NAT'}},
#  {'1': {'shortname': 'SPA',
#    'title': 'SPANISH GRAND PRIX',
#    'circuit': 'Jarama Circuit',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1969/SPA'},
#   '2': {'shortname': 'WGER',
#    'title': 'WEST GERMANY GRAND PRIX',
#    'circuit': 'Hockenheim',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1969/WGER'},
#   '3': {'shortname': 'FRA',
#    'title': 'FRENCH GRAND PRIX',
#    'circuit': 'Le Mans',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1969/FRA'},
#   '4': {'shortname': 'TT',
#    'title': 'TOURIST TROPHY',
#    'circuit': 'Isle of Man',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1969/TT'},
#   '5': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1969/NED'},
#   '6': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1969/BEL'},
#   '7': {'shortname': 'EGER',
#    'title': 'EAST GERMANY GRAND PRIX',
#    'circuit': 'Sachsenring',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1969/EGER'},
#   '8': {'shortname': 'TCH',
#    'title': 'CZECHOSLOVAKIAN GRAND PRIX',
#    'circuit': 'Automotodrom Brno',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/1969/TCH'},
#   '9': {'shortname': 'FIN',
#    'title': 'FINLAND GRAND PRIX',
#    'circuit': 'Imatra',
#    'sequence': '9',
#    'url': '/en/ajax/results/selector/1969/FIN'},
#   '10': {'shortname': 'ULST',
#    'title': 'ULSTER GRAND PRIX',
#    'circuit': 'Belfast',
#    'sequence': '10',
#    'url': '/en/ajax/results/selector/1969/ULST'},
#   '11': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Autodromo Enzo e Dino Ferrari',
#    'sequence': '11',
#    'url': '/en/ajax/results/selector/1969/NAT'},
#   '12': {'shortname': 'JUG',
#    'title': 'YUGOSLAVIAN GRAND PRIX',
#    'circuit': 'Opatija',
#    'sequence': '12',
#    'url': '/en/ajax/results/selector/1969/JUG'}},
#  {'1': {'shortname': 'WGER',
#    'title': 'WEST GERMANY GRAND PRIX',
#    'circuit': 'Nurburgring',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1970/WGER'},
#   '2': {'shortname': 'FRA',
#    'title': 'FRENCH GRAND PRIX',
#    'circuit': 'Le Mans',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1970/FRA'},
#   '3': {'shortname': 'JUG',
#    'title': 'YUGOSLAVIAN GRAND PRIX',
#    'circuit': 'Opatija',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1970/JUG'},
#   '4': {'shortname': 'TT',
#    'title': 'TOURIST TROPHY',
#    'circuit': 'Isle of Man',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1970/TT'},
#   '5': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1970/NED'},
#   '6': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1970/BEL'},
#   '7': {'shortname': 'EGER',
#    'title': 'EAST GERMANY GRAND PRIX',
#    'circuit': 'Sachsenring',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1970/EGER'},
#   '8': {'shortname': 'FIN',
#    'title': 'FINLAND GRAND PRIX',
#    'circuit': 'Imatra',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/1970/FIN'},
#   '9': {'shortname': 'ULST',
#    'title': 'ULSTER GRAND PRIX',
#    'circuit': 'Belfast',
#    'sequence': '9',
#    'url': '/en/ajax/results/selector/1970/ULST'},
#   '10': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Monza',
#    'sequence': '10',
#    'url': '/en/ajax/results/selector/1970/NAT'},
#   '11': {'shortname': 'SPA',
#    'title': 'SPANISH GRAND PRIX',
#    'circuit': 'Montjuïc',
#    'sequence': '11',
#    'url': '/en/ajax/results/selector/1970/SPA'}},
#  {'1': {'shortname': 'AUT',
#    'title': 'AUSTRIAN GRAND PRIX',
#    'circuit': 'Salzburgring',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1971/AUT'},
#   '2': {'shortname': 'WGER',
#    'title': 'WEST GERMANY GRAND PRIX',
#    'circuit': 'Hockenheim',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1971/WGER'},
#   '3': {'shortname': 'TT',
#    'title': 'TOURIST TROPHY',
#    'circuit': 'Isle of Man',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1971/TT'},
#   '4': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1971/NED'},
#   '5': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1971/BEL'},
#   '6': {'shortname': 'EGER',
#    'title': 'EAST GERMANY GRAND PRIX',
#    'circuit': 'Sachsenring',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1971/EGER'},
#   '7': {'shortname': 'SWE',
#    'title': 'SWEDISH GRAND PRIX',
#    'circuit': 'Anderstorp',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1971/SWE'},
#   '8': {'shortname': 'FIN',
#    'title': 'FINLAND GRAND PRIX',
#    'circuit': 'Imatra',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/1971/FIN'},
#   '9': {'shortname': 'ULST',
#    'title': 'ULSTER GRAND PRIX',
#    'circuit': 'Belfast',
#    'sequence': '9',
#    'url': '/en/ajax/results/selector/1971/ULST'},
#   '10': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Monza',
#    'sequence': '10',
#    'url': '/en/ajax/results/selector/1971/NAT'},
#   '11': {'shortname': 'SPA',
#    'title': 'SPANISH GRAND PRIX',
#    'circuit': 'Jarama Circuit',
#    'sequence': '11',
#    'url': '/en/ajax/results/selector/1971/SPA'}},
#  {'1': {'shortname': 'WGER',
#    'title': 'WEST GERMANY GRAND PRIX',
#    'circuit': 'Nurburgring',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1972/WGER'},
#   '2': {'shortname': 'FRA',
#    'title': 'FRENCH GRAND PRIX',
#    'circuit': 'Clermont-Ferrand',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1972/FRA'},
#   '3': {'shortname': 'AUT',
#    'title': 'AUSTRIAN GRAND PRIX',
#    'circuit': 'Salzburgring',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1972/AUT'},
#   '4': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Autodromo Enzo e Dino Ferrari',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1972/NAT'},
#   '5': {'shortname': 'TT',
#    'title': 'TOURIST TROPHY',
#    'circuit': 'Isle of Man',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1972/TT'},
#   '6': {'shortname': 'JUG',
#    'title': 'YUGOSLAVIAN GRAND PRIX',
#    'circuit': 'Opatija',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1972/JUG'},
#   '7': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1972/NED'},
#   '8': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/1972/BEL'},
#   '9': {'shortname': 'EGER',
#    'title': 'EAST GERMANY GRAND PRIX',
#    'circuit': 'Sachsenring',
#    'sequence': '9',
#    'url': '/en/ajax/results/selector/1972/EGER'},
#   '10': {'shortname': 'TCH',
#    'title': 'CZECHOSLOVAKIAN GRAND PRIX',
#    'circuit': 'Automotodrom Brno',
#    'sequence': '10',
#    'url': '/en/ajax/results/selector/1972/TCH'},
#   '11': {'shortname': 'SWE',
#    'title': 'SWEDISH GRAND PRIX',
#    'circuit': 'Anderstorp',
#    'sequence': '11',
#    'url': '/en/ajax/results/selector/1972/SWE'},
#   '12': {'shortname': 'FIN',
#    'title': 'FINLAND GRAND PRIX',
#    'circuit': 'Imatra',
#    'sequence': '12',
#    'url': '/en/ajax/results/selector/1972/FIN'},
#   '13': {'shortname': 'SPA',
#    'title': 'SPANISH GRAND PRIX',
#    'circuit': 'Montjuïc',
#    'sequence': '13',
#    'url': '/en/ajax/results/selector/1972/SPA'}},
#  {'1': {'shortname': 'FRA',
#    'title': 'FRENCH GRAND PRIX',
#    'circuit': 'Paul Ricard Circuit',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1973/FRA'},
#   '2': {'shortname': 'AUT',
#    'title': 'AUSTRIAN GRAND PRIX',
#    'circuit': 'Salzburgring',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1973/AUT'},
#   '3': {'shortname': 'WGER',
#    'title': 'WEST GERMANY GRAND PRIX',
#    'circuit': 'Hockenheim',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1973/WGER'},
#   '4': {'shortname': 'TT',
#    'title': 'TOURIST TROPHY',
#    'circuit': 'Isle of Man',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1973/TT'},
#   '5': {'shortname': 'JUG',
#    'title': 'YUGOSLAVIAN GRAND PRIX',
#    'circuit': 'Opatija',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1973/JUG'},
#   '6': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1973/NED'},
#   '7': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1973/BEL'},
#   '8': {'shortname': 'TCH',
#    'title': 'CZECHOSLOVAKIAN GRAND PRIX',
#    'circuit': 'Automotodrom Brno',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/1973/TCH'},
#   '9': {'shortname': 'SWE',
#    'title': 'SWEDISH GRAND PRIX',
#    'circuit': 'Anderstorp',
#    'sequence': '9',
#    'url': '/en/ajax/results/selector/1973/SWE'},
#   '10': {'shortname': 'FIN',
#    'title': 'FINLAND GRAND PRIX',
#    'circuit': 'Imatra',
#    'sequence': '10',
#    'url': '/en/ajax/results/selector/1973/FIN'},
#   '11': {'shortname': 'SPA',
#    'title': 'SPANISH GRAND PRIX',
#    'circuit': 'Jarama Circuit',
#    'sequence': '11',
#    'url': '/en/ajax/results/selector/1973/SPA'}},
#  {'1': {'shortname': 'FRA',
#    'title': 'FRENCH GRAND PRIX',
#    'circuit': 'Clermont-Ferrand',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1974/FRA'},
#   '2': {'shortname': 'WGER',
#    'title': 'WEST GERMANY GRAND PRIX',
#    'circuit': 'Nurburgring',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1974/WGER'},
#   '3': {'shortname': 'AUT',
#    'title': 'AUSTRIAN GRAND PRIX',
#    'circuit': 'Salzburgring',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1974/AUT'},
#   '4': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Autodromo Enzo e Dino Ferrari',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1974/NAT'},
#   '5': {'shortname': 'TT',
#    'title': 'TOURIST TROPHY',
#    'circuit': 'Isle of Man',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1974/TT'},
#   '6': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1974/NED'},
#   '7': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1974/BEL'},
#   '8': {'shortname': 'SWE',
#    'title': 'SWEDISH GRAND PRIX',
#    'circuit': 'Anderstorp',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/1974/SWE'},
#   '9': {'shortname': 'FIN',
#    'title': 'FINLAND GRAND PRIX',
#    'circuit': 'Imatra',
#    'sequence': '9',
#    'url': '/en/ajax/results/selector/1974/FIN'},
#   '10': {'shortname': 'TCH',
#    'title': 'CZECHOSLOVAKIAN GRAND PRIX',
#    'circuit': 'Automotodrom Brno',
#    'sequence': '10',
#    'url': '/en/ajax/results/selector/1974/TCH'}},
#  {'1': {'shortname': 'FRA',
#    'title': 'FRENCH GRAND PRIX',
#    'circuit': 'Paul Ricard Circuit',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1975/FRA'},
#   '2': {'shortname': 'AUT',
#    'title': 'AUSTRIAN GRAND PRIX',
#    'circuit': 'Salzburgring',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1975/AUT'},
#   '3': {'shortname': 'WGER',
#    'title': 'WEST GERMANY GRAND PRIX',
#    'circuit': 'Hockenheim',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1975/WGER'},
#   '4': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Autodromo Enzo e Dino Ferrari',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1975/NAT'},
#   '5': {'shortname': 'TT',
#    'title': 'TOURIST TROPHY',
#    'circuit': 'Isle of Man',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1975/TT'},
#   '6': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1975/NED'},
#   '7': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1975/BEL'},
#   '8': {'shortname': 'SWE',
#    'title': 'SWEDISH GRAND PRIX',
#    'circuit': 'Anderstorp',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/1975/SWE'},
#   '9': {'shortname': 'FIN',
#    'title': 'FINLAND GRAND PRIX',
#    'circuit': 'Imatra',
#    'sequence': '9',
#    'url': '/en/ajax/results/selector/1975/FIN'},
#   '10': {'shortname': 'TCH',
#    'title': 'CZECHOSLOVAKIAN GRAND PRIX',
#    'circuit': 'Automotodrom Brno',
#    'sequence': '10',
#    'url': '/en/ajax/results/selector/1975/TCH'}},
#  {'1': {'shortname': 'FRA',
#    'title': 'FRENCH GRAND PRIX',
#    'circuit': 'Le Mans',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1976/FRA'},
#   '2': {'shortname': 'AUT',
#    'title': 'AUSTRIAN GRAND PRIX',
#    'circuit': 'Salzburgring',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1976/AUT'},
#   '3': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Autodromo Internazionale del Mugello',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1976/NAT'},
#   '4': {'shortname': 'TT',
#    'title': 'TOURIST TROPHY',
#    'circuit': 'Isle of Man',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1976/TT'},
#   '5': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1976/NED'},
#   '6': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1976/BEL'},
#   '7': {'shortname': 'SWE',
#    'title': 'SWEDISH GRAND PRIX',
#    'circuit': 'Anderstorp',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1976/SWE'},
#   '8': {'shortname': 'FIN',
#    'title': 'FINLAND GRAND PRIX',
#    'circuit': 'Imatra',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/1976/FIN'},
#   '9': {'shortname': 'TCH',
#    'title': 'CZECHOSLOVAKIAN GRAND PRIX',
#    'circuit': 'Automotodrom Brno',
#    'sequence': '9',
#    'url': '/en/ajax/results/selector/1976/TCH'},
#   '10': {'shortname': 'WGER',
#    'title': 'WEST GERMANY GRAND PRIX',
#    'circuit': 'Nurburgring',
#    'sequence': '10',
#    'url': '/en/ajax/results/selector/1976/WGER'}},
#  {'1': {'shortname': 'VEN',
#    'title': 'VENEZUELA GRAND PRIX',
#    'circuit': 'San Carlos',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1977/VEN'},
#   '2': {'shortname': 'AUT',
#    'title': 'AUSTRIAN GRAND PRIX',
#    'circuit': 'Salzburgring',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1977/AUT'},
#   '3': {'shortname': 'WGER',
#    'title': 'WEST GERMANY GRAND PRIX',
#    'circuit': 'Hockenheim',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1977/WGER'},
#   '4': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Autodromo Enzo e Dino Ferrari',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1977/NAT'},
#   '5': {'shortname': 'FRA',
#    'title': 'FRENCH GRAND PRIX',
#    'circuit': 'Paul Ricard Circuit',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1977/FRA'},
#   '6': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1977/NED'},
#   '7': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1977/BEL'},
#   '8': {'shortname': 'SWE',
#    'title': 'SWEDISH GRAND PRIX',
#    'circuit': 'Anderstorp',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/1977/SWE'},
#   '9': {'shortname': 'FIN',
#    'title': 'FINLAND GRAND PRIX',
#    'circuit': 'Imatra',
#    'sequence': '9',
#    'url': '/en/ajax/results/selector/1977/FIN'},
#   '10': {'shortname': 'TCH',
#    'title': 'CZECHOSLOVAKIAN GRAND PRIX',
#    'circuit': 'Automotodrom Brno',
#    'sequence': '10',
#    'url': '/en/ajax/results/selector/1977/TCH'},
#   '11': {'shortname': 'GBR',
#    'title': 'BRITISH GRAND PRIX',
#    'circuit': 'Silverstone Circuit',
#    'sequence': '11',
#    'url': '/en/ajax/results/selector/1977/GBR'}},
#  {'1': {'shortname': 'VEN',
#    'title': 'VENEZUELA GRAND PRIX',
#    'circuit': 'San Carlos',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1978/VEN'},
#   '2': {'shortname': 'SPA',
#    'title': 'SPANISH GRAND PRIX',
#    'circuit': 'Jarama Circuit',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1978/SPA'},
#   '3': {'shortname': 'AUT',
#    'title': 'AUSTRIAN GRAND PRIX',
#    'circuit': 'Salzburgring',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1978/AUT'},
#   '4': {'shortname': 'FRA',
#    'title': 'FRENCH GRAND PRIX',
#    'circuit': 'Nogaro',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1978/FRA'},
#   '5': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Autodromo Internazionale del Mugello',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1978/NAT'},
#   '6': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1978/NED'},
#   '7': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1978/BEL'},
#   '8': {'shortname': 'SWE',
#    'title': 'SWEDISH GRAND PRIX',
#    'circuit': 'Karlskoga',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/1978/SWE'},
#   '9': {'shortname': 'FIN',
#    'title': 'FINLAND GRAND PRIX',
#    'circuit': 'Imatra',
#    'sequence': '9',
#    'url': '/en/ajax/results/selector/1978/FIN'},
#   '10': {'shortname': 'GBR',
#    'title': 'BRITISH GRAND PRIX',
#    'circuit': 'Silverstone Circuit',
#    'sequence': '10',
#    'url': '/en/ajax/results/selector/1978/GBR'},
#   '11': {'shortname': 'WGER',
#    'title': 'WEST GERMANY GRAND PRIX',
#    'circuit': 'Nurburgring',
#    'sequence': '11',
#    'url': '/en/ajax/results/selector/1978/WGER'}},
#  {'1': {'shortname': 'VEN',
#    'title': 'VENEZUELA GRAND PRIX',
#    'circuit': 'San Carlos',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1979/VEN'},
#   '2': {'shortname': 'AUT',
#    'title': 'AUSTRIAN GRAND PRIX',
#    'circuit': 'Salzburgring',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1979/AUT'},
#   '3': {'shortname': 'WGER',
#    'title': 'WEST GERMANY GRAND PRIX',
#    'circuit': 'Hockenheim',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1979/WGER'},
#   '4': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Autodromo Enzo e Dino Ferrari',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1979/NAT'},
#   '5': {'shortname': 'SPA',
#    'title': 'SPANISH GRAND PRIX',
#    'circuit': 'Jarama Circuit',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1979/SPA'},
#   '6': {'shortname': 'JUG',
#    'title': 'YUGOSLAVIAN GRAND PRIX',
#    'circuit': 'Rijeka',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1979/JUG'},
#   '7': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1979/NED'},
#   '8': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/1979/BEL'},
#   '9': {'shortname': 'SWE',
#    'title': 'SWEDISH GRAND PRIX',
#    'circuit': 'Karlskoga',
#    'sequence': '9',
#    'url': '/en/ajax/results/selector/1979/SWE'},
#   '10': {'shortname': 'FIN',
#    'title': 'FINLAND GRAND PRIX',
#    'circuit': 'Imatra',
#    'sequence': '10',
#    'url': '/en/ajax/results/selector/1979/FIN'},
#   '11': {'shortname': 'GBR',
#    'title': 'BRITISH GRAND PRIX',
#    'circuit': 'Silverstone Circuit',
#    'sequence': '11',
#    'url': '/en/ajax/results/selector/1979/GBR'},
#   '12': {'shortname': 'FRA',
#    'title': 'FRENCH GRAND PRIX',
#    'circuit': 'Le Mans',
#    'sequence': '12',
#    'url': '/en/ajax/results/selector/1979/FRA'}},
#  {'1': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Misano World Circuit Marco Simoncelli',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1980/NAT'},
#   '2': {'shortname': 'SPA',
#    'title': 'SPANISH GRAND PRIX',
#    'circuit': 'Jarama Circuit',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1980/SPA'},
#   '3': {'shortname': 'FRA',
#    'title': 'FRENCH GRAND PRIX',
#    'circuit': 'Paul Ricard Circuit',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1980/FRA'},
#   '4': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1980/NED'},
#   '5': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Zolder',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1980/BEL'},
#   '6': {'shortname': 'FIN',
#    'title': 'FINLAND GRAND PRIX',
#    'circuit': 'Imatra',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1980/FIN'},
#   '7': {'shortname': 'GBR',
#    'title': 'BRITISH GRAND PRIX',
#    'circuit': 'Silverstone Circuit',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1980/GBR'},
#   '8': {'shortname': 'WGER',
#    'title': 'WEST GERMANY GRAND PRIX',
#    'circuit': 'Nurburgring',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/1980/WGER'}},
#  {'1': {'shortname': 'AUT',
#    'title': 'AUSTRIAN GRAND PRIX',
#    'circuit': 'Salzburgring',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1981/AUT'},
#   '2': {'shortname': 'WGER',
#    'title': 'WEST GERMANY GRAND PRIX',
#    'circuit': 'Hockenheim',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1981/WGER'},
#   '3': {'shortname': 'NAT',
#    'title': 'NATIONS GRAND PRIX',
#    'circuit': 'Monza',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1981/NAT'},
#   '4': {'shortname': 'FRA',
#    'title': 'FRENCH GRAND PRIX',
#    'circuit': 'Paul Ricard Circuit',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/1981/FRA'},
#   '5': {'shortname': 'JUG',
#    'title': 'YUGOSLAVIAN GRAND PRIX',
#    'circuit': 'Rijeka',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/1981/JUG'},
#   '6': {'shortname': 'NED',
#    'title': 'DUTCH TT',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/1981/NED'},
#   '7': {'shortname': 'BEL',
#    'title': 'BELGIUM GRAND PRIX',
#    'circuit': 'Spa-Francorchamps',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/1981/BEL'},
#   '8': {'shortname': 'RSM',
#    'title': 'SAN MARINO GRAND PRIX',
#    'circuit': 'Autodromo Enzo e Dino Ferrari',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/1981/RSM'},
#   '9': {'shortname': 'GBR',
#    'title': 'BRITISH GRAND PRIX',
#    'circuit': 'Silverstone Circuit',
#    'sequence': '9',
#    'url': '/en/ajax/results/selector/1981/GBR'},
#   '10': {'shortname': 'FIN',
#    'title': 'FINLAND GRAND PRIX',
#    'circuit': 'Imatra',
#    'sequence': '10',
#    'url': '/en/ajax/results/selector/1981/FIN'},
#   '11': {'shortname': 'SWE',
#    'title': 'SWEDISH GRAND PRIX',
#    'circuit': 'Anderstorp',
#    'sequence': '11',
#    'url': '/en/ajax/results/selector/1981/SWE'}},
#  {'1': {'shortname': 'ARG',
#    'title': 'Argentinian Grand Prix',
#    'circuit': 'Autodromo Oscar A. Galvez',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/1982/ARG'},
#   '2': {'shortname': 'AUT',
#    'title': 'AUSTRIAN GRAND PRIX',
#    'circuit': 'Salzburgring',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/1982/AUT'},
#   '3': {'shortname': 'FRA',
#    'title': 'FRENCH GRAND PRIX',
#    'circuit': 'Nogaro',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/1982/FRA'},
#   '4': {'shortname': 'SPA',
#    'title': 'SPANISH GRAND PRIX',
#    'circuit': 'Jarama Circuit',
#    'sequence': '4',
# ...
#    'url': '/en/ajax/results/selector/2015/CAT'},
#   '8': {'shortname': 'NED',
#    'title': 'Motul TT Assen',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/2015/NED'},
#   '9': {'shortname': 'GER',
#    'title': 'GoPro Motorrad Grand Prix Deutschland',
#    'circuit': 'Sachsenring',
#    'sequence': '9',
#    'url': '/en/ajax/results/selector/2015/GER'},
#   '10': {'shortname': 'INP',
#    'title': 'Red Bull Indianapolis Grand Prix',
#    'circuit': 'Indianapolis Motor Speedway',
#    'sequence': '10',
#    'url': '/en/ajax/results/selector/2015/INP'},
#   '11': {'shortname': 'CZE',
#    'title': 'bwin Grand Prix České republiky',
#    'circuit': 'Automotodrom Brno',
#    'sequence': '11',
#    'url': '/en/ajax/results/selector/2015/CZE'},
#   '12': {'shortname': 'GBR',
#    'title': 'Octo British Grand Prix',
#    'circuit': 'Silverstone Circuit',
#    'sequence': '12',
#    'url': '/en/ajax/results/selector/2015/GBR'},
#   '13': {'shortname': 'RSM',
#    'title': 'GP TIM di San Marino e della Riviera di Rimini',
#    'circuit': 'Misano World Circuit Marco Simoncelli',
#    'sequence': '13',
#    'url': '/en/ajax/results/selector/2015/RSM'},
#   '14': {'shortname': 'ARA',
#    'title': 'Gran Premio Movistar de Aragón',
#    'circuit': 'MotorLand Aragón',
#    'sequence': '14',
#    'url': '/en/ajax/results/selector/2015/ARA'},
#   '15': {'shortname': 'JPN',
#    'title': 'Motul Grand Prix of Japan',
#    'circuit': 'Twin Ring Motegi',
#    'sequence': '15',
#    'url': '/en/ajax/results/selector/2015/JPN'},
#   '16': {'shortname': 'AUS',
#    'title': 'Pramac Australian Motorcycle Grand Prix',
#    'circuit': 'Phillip Island',
#    'sequence': '16',
#    'url': '/en/ajax/results/selector/2015/AUS'},
#   '17': {'shortname': 'MAL',
#    'title': 'Shell Malaysia Motorcycle Grand Prix',
#    'circuit': 'Sepang International Circuit',
#    'sequence': '17',
#    'url': '/en/ajax/results/selector/2015/MAL'},
#   '18': {'shortname': 'VAL',
#    'title': 'Gran Premio Motul de la Comunitat Valenciana',
#    'circuit': 'Circuit Ricardo Tormo',
#    'sequence': '18',
#    'url': '/en/ajax/results/selector/2015/VAL'}},
#  {'1': {'shortname': 'QAT',
#    'title': 'Commercial Bank Grand Prix of Qatar',
#    'circuit': 'Losail International Circuit',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/2016/QAT'},
#   '2': {'shortname': 'ARG',
#    'title': 'Gran Premio Motul de la República Argentina',
#    'circuit': 'Termas de Río Hondo',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/2016/ARG'},
#   '3': {'shortname': 'AME',
#    'title': 'Red Bull Grand Prix of The Americas',
#    'circuit': 'Circuit Of The Americas',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/2016/AME'},
#   '4': {'shortname': 'SPA',
#    'title': 'Gran Premio Red Bull de España',
#    'circuit': 'Circuito de Jerez - Angel Nieto',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/2016/SPA'},
#   '5': {'shortname': 'FRA',
#    'title': 'Monster Energy Grand Prix de France',
#    'circuit': 'Le Mans',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/2016/FRA'},
#   '6': {'shortname': 'ITA',
#    'title': "Gran Premio d'Italia TIM",
#    'circuit': 'Autodromo Internazionale del Mugello',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/2016/ITA'},
#   '7': {'shortname': 'CAT',
#    'title': 'Gran Premi Monster Energy de Catalunya',
#    'circuit': 'Circuit de Barcelona-Catalunya',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/2016/CAT'},
#   '8': {'shortname': 'NED',
#    'title': 'Motul TT Assen',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/2016/NED'},
#   '9': {'shortname': 'GER',
#    'title': 'GoPro Motorrad Grand Prix Deutschland',
#    'circuit': 'Sachsenring',
#    'sequence': '9',
#    'url': '/en/ajax/results/selector/2016/GER'},
#   '10': {'shortname': 'AUT',
#    'title': 'NeroGiardini Motorrad Grand Prix von Österreich',
#    'circuit': 'Red Bull Ring - Spielberg',
#    'sequence': '10',
#    'url': '/en/ajax/results/selector/2016/AUT'},
#   '11': {'shortname': 'CZE',
#    'title': 'HJC Helmets Grand Prix České republiky',
#    'circuit': 'Automotodrom Brno',
#    'sequence': '11',
#    'url': '/en/ajax/results/selector/2016/CZE'},
#   '12': {'shortname': 'GBR',
#    'title': 'Octo British Grand Prix',
#    'circuit': 'Silverstone Circuit',
#    'sequence': '12',
#    'url': '/en/ajax/results/selector/2016/GBR'},
#   '13': {'shortname': 'RSM',
#    'title': 'GP TIM di San Marino e della Riviera di Rimini',
#    'circuit': 'Misano World Circuit Marco Simoncelli',
#    'sequence': '13',
#    'url': '/en/ajax/results/selector/2016/RSM'},
#   '14': {'shortname': 'ARA',
#    'title': 'Gran Premio Movistar de Aragón',
#    'circuit': 'MotorLand Aragón',
#    'sequence': '14',
#    'url': '/en/ajax/results/selector/2016/ARA'},
#   '15': {'shortname': 'JPN',
#    'title': 'Motul Grand Prix of Japan',
#    'circuit': 'Twin Ring Motegi',
#    'sequence': '15',
#    'url': '/en/ajax/results/selector/2016/JPN'},
#   '16': {'shortname': 'AUS',
#    'title': 'Michelin® Australian Motorcycle Grand Prix',
#    'circuit': 'Phillip Island',
#    'sequence': '16',
#    'url': '/en/ajax/results/selector/2016/AUS'},
#   '17': {'shortname': 'MAL',
#    'title': 'Shell Malaysia Motorcycle Grand Prix',
#    'circuit': 'Sepang International Circuit',
#    'sequence': '17',
#    'url': '/en/ajax/results/selector/2016/MAL'},
#   '18': {'shortname': 'VAL',
#    'title': 'Gran Premio Motul de la Comunitat Valenciana',
#    'circuit': 'Circuit Ricardo Tormo',
#    'sequence': '18',
#    'url': '/en/ajax/results/selector/2016/VAL'}},
#  {'1': {'shortname': 'QAT',
#    'title': 'Grand Prix of Qatar',
#    'circuit': 'Losail International Circuit',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/2017/QAT'},
#   '2': {'shortname': 'ARG',
#    'title': 'Gran Premio Motul de la República Argentina',
#    'circuit': 'Termas de Río Hondo',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/2017/ARG'},
#   '3': {'shortname': 'AME',
#    'title': 'Red Bull Grand Prix of The Americas',
#    'circuit': 'Circuit Of The Americas',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/2017/AME'},
#   '4': {'shortname': 'SPA',
#    'title': 'Gran Premio Red Bull de España',
#    'circuit': 'Circuito de Jerez - Angel Nieto',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/2017/SPA'},
#   '5': {'shortname': 'FRA',
#    'title': 'HJC Helmets Grand Prix de France',
#    'circuit': 'Le Mans',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/2017/FRA'},
#   '6': {'shortname': 'ITA',
#    'title': "Gran Premio d'Italia Oakley",
#    'circuit': 'Autodromo Internazionale del Mugello',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/2017/ITA'},
#   '7': {'shortname': 'CAT',
#    'title': 'Gran Premi Monster Energy de Catalunya',
#    'circuit': 'Circuit de Barcelona-Catalunya',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/2017/CAT'},
#   '8': {'shortname': 'NED',
#    'title': 'Motul TT Assen',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/2017/NED'},
#   '9': {'shortname': 'GER',
#    'title': 'GoPro Motorrad Grand Prix Deutschland',
#    'circuit': 'Sachsenring',
#    'sequence': '9',
#    'url': '/en/ajax/results/selector/2017/GER'},
#   '10': {'shortname': 'CZE',
#    'title': 'Monster Energy Grand Prix České republiky',
#    'circuit': 'Automotodrom Brno',
#    'sequence': '10',
#    'url': '/en/ajax/results/selector/2017/CZE'},
#   '11': {'shortname': 'AUT',
#    'title': 'NeroGiardini Motorrad Grand Prix von Österreich',
#    'circuit': 'Red Bull Ring - Spielberg',
#    'sequence': '11',
#    'url': '/en/ajax/results/selector/2017/AUT'},
#   '12': {'shortname': 'GBR',
#    'title': 'Octo British Grand Prix',
#    'circuit': 'Silverstone Circuit',
#    'sequence': '12',
#    'url': '/en/ajax/results/selector/2017/GBR'},
#   '13': {'shortname': 'RSM',
#    'title': 'Tribul Mastercard GP S.Marino e Riviera di Rimini',
#    'circuit': 'Misano World Circuit Marco Simoncelli',
#    'sequence': '13',
#    'url': '/en/ajax/results/selector/2017/RSM'},
#   '14': {'shortname': 'ARA',
#    'title': 'Gran Premio Movistar de Aragón',
#    'circuit': 'MotorLand Aragón',
#    'sequence': '14',
#    'url': '/en/ajax/results/selector/2017/ARA'},
#   '15': {'shortname': 'JPN',
#    'title': 'Motul Grand Prix of Japan',
#    'circuit': 'Twin Ring Motegi',
#    'sequence': '15',
#    'url': '/en/ajax/results/selector/2017/JPN'},
#   '16': {'shortname': 'AUS',
#    'title': 'Michelin® Australian Motorcycle Grand Prix',
#    'circuit': 'Phillip Island',
#    'sequence': '16',
#    'url': '/en/ajax/results/selector/2017/AUS'},
#   '17': {'shortname': 'MAL',
#    'title': 'Shell Malaysia Motorcycle Grand Prix',
#    'circuit': 'Sepang International Circuit',
#    'sequence': '17',
#    'url': '/en/ajax/results/selector/2017/MAL'},
#   '18': {'shortname': 'VAL',
#    'title': 'Gran Premio Motul de la Comunitat Valenciana',
#    'circuit': 'Circuit Ricardo Tormo',
#    'sequence': '18',
#    'url': '/en/ajax/results/selector/2017/VAL'}},
#  {'1': {'shortname': 'QAT',
#    'title': 'Grand Prix of Qatar',
#    'circuit': 'Losail International Circuit',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/2018/QAT'},
#   '2': {'shortname': 'ARG',
#    'title': 'Gran Premio Motul de la República Argentina',
#    'circuit': 'Termas de Río Hondo',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/2018/ARG'},
#   '3': {'shortname': 'AME',
#    'title': 'Red Bull Grand Prix of The Americas',
#    'circuit': 'Circuit Of The Americas',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/2018/AME'},
#   '4': {'shortname': 'SPA',
#    'title': 'Gran Premio Red Bull de España',
#    'circuit': 'Circuito de Jerez - Angel Nieto',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/2018/SPA'},
#   '5': {'shortname': 'FRA',
#    'title': 'HJC Helmets Grand Prix de France',
#    'circuit': 'Le Mans',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/2018/FRA'},
#   '6': {'shortname': 'ITA',
#    'title': "Gran Premio d'Italia Oakley",
#    'circuit': 'Autodromo Internazionale del Mugello',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/2018/ITA'},
#   '7': {'shortname': 'CAT',
#    'title': 'Gran Premi Monster Energy de Catalunya',
#    'circuit': 'Circuit de Barcelona-Catalunya',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/2018/CAT'},
#   '8': {'shortname': 'NED',
#    'title': 'Motul TT Assen',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/2018/NED'},
#   '9': {'shortname': 'GER',
#    'title': 'Pramac Motorrad Grand Prix Deutschland',
#    'circuit': 'Sachsenring',
#    'sequence': '9',
#    'url': '/en/ajax/results/selector/2018/GER'},
#   '10': {'shortname': 'CZE',
#    'title': 'Monster Energy Grand Prix České republiky',
#    'circuit': 'Automotodrom Brno',
#    'sequence': '10',
#    'url': '/en/ajax/results/selector/2018/CZE'},
#   '11': {'shortname': 'AUT',
#    'title': 'eyetime Motorrad Grand Prix von Österreich',
#    'circuit': 'Red Bull Ring - Spielberg',
#    'sequence': '11',
#    'url': '/en/ajax/results/selector/2018/AUT'},
#   '12': {'shortname': 'GBR',
#    'title': 'GoPro British Grand Prix',
#    'circuit': 'Silverstone Circuit',
#    'sequence': '12',
#    'url': '/en/ajax/results/selector/2018/GBR'},
#   '13': {'shortname': 'RSM',
#    'title': 'GP Octo di San Marino e della Riviera di Rimini',
#    'circuit': 'Misano World Circuit Marco Simoncelli',
#    'sequence': '13',
#    'url': '/en/ajax/results/selector/2018/RSM'},
#   '14': {'shortname': 'ARA',
#    'title': 'Gran Premio Movistar de Aragón',
#    'circuit': 'MotorLand Aragón',
#    'sequence': '14',
#    'url': '/en/ajax/results/selector/2018/ARA'},
#   '15': {'shortname': 'THA',
#    'title': 'PTT Thailand Grand Prix',
#    'circuit': 'Chang International Circuit',
#    'sequence': '15',
#    'url': '/en/ajax/results/selector/2018/THA'},
#   '16': {'shortname': 'JPN',
#    'title': 'Motul Grand Prix of Japan',
#    'circuit': 'Twin Ring Motegi',
#    'sequence': '16',
#    'url': '/en/ajax/results/selector/2018/JPN'},
#   '17': {'shortname': 'AUS',
#    'title': 'Michelin® Australian Motorcycle Grand Prix',
#    'circuit': 'Phillip Island',
#    'sequence': '17',
#    'url': '/en/ajax/results/selector/2018/AUS'},
#   '18': {'shortname': 'MAL',
#    'title': 'Shell Malaysia Motorcycle Grand Prix',
#    'circuit': 'Sepang International Circuit',
#    'sequence': '18',
#    'url': '/en/ajax/results/selector/2018/MAL'},
#   '19': {'shortname': 'VAL',
#    'title': 'Gran Premio Motul de la Comunitat Valenciana',
#    'circuit': 'Circuit Ricardo Tormo',
#    'sequence': '19',
#    'url': '/en/ajax/results/selector/2018/VAL'}},
#  {'1': {'shortname': 'QAT',
#    'title': 'VisitQatar Grand Prix',
#    'circuit': 'Losail International Circuit',
#    'sequence': '1',
#    'url': '/en/ajax/results/selector/2019/QAT'},
#   '2': {'shortname': 'ARG',
#    'title': 'Gran Premio Motul de la República Argentina',
#    'circuit': 'Termas de Río Hondo',
#    'sequence': '2',
#    'url': '/en/ajax/results/selector/2019/ARG'},
#   '3': {'shortname': 'AME',
#    'title': 'Red Bull Grand Prix of The Americas',
#    'circuit': 'Circuit Of The Americas',
#    'sequence': '3',
#    'url': '/en/ajax/results/selector/2019/AME'},
#   '4': {'shortname': 'SPA',
#    'title': 'Gran Premio Red Bull de España',
#    'circuit': 'Circuito de Jerez - Angel Nieto',
#    'sequence': '4',
#    'url': '/en/ajax/results/selector/2019/SPA'},
#   '5': {'shortname': 'FRA',
#    'title': 'SHARK Helmets Grand Prix de France',
#    'circuit': 'Le Mans',
#    'sequence': '5',
#    'url': '/en/ajax/results/selector/2019/FRA'},
#   '6': {'shortname': 'ITA',
#    'title': "Gran Premio d'Italia Oakley",
#    'circuit': 'Autodromo Internazionale del Mugello',
#    'sequence': '6',
#    'url': '/en/ajax/results/selector/2019/ITA'},
#   '7': {'shortname': 'CAT',
#    'title': 'Gran Premi Monster Energy de Catalunya',
#    'circuit': 'Circuit de Barcelona-Catalunya',
#    'sequence': '7',
#    'url': '/en/ajax/results/selector/2019/CAT'},
#   '8': {'shortname': 'NED',
#    'title': 'Motul TT Assen',
#    'circuit': 'TT Circuit Assen',
#    'sequence': '8',
#    'url': '/en/ajax/results/selector/2019/NED'},
#   '9': {'shortname': 'GER',
#    'title': 'HJC Helmets Motorrad Grand Prix Deutschland',
#    'circuit': 'Sachsenring',
#    'sequence': '9',
#    'url': '/en/ajax/results/selector/2019/GER'},
#   '10': {'shortname': 'CZE',
#    'title': 'Monster Energy Grand Prix České republiky',
#    'circuit': 'Automotodrom Brno',
#    'sequence': '10',
#    'url': '/en/ajax/results/selector/2019/CZE'},
#   '11': {'shortname': 'AUT',
#    'title': 'myWorld Motorrad Grand Prix von Österreich',
#    'circuit': 'Red Bull Ring - Spielberg',
#    'sequence': '11',
#    'url': '/en/ajax/results/selector/2019/AUT'},
#   '12': {'shortname': 'GBR',
#    'title': 'GoPro British Grand Prix',
#    'circuit': 'Silverstone Circuit',
#    'sequence': '12',
#    'url': '/en/ajax/results/selector/2019/GBR'},
#   '13': {'shortname': 'RSM',
#    'title': 'GP Octo di San Marino e della Riviera di Rimini',
#    'circuit': 'Misano World Circuit Marco Simoncelli',
#    'sequence': '13',
#    'url': '/en/ajax/results/selector/2019/RSM'},
#   '14': {'shortname': 'ARA',
#    'title': 'Gran Premio Michelin® de Aragon',
#    'circuit': 'MotorLand Aragón',
#    'sequence': '14',
#    'url': '/en/ajax/results/selector/2019/ARA'},
#   '15': {'shortname': 'THA',
#    'title': 'PTT Thailand Grand Prix ',
#    'circuit': 'Chang International Circuit',
#    'sequence': '15',
#    'url': '/en/ajax/results/selector/2019/THA'},
#   '16': {'shortname': 'JPN',
#    'title': 'Motul Grand Prix of Japan',
#    'circuit': 'Twin Ring Motegi',
#    'sequence': '16',
#    'url': '/en/ajax/results/selector/2019/JPN'},
#   '17': {'shortname': 'AUS',
#    'title': 'Pramac Generac Australian Motorcycle GP',
#    'circuit': 'Phillip Island',
#    'sequence': '17',
#    'url': '/en/ajax/results/selector/2019/AUS'},
#   '18': {'shortname': 'MAL',
#    'title': 'Shell Malaysia Motorcycle Grand Prix',
#    'circuit': 'Sepang International Circuit',
#    'sequence': '18',
#    'url': '/en/ajax/results/selector/2019/MAL'},
#   '19': {'shortname': 'VAL',
#    'title': 'Gran Premio Motul de la Comunitat Valenciana',
#    'circuit': 'Circuit Ricardo Tormo',
#    'sequence': '19',
#    'url': '/en/ajax/results/selector/2019/VAL'}}]
